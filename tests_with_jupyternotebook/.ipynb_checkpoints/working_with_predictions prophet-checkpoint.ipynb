# %% [markdown]
# # Paso 1:
# Abrir nuestro csv con la información moldeada y convertir el formato de la columna date a datetime

# %%
import pandas as pd
import numpy as np
from fbprophet import Prophet
import matplotlib.pyplot as plt
import datetime as dt

# %%
btc_df = pd.read_csv('../csv_files/btc_mxn_bitso_19_12_14.csv')

# %%
btc_df.date = btc_df.date.astype('datetime64')

# %%
btc_df
# Out:
#           date        24h_avg        12h_avg        min        max     volume  \
# 0   2019-01-01   72367.013703   71940.650982   71482.60   74305.00  23.596065
# 1   2019-01-02   74240.741398   73729.642422   73200.00   75800.00  32.171027
# 2   2019-01-03   74502.944671   75087.876912   73206.01   75770.91  32.681422
# 3   2019-01-04   73862.854180   74143.966128   73111.00   74992.99  63.488756
# 4   2019-01-05   74501.196250   74502.782839   73500.00   75340.12  43.711783
# ..         ...            ...            ...        ...        ...        ...
# 343 2019-12-10  140312.664853  141920.500901  138009.72  142536.45  42.952229
# 344 2019-12-11  137608.144227  139283.050570  132000.00  139900.00  35.334826
# 345 2019-12-12  136844.432405  136662.505259  135250.41  138699.98  25.641359
# 346 2019-12-13  137767.075557  137186.985455  136800.01  138799.97  39.382959
# 347 2019-12-14  136215.456165  138189.031451  133300.11  138488.46  32.294932
#
#     m_side
# 0     sell
# 1     sell
# 2     sell
# 3      buy
# 4      buy
# ..     ...
# 343   sell
# 344    buy
# 345   sell
# 346   sell
# 347   sell
#
# [348 rows x 7 columns]

# %% [markdown]
# # Paso 2:
#
# Utilizando prophet de Fb con cada una de las columnas de precios

# %% [markdown]
# ## Utilizando 24h_avg

# %%
#Seleccionando las columnas necesarias para utilizar con prophet
btc_24h_avg = btc_df[['date', '24h_avg']].copy()

# %%
#Cambiando el nombre de las columnas al formato requerido por prophet
btc_24h_avg.rename(columns={'date': 'ds', '24h_avg': 'y'}, inplace=True)

# %%
#Entrenando el modelo
mod = Prophet(growth='linear', n_changepoints=150)
mod.fit(btc_24h_avg)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = mod.make_future_dataframe(periods=60)
future.head()
# Out:
#           ds
# 0 2019-01-01
# 1 2019-01-02
# 2 2019-01-03
# 3 2019-01-04
# 4 2019-01-05

# %%
forecast = mod.predict(future)

# %%
mod.plot(forecast, uncertainty=True)
plt.title('Media de 24 horas para el precio del BTC/MXN ')
plt.xlabel('Fecha')
plt.ylabel('MXN')

plt.show()

# %%
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']]
# Out:
#             ds           yhat    yhat_lower     yhat_upper
# 0   2019-01-01   66215.883132  50941.408398   80921.268017
# 1   2019-01-02   66260.768791  50749.979981   81451.496070
# 2   2019-01-03   65289.960033  50596.375662   79262.224473
# 3   2019-01-04   65480.211146  50551.848875   79974.930677
# 4   2019-01-05   66870.029413  53523.639943   81411.227326
# ..         ...            ...           ...            ...
# 403 2020-02-08  109422.220832  93582.930969  126977.260732
# 404 2020-02-09  108408.398955  90996.894816  124358.698221
# 405 2020-02-10  108359.669421  93817.905353  124978.280014
# 406 2020-02-11  107651.871018  90961.524810  123847.896724
# 407 2020-02-12  107018.896588  90618.345462  123602.065377
#
# [408 rows x 4 columns]

# %% [markdown]
# ## Utilizando 12h_avg

# %%
#Seleccionando las columnas necesarias para utilizar con prophet
btc_12h_avg = btc_df[['date', '12h_avg']].copy()

#Cambiando el nombre de las columnas al formato requerido por prophet
btc_12h_avg.rename(columns={'date': 'ds', '12h_avg': 'y'}, inplace=True)

#Entrenando el modelo
mod12 = Prophet(growth='linear', n_changepoints=150)
mod12.fit(btc_12h_avg)

#Creando el nuevo dataframe con las fechas a predecir
future12 = mod12.make_future_dataframe(periods=60)
future12.tail()
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#             ds
# 403 2020-02-08
# 404 2020-02-09
# 405 2020-02-10
# 406 2020-02-11
# 407 2020-02-12

# %%
#Prediciendo los precios del nuevo dataframe
forecast12 = mod12.predict(future12)

#Creando gráfico de la predicción
mod12.plot(forecast12, uncertainty=True)
plt.title('Media de 12 horas para el precio del BTC/MXN ')
plt.xlabel('Fecha')
plt.ylabel('MXN')
plt.show()

# %%
#Revisando las ultimas columnas del modelo
forecast12[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#             ds           yhat    yhat_lower     yhat_upper
# 403 2020-02-08  109678.748601  91423.942465  124843.053720
# 404 2020-02-09  108704.595678  93223.796933  124840.668740
# 405 2020-02-10  107853.066525  90984.685636  123090.964540
# 406 2020-02-11  108434.254363  93112.790943  123596.397001
# 407 2020-02-12  106978.193259  88874.382253  122770.223439

# %% [markdown]
# ## Utilizando el mínimo

# %%
#Seleccionando las columnas necesarias para utilizar con prophet
btc_min = btc_df[['date', 'min']].copy()

#Cambiando el nombre de las columnas al formato requerido por prophet
btc_min.rename(columns={'date': 'ds', 'min': 'y'}, inplace=True)

#Entrenando el modelo
mod_min = Prophet(growth='linear', n_changepoints=150)
mod_min.fit(btc_min)

#Creando el nuevo dataframe con las fechas a predecir
future_min = mod_min.make_future_dataframe(periods=60)
future_min.tail()
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#             ds
# 403 2020-02-08
# 404 2020-02-09
# 405 2020-02-10
# 406 2020-02-11
# 407 2020-02-12

# %%
#Prediciendo los precios del nuevo dataframe
forecast_min = mod_min.predict(future_min)

#Creando gráfico de la predicción
mod_min.plot(forecast_min, uncertainty=True)
plt.title('Precio mínimo para BTC/MXN ')
plt.xlabel('Fecha')
plt.ylabel('MXN')
plt.show()

# %%
#Revisando las ultimas columnas del modelo
forecast_min[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#             ds           yhat    yhat_lower     yhat_upper
# 403 2020-02-08  107956.721156  92090.758203  123558.455885
# 404 2020-02-09  106931.236494  91962.244726  122849.751887
# 405 2020-02-10  106083.710162  90820.595047  122863.947002
# 406 2020-02-11  105579.694212  88982.713689  121659.171735
# 407 2020-02-12  104750.589280  88159.486220  120169.754170

# %% [markdown]
# ## Utilizando el máximo

# %%
#Seleccionando las columnas necesarias para utilizar con prophet
btc_max = btc_df[['date', 'max']].copy()

#Cambiando el nombre de las columnas al formato requerido por prophet
btc_max.rename(columns={'date': 'ds', 'max': 'y'}, inplace=True)

#Entrenando el modelo
mod_max = Prophet(growth='linear', n_changepoints=150)
mod_max.fit(btc_max)

#Creando el nuevo dataframe con las fechas a predecir
future_max = mod_max.make_future_dataframe(periods=60)
future_max.tail()
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#             ds
# 403 2020-02-08
# 404 2020-02-09
# 405 2020-02-10
# 406 2020-02-11
# 407 2020-02-12

# %%
#Prediciendo los precios del nuevo dataframe
forecast_max = mod_max.predict(future_min)

#Creando gráfico de la predicción
mod_max.plot(forecast_max, uncertainty=True)
plt.title('Precio máximo para BTC/MXN ')
plt.xlabel('Fecha')
plt.ylabel('MXN')
plt.show()

# %%
#Revisando las ultimas columnas del modelo
forecast_max[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#             ds           yhat    yhat_lower     yhat_upper
# 403 2020-02-08  111174.010089  93902.009984  129477.555005
# 404 2020-02-09  110247.033194  93360.047970  128486.076294
# 405 2020-02-10  110505.175223  91570.118347  127733.047338
# 406 2020-02-11  110014.156850  93161.662019  127314.791695
# 407 2020-02-12  109511.411119  93262.775268  127545.548978
