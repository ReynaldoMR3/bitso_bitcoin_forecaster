# %%
#Necesary imports.
import bitso
import pandas as pd
import numpy as np
from datetime import timezone
import datetime
from dateutil.tz import tzutc
import time
from fbprophet import Prophet
import matplotlib.pyplot as plt
from scipy.stats import boxcox
import warnings
warnings.filterwarnings('ignore')
import plotly.offline
from plotly import graph_objs as go

# %%
#Opening my api key and secret.
with open('../key.txt') as f:
    a = f.readlines()

with open('../secret.txt') as p:
    b = p.readlines()

#Using the api secret and key to call the api.
API_SECRET = [i.split('\n') for i in a][0][0]
API_KEY = [i.split('\n') for i in b][0][0]
api = bitso.Api(API_KEY, API_SECRET)

# %%
#Defining the empyt lists of the elements we need from the api.
btc_mxn_date = []
btc_mxn_price = []
btc_mxn_volume = []
btc_mxn_hour = []
btc_mxn_side = []

#Marker than changes the time in the api calls.
mark = 13059700

#Datetime when the code is running
now = datetime.datetime.now(timezone.utc)

#While loop for scrapping the information we need
while 1:
    #limit of requests, the max we can get is 100
    limit = '100'
    #Calling the api trades, we use sort 'asc' so i't starts on the marker we want.
    trades = api.trades('btc_mxn', sort='asc', limit=limit, marker=mark)
    #Starting the counter so we don't raise the error of too many requests on the api.
    count = 0
    #printing the mark and the spaces, we need these so we know the last mark we use.
    print(mark)
    print('')
    print('')
    #if statement to break the while loop.
    if trades != []:
        #starting a for loop to append the elements we need from each trade to our lists
        for e in trades:
            #adding to the counter.
            count +=1
            # if statement so we just scrap elements before today.
            if e.created_at < now :
                #printing each trade so we can see that everythings is working fine.
                print(e)
                #scrapping the elements we need
                btc_mxn_price.append(e.price)
                btc_mxn_volume.append(e.amount)
                btc_mxn_hour.append(e.created_at.hour)
                btc_mxn_date.append(e.created_at.date())
                btc_mxn_side.append(e.maker_side)
        '''
        if statement that starts a timer when the count reachs 100, we can just get
        300 requests per minute so our timer waits 21 seconds before making the next
        100 requests. It also adds a thousand to our mark so it moves forward in time.
        '''
        if count == 100:
            time.sleep(21)
            count = 0
            mark = mark + 1000
            
    #else statement to break the loop.
    else:
        break
# Out:
# 12992700
#
#
# Trade(tid=12992701, price=138300.00, amount=0.02725300, maker_side=sell, created_at=2019-12-22 22:27:19+00:00)
# Trade(tid=12992703, price=138300.00, amount=0.01604200, maker_side=sell, created_at=2019-12-22 22:27:20+00:00)
# Trade(tid=12992705, price=138300.00, amount=0.00007133, maker_side=sell, created_at=2019-12-22 22:27:54+00:00)
# Trade(tid=12992706, price=139088.74, amount=0.00924202, maker_side=sell, created_at=2019-12-22 22:28:47+00:00)
# Trade(tid=12992707, price=139088.66, amount=0.00647069, maker_side=sell, created_at=2019-12-22 22:29:06+00:00)
# Trade(tid=12992708, price=139088.52, amount=0.01078450, maker_side=sell, created_at=2019-12-22 22:29:36+00:00)
# Trade(tid=12992709, price=139087.90, amount=0.03267801, maker_side=sell, created_at=2019-12-22 22:31:43+00:00)
# Trade(tid=12992710, price=139087.90, amount=0.01046018, maker_side=sell, created_at=2019-12-22 22:31:43+00:00)
# Trade(tid=12992711, price=138307.66, amount=0.00218327, maker_side=buy, created_at=2019-12-22 22:32:08+00:00)
# Trade(tid=12992712, price=138308.87, amount=0.00127721, maker_side=buy, created_at=2019-12-22 22:32:42+00:00)
# Trade(tid=12992726, price=138999.99, amount=0.01551449, maker_side=sell, created_at=2019-12-22 22:35:11+00:00)
# Trade(tid=12992790, price=138404.48, amount=0.00800000, maker_side=buy, created_at=2019-12-22 22:58:59+00:00)
# Trade(tid=12992791, price=138404.49, amount=0.05293672, maker_side=buy, created_at=2019-12-22 22:59:00+00:00)
# Trade(tid=12992797, price=138408.40, amount=0.00581783, maker_side=buy, created_at=2019-12-22 23:00:58+00:00)
# Trade(tid=12992799, price=139449.10, amount=0.00358554, maker_side=sell, created_at=2019-12-22 23:01:21+00:00)
# Trade(tid=12992800, price=138409.08, amount=0.05100000, maker_side=buy, created_at=2019-12-22 23:01:21+00:00)
# Trade(tid=12992803, price=138410.01, amount=0.00581775, maker_side=buy, created_at=2019-12-22 23:01:47+00:00)
# Trade(tid=12992807, price=139449.99, amount=0.01635439, maker_side=sell, created_at=2019-12-22 23:02:14+00:00)
# Trade(tid=12992808, price=139450.00, amount=0.00014343, maker_side=sell, created_at=2019-12-22 23:02:14+00:00)
# Trade(tid=12992809, price=139450.04, amount=0.00010289, maker_side=sell, created_at=2019-12-22 23:02:14+00:00)
# Trade(tid=12992810, price=139450.46, amount=0.00012057, maker_side=sell, created_at=2019-12-22 23:02:14+00:00)
# Trade(tid=12992811, price=139468.66, amount=0.00008037, maker_side=sell, created_at=2019-12-22 23:02:14+00:00)
# Trade(tid=12992812, price=139468.76, amount=0.00010717, maker_side=sell, created_at=2019-12-22 23:02:14+00:00)
# Trade(tid=12992813, price=139548.56, amount=0.00012057, maker_side=sell, created_at=2019-12-22 23:02:14+00:00)
# Trade(tid=12992814, price=139639.98, amount=0.00203284, maker_side=sell, created_at=2019-12-22 23:02:14+00:00)
# Trade(tid=12992815, price=138459.92, amount=0.00731047, maker_side=buy, created_at=2019-12-22 23:02:45+00:00)
# Trade(tid=12992817, price=139639.56, amount=0.00291465, maker_side=sell, created_at=2019-12-22 23:03:41+00:00)
# Trade(tid=12992819, price=139639.40, amount=0.00009668, maker_side=sell, created_at=2019-12-22 23:04:10+00:00)
# Trade(tid=12992820, price=139639.40, amount=0.00071613, maker_side=sell, created_at=2019-12-22 23:04:10+00:00)
# Trade(tid=12992821, price=138600.64, amount=0.00734162, maker_side=buy, created_at=2019-12-22 23:04:14+00:00)
# Trade(tid=12992822, price=139639.25, amount=0.00358066, maker_side=sell, created_at=2019-12-22 23:04:41+00:00)
# Trade(tid=12992824, price=139639.23, amount=0.03988724, maker_side=sell, created_at=2019-12-22 23:04:47+00:00)
# Trade(tid=12992825, price=139639.23, amount=0.00308058, maker_side=sell, created_at=2019-12-22 23:04:47+00:00)
# Trade(tid=12992826, price=138701.33, amount=0.00290277, maker_side=buy, created_at=2019-12-22 23:05:26+00:00)
# Trade(tid=12992828, price=139638.97, amount=0.02288611, maker_side=sell, created_at=2019-12-22 23:05:43+00:00)
# Trade(tid=12992829, price=139638.97, amount=0.01650117, maker_side=sell, created_at=2019-12-22 23:05:43+00:00)
# Trade(tid=12992838, price=139639.99, amount=0.00139072, maker_side=sell, created_at=2019-12-22 23:07:30+00:00)
# Trade(tid=12992844, price=138944.83, amount=0.00157576, maker_side=buy, created_at=2019-12-22 23:08:17+00:00)
# Trade(tid=12992846, price=139639.99, amount=0.00157548, maker_side=sell, created_at=2019-12-22 23:08:48+00:00)
# Trade(tid=12992849, price=138946.29, amount=0.00700000, maker_side=buy, created_at=2019-12-22 23:09:27+00:00)
# Trade(tid=12992852, price=139639.99, amount=0.00457856, maker_side=sell, created_at=2019-12-22 23:10:12+00:00)
# Trade(tid=12992853, price=139639.99, amount=0.00794186, maker_side=sell, created_at=2019-12-22 23:10:12+00:00)
# Trade(tid=12992854, price=139640.00, amount=0.03261980, maker_side=sell, created_at=2019-12-22 23:10:12+00:00)
maker_side=sell, created_at=2019-12-22 23:21:29+00:00)
# Trade(tid=12992914, price=139889.00, amount=0.00338336, maker_side=sell, created_at=2019-12-22 23:21:29+00:00)
# Trade(tid=12992916, price=139889.00, amount=0.00384500, maker_side=sell, created_at=2019-12-22 23:21:31+00:00)
# Trade(tid=12992917, price=139888.99, amount=0.00100000, maker_side=buy, created_at=2019-12-22 23:21:41+00:00)
# Trade(tid=12992918, price=139888.99, amount=0.00668855, maker_side=buy, created_at=2019-12-22 23:21:41+00:00)
# 12993700
#
#
# Trade(tid=12993701, price=142000.00, amount=0.02668300, maker_side=sell, created_at=2019-12-23 00:19:46+00:00)
# Trade(tid=12993702, price=142000.00, amount=0.02668300, maker_side=sell, created_at=2019-12-23 00:19:47+00:00)
# Trade(tid=12993703, price=142000.00, amount=0.02668300, maker_side=sell, created_at=2019-12-23 00:19:48+00:00)
# Trade(tid=12993704, price=142000.00, amount=0.02668300, maker_side=sell, created_at=2019-12-23 00:19:49+00:00)
# Trade(tid=12993705, price=142000.00, amount=0.00352113, maker_side=sell, created_at=2019-12-23 00:19:52+00:00)
# Trade(tid=12993707, price=142000.00, amount=0.07042254, maker_side=sell, created_at=2019-12-23 00:20:02+00:00)
# Trade(tid=12993708, price=142000.00, amount=0.12808000, maker_side=sell, created_at=2019-12-23 00:20:04+00:00)
# Trade(tid=12993709, price=142000.00, amount=0.12808000, maker_side=sell, created_at=2019-12-23 00:20:07+00:00)
# Trade(tid=12993711, price=142000.00, amount=0.12808000, maker_side=sell, created_at=2019-12-23 00:20:16+00:00)
# Trade(tid=12993712, price=142000.00, amount=0.12808000, maker_side=sell, created_at=2019-12-23 00:20:18+00:00)
# Trade(tid=12993713, price=142000.00, amount=0.12808000, maker_side=sell, created_at=2019-12-23 00:20:20+00:00)
# Trade(tid=12993714, price=142000.00, amount=0.12808000, maker_side=sell, created_at=2019-12-23 00:20:23+00:00)
# Trade(tid=12993715, price=142000.00, amount=0.12808000, maker_side=sell, created_at=2019-12-23 00:20:26+00:00)
# Trade(tid=12993718, price=142000.00, amount=0.10000000, maker_side=sell, created_at=2019-12-23 00:20:35+00:00)
# Trade(tid=12993719, price=142000.00, amount=0.15239652, maker_side=sell, created_at=2019-12-23 00:20:48+00:00)
# Trade(tid=12993720, price=141999.99, amount=0.00994480, maker_side=buy, created_at=2019-12-23 00:20:55+00:00)
# Trade(tid=12993721, price=142000.01, amount=0.00144423, maker_side=buy, created_at=2019-12-23 00:21:07+00:00)
# Trade(tid=12993725, price=142100.00, amount=0.00783100, maker_side=sell, created_at=2019-12-23 00:21:14+00:00)
# Trade(tid=12993727, price=142100.00, amount=0.00756600, maker_side=sell, created_at=2019-12-23 00:21:14+00:00)
# Trade(tid=12993728, price=142100.00, amount=0.00332400, maker_side=sell, created_at=2019-12-23 00:21:15+00:00)
# Trade(tid=12993729, price=142100.00, amount=0.02666300, maker_side=sell, created_at=2019-12-23 00:21:16+00:00)
# Trade(tid=12993730, price=142100.00, amount=0.02666300, maker_side=sell, created_at=2019-12-23 00:21:17+00:00)
# Trade(tid=12993732, price=142099.99, amount=0.00147599, maker_side=sell, created_at=2019-12-23 00:21:36+00:00)
# Trade(tid=12993733, price=142100.00, amount=0.12800000, maker_side=sell, created_at=2019-12-23 00:21:38+00:00)
# Trade(tid=12993734, price=142100.00, amount=0.02666300, maker_side=sell, created_at=2019-12-23 00:21:43+00:00)
# Trade(tid=12993735, price=142100.00, amount=0.02666300, maker_side=sell, created_at=2019-12-23 00:21:44+00:00)
# Trade(tid=12993736, price=142100.00, amount=0.02666300, maker_side=sell, created_at=2019-12-23 00:21:45+00:00)
# Trade(tid=12993737, price=142100.00, amount=0.02666300, maker_side=sell, created_at=2019-12-23 00:21:46+00:00)
# Trade(tid=12993740, price=142100.00, amount=0.02666300, maker_side=sell, created_at=2019-12-23 00:21:47+00:00)
# Trade(tid=12993741, price=142100.00, amount=0.02666300, maker_side=sell, created_at=2019-12-23 00:21:48+00:00)
# Trade(tid=12993742, price=142100.00, amount=0.02666300, maker_side=sell, created_at=2019-12-23 00:21:49+00:00)
# Trade(tid=12993743, price=142100.00, amount=0.02666300, maker_side=sell, created_at=2019-12-23 00:21:50+00:00)
# Trade(tid=12993744, price=142100.00, amount=0.02666300, maker_side=sell, created_at=2019-12-23 00:21:51+00:00)
# Trade(tid=12993746, price=142100.00, amount=0.02645500, maker_side=sell, created_at=2019-12-23 00:21:53+00:00)
# Trade(tid=12993747, price=142100.00, amount=0.02666300, maker_side=sell, created_at=2019-12-23 00:21:53+00:00)
# Trade(tid=12993749, price=142100.00, amount=0.01102500, maker_side=sell, created_at=2019-12-23 00:21:55+00:00)
# Trade(tid=12993750, price=142100.00, amount=0.05000000, maker_side=sell, created_at=2019-12-23 00:21:58+00:00)
# Trade(tid=12993753, price=142100.00, amount=0.05000000, maker_side=sell, created_at=2019-12-23 00:22:01+00:00)
# Trade(tid=12993754, price=142100.00, amount=0.05000000, maker_side=sell, created_at=2019-12-23 00:22:16+00:00)
# Trade(tid=12993755, price=142100.00, amount=0.00301963, maker_side=sell, created_at=2019-12-23 00:22:17+00:00)
# Trade(tid=12993756, price=142100.00, amount=0.05000000, maker_side=sell, created_at=2019-12-23 00:22:20+00:00)
# Trade(tid=12993757, price=142100.00, amount=0.05000000, maker_side=sell, created_at=2019-12-23 00:22:23+00:00)
# Trade(tid=12993758, price=142100.00, amount=0.05000000, maker_side=sell, created_at=2019-12-23 00:22:26+00:00)
# Trade(tid=12993759, price=142100.00, amount=0.01534131, maker_side=sell, created_at=2019-12-23 00:22:29+00:00)
# Trade(tid=12993760, price=142100.00, amount=0.05000000, maker_side=sell, created_at=2019-12-23 00:22:30+00:00)
# Trade(tid=12993761, price=142100.00, amount=0.05000000, maker_side=sell, created_at=2019-12-23 00:22:33+00:00)
# Trade(tid=12993762, price=142100.00, amount=0.05000000, maker_side=sell, created_at=2019-12-23 00:22:37+00:00)
# Trade(tid=12993763, price=142100.00, amount=0.05000000, maker_side=sell, created_at=2019-12-23 00:22:40+00:00)
# Trade(tid=12993764, price=142100.00, amount=0.00070373, maker_side=sell, created_at=2019-12-23 00:22:41+00:00)
# Trade(tid=12993765, price=142100.00, amount=0.05000000, maker_side=sell, created_at=2019-12-23 00:22:43+00:00)
# Trade(tid=12993766, price=142100.00, amount=0.40000000, maker_side=sell, created_at=2019-12-23 00:22:44+00:00)
# Trade(tid=12993767, price=142100.00, amount=0.05000000, maker_side=sell, created_at=2019-12-23 00:22:46+00:00)
# Trade(tid=12993768, price=142100.00, amount=0.05000000, maker_side=sell, created_at=2019-12-23 00:22:50+00:00)
# Trade(tid=12993769, price=142100.00, amount=0.05000000, maker_side=sell, created_at=2019-12-23 00:22:53+00:00)
# Trade(tid=12993770, price=142100.00, amount=0.05000000, maker_side=sell, created_at=2019-12-23 00:22:56+00:00)
# Trade(tid=12993771, price=142100.00, amount=0.05000000, maker_side=sell, created_at=2019-12-23 00:23:00+00:00)
# Trade(tid=12993773, price=142100.00, amount=0.25000000, maker_side=sell, created_at=2019-12-23 00:23:01+00:00)
# Trade(tid=12993774, price=142100.00, amount=0.05000000, maker_side=sell, created_at=2019-12-23 00:23:03+00:00)
# Trade(tid=12993775, price=142100.00, amount=0.40000000, maker_side=sell, created_at=2019-12-23 00:23:03+00:00)
# Trade(tid=12993776, price=142100.00, amount=0.05000000, maker_side=sell, created_at=2019-12-23 00:23:06+00:00)
# Trade(tid=12993777, price=142100.00, amount=0.05000000, maker_side=sell, created_at=2019-12-23 00:23:10+00:00)
# Trade(tid=12993778, price=142100.00, amount=0.05000000, maker_side=sell, created_at=2019-12-23 00:23:13+00:00)
# Trade(tid=12993779, price=142100.00, amount=0.05000000, maker_side=sell, created_at=2019-12-23 00:23:16+00:00)
# Trade(tid=12993780, price=142100.00, amount=0.00703730, maker_side=sell, created_at=2019-12-23 00:23:19+00:00)
# Trade(tid=12993781, price=142100.00, amount=0.05000000, maker_side=sell, created_at=2019-12-23 00:23:19+00:00)
# Trade(tid=12993782, price=142100.00, amount=0.00703730, maker_side=sell, created_at=2019-12-23 00:23:20+00:00)
# Trade(tid=12993783, price=142100.00, amount=0.05000000, maker_side=sell, created_at=2019-12-23 00:23:23+00:00)
# Trade(tid=12993784, price=142100.00, amount=0.14637580, maker_side=sell, created_at=2019-12-23 00:23:31+00:00)
# Trade(tid=12993785, price=142095.04, amount=0.03000000, maker_side=buy, created_at=2019-12-23 00:23:42+00:00)
# Trade(tid=12993787, price=142100.00, amount=0.05000000, maker_side=sell, created_at=2019-12-23 00:23:54+00:00)
# Trade(tid=12993788, price=142100.00, amount=0.05000000, maker_side=sell, created_at=2019-12-23 00:23:57+00:00)
# Trade(tid=12993789, price=142100.00, amount=0.05000000, maker_side=sell, created_at=2019-12-23 00:24:00+00:00)
# Trade(tid=12993791, price=142100.00, amount=0.00351865, maker_side=sell, created_at=2019-12-23 00:24:26+00:00)
# Trade(tid=12993795, price=142096.94, amount=0.00035187, maker_side=sell, created_at=2019-12-23 00:25:03+00:00)
# Trade(tid=12993796, price=142096.94, amount=0.03521150, maker_side=sell, created_at=2019-12-23 00:25:05+00:00)
# Trade(tid=12993800, price=142100.00, amount=0.00010065, maker_side=sell, created_at=2019-12-23 00:25:13+00:00)
# Trade(tid=12993801, price=142097.07, amount=0.00495844, maker_side=buy, created_at=2019-12-23 00:25:16+00:00)
# Trade(tid=12993802, price=142097.12, amount=0.92882298, maker_side=buy, created_at=2019-12-23 00:25:23+00:00)
# Trade(tid=12993803, price=142097.11, amount=0.61438610, maker_side=buy, created_at=2019-12-23 00:25:23+00:00)
# Trade(tid=12993804, price=142097.07, amount=1.77632486, maker_side=buy, created_at=2019-12-23 00:25:23+00:00)
# Trade(tid=12993805, price=142050.00, amount=0.00100000, maker_side=sell, created_at=2019-12-23 00:25:23+00:00)
# Trade(tid=12993806, price=142049.99, amount=0.06166754, maker_side=sell, created_at=2019-12-23 00:25:24+00:00)
# Trade(tid=12993807, price=142050.00, amount=1.67946606, maker_side=sell, created_at=2019-12-23 00:25:24+00:00)
# Trade(tid=12993808, price=142100.00, amount=1.96270863, maker_side=sell, created_at=2019-12-23 00:25:27+00:00)
# Trade(tid=12993810, price=142101.69, amount=1.00000000, maker_side=buy, created_at=2019-12-23 00:26:10+00:00)
# Trade(tid=12993811, price=142100.00, amount=4.00000000, maker_side=buy, created_at=2019-12-23 00:26:10+00:00)
# Trade(tid=12993812, price=142200.00, amount=0.02109001, maker_side=sell, created_at=2019-12-23 00:26:13+00:00)
# Trade(tid=12993816, price=142200.00, amount=0.00566846, maker_side=sell, created_at=2019-12-23 00:26:24+00:00)
# Trade(tid=12993819, price=142200.00, amount=0.00007032, maker_side=sell, created_at=2019-12-23 00:26:45+00:00)
# Trade(tid=12993821, price=142200.00, amount=0.00008439, maker_side=sell, created_at=2019-12-23 00:26:54+00:00)
# Trade(tid=12993823, price=142200.00, amount=0.00007595, maker_side=sell, created_at=2019-12-23 00:27:28+00:00)
# Trade(tid=12993824, price=142100.01, amount=0.00807477, maker_side=buy, created_at=2019-12-23 00:27:34+00:00)
# Trade(tid=12993825, price=142100.00, amount=0.00708334, maker_side=buy, created_at=2019-12-23 00:27:50+00:00)
# Trade(tid=12993826, price=142100.00, amount=10.14233330, maker_side=buy, created_at=2019-12-23 00:28:14+00:00)
# Trade(tid=12993827, price=142099.99, amount=0.00110331, maker_side=sell, created_at=2019-12-23 00:28:23+00:00)
# Trade(tid=12993833, price=142099.99, amount=0.00559167, maker_side=sell, created_at=2019-12-23 00:29:21+00:00)
# Trade(tid=12993834, price=141999.99, amount=0.00610176, maker_side=sell, created_at=2019-12-23 00:29:43+00:00)
# Trade(tid=12993835, price=141999.99, amount=0.00433240, maker_side=sell, created_at=2019-12-23 00:29:55+00:00)
# Trade(tid=12993836, price=141999.99, amount=0.00140846, maker_side=sell, created_at=2019-12-23 00:30:24+00:00)
# Trade(tid=12993837, price=141999.99, amount=0.03125979, maker_side=sell, created_at=2019-12-23 00:30:37+00:00)
# 12994700
#
#
# Trade(tid=12994702, price=143024.41, amount=0.00810044, maker_side=sell, created_at=2019-12-23 02:47:46+00:00)
# Trade(tid=12994704, price=142400.00, amount=0.00295098, maker_side=buy, created_at=2019-12-23 02:48:10+00:00)
# Trade(tid=12994705, price=142343.00, amount=0.00280800, maker_side=buy, created_at=2019-12-23 02:48:10+00:00)
# Trade(tid=12994706, price=142300.02, amount=0.00070275, maker_side=buy, created_at=2019-12-23 02:48:10+00:00)
# Trade(tid=12994707, price=142300.00, amount=0.00823254, maker_side=buy, created_at=2019-12-23 02:48:10+00:00)
# Trade(tid=12994708, price=141936.51, amount=0.06330573, maker_side=buy, created_at=2019-12-23 02:48:10+00:00)
# Trade(tid=12994709, price=143024.25, amount=0.01508961, maker_side=sell, created_at=2019-12-23 02:48:20+00:00)
# Trade(tid=12994894, price=143410.75, amount=0.00294602, maker_side=sell, created_at=2019-12-23 03:17:31+00:00)
# Trade(tid=12994895, price=143410.75, amount=0.00310108, maker_side=sell, created_at=2019-12-23 03:17:31+00:00)
# Trade(tid=12994896, price=143410.76, amount=0.00476102, maker_side=sell, created_at=2019-12-23 03:17:31+00:00)
# Trade(tid=12994897, price=143410.76, amount=0.00029984, maker_side=sell, created_at=2019-12-23 03:17:32+00:00)
# Trade(tid=12994898, price=142481.52, amount=0.00022585, maker_side=buy, created_at=2019-12-23 03:17:51+00:00)
# Trade(tid=12994899, price=142481.79, amount=0.11449380, maker_side=buy, created_at=2019-12-23 03:17:57+00:00)
# Trade(tid=12994900, price=142481.79, amount=0.36495892, maker_side=buy, created_at=2019-12-23 03:17:57+00:00)
# Trade(tid=12994901, price=142481.78, amount=0.11449380, maker_side=buy, created_at=2019-12-23 03:17:57+00:00)
# Trade(tid=12994902, price=142481.77, amount=0.36495897, maker_side=buy, created_at=2019-12-23 03:17:57+00:00)
# Trade(tid=12994903, price=142481.76, amount=0.04109451, maker_side=buy, created_at=2019-12-23 03:17:57+00:00)
# Trade(tid=12994904, price=143410.07, amount=0.00440102, maker_side=sell, created_at=2019-12-23 03:18:49+00:00)
# Trade(tid=12994907, price=142530.18, amount=0.01031950, maker_side=buy, created_at=2019-12-23 03:21:31+00:00)
# Trade(tid=12994915, price=142566.71, amount=0.00264740, maker_side=buy, created_at=2019-12-23 03:23:19+00:00)
# 12995700
#
#
# Trade(tid=12995701, price=141000.00, amount=0.00288549, maker_side=buy, created_at=2019-12-23 06:37:09+00:00)
# Trade(tid=12995702, price=141000.00, amount=0.00794890, maker_side=buy, created_at=2019-12-23 06:38:48+00:00)
# Trade(tid=12995703, price=141000.35, amount=0.00076032, maker_side=sell, created_at=2019-12-23 06:39:09+00:00)
# Trade(tid=12995704, price=141233.52, amount=0.02260649, maker_side=sell, created_at=2019-12-23 06:39:09+00:00)
# Trade(tid=12995705, price=140999.88, amount=0.00009929, maker_side=sell, created_at=2019-12-23 06:39:16+00:00)
# Trade(tid=12995711, price=140999.00, amount=0.01000000, maker_side=buy, created_at=2019-12-23 06:41:42+00:00)
# Trade(tid=12995712, price=140700.00, amount=0.00639659, maker_side=buy, created_at=2019-12-23 06:42:17+00:00)
# Trade(tid=12995713, price=140629.67, amount=0.00017569, maker_side=buy, created_at=2019-12-23 06:42:17+00:00)
# Trade(tid=12995714, price=140000.05, amount=0.00142858, maker_side=buy, created_at=2019-12-23 06:42:17+00:00)
# Trade(tid=12995715, price=140000.00, amount=0.00857143, maker_side=buy, created_at=2019-12-23 06:42:17+00:00)
# Trade(tid=12995716, price=140000.00, amount=0.13081072, maker_side=buy, created_at=2019-12-23 06:42:17+00:00)
# Trade(tid=12995717, price=140000.00, amount=0.01697800, maker_side=buy, created_at=2019-12-23 06:42:17+00:00)
# Trade(tid=12995718, price=140000.00, amount=0.06428572, maker_side=buy, created_at=2019-12-23 06:42:17+00:00)
# Trade(tid=12995719, price=140000.00, amount=0.00428572, maker_side=buy, created_at=2019-12-23 06:42:17+00:00)
# Trade(tid=12995720, price=140000.00, amount=0.00285708, maker_side=buy, created_at=2019-12-23 06:42:17+00:00)
# Trade(tid=12995721, price=140000.00, amount=0.00071429, maker_side=buy, created_at=2019-12-23 06:42:17+00:00)
# Trade(tid=12995722, price=140000.00, amount=0.01428572, maker_side=buy, created_at=2019-12-23 06:42:17+00:00)
# Trade(tid=12995723, price=140000.00, amount=0.00714286, maker_side=buy, created_at=2019-12-23 06:42:17+00:00)
# Trade(tid=12995724, price=140000.00, amount=0.04214286, maker_side=buy, created_at=2019-12-23 06:42:17+00:00)
# Trade(tid=12995725, price=140000.00, amount=0.00071429, maker_side=buy, created_at=2019-12-23 06:42:17+00:00)
# Trade(tid=12995726, price=140000.00, amount=0.00040000, maker_side=buy, created_at=2019-12-23 06:42:17+00:00)
# Trade(tid=12995727, price=139810.76, amount=0.20314128, maker_side=buy, created_at=2019-12-23 06:42:17+00:00)
# Trade(tid=12995728, price=139810.76, amount=0.05978951, maker_side=sell, created_at=2019-12-23 06:42:17+00:00)
# Trade(tid=12995730, price=139900.00, amount=0.02699900, maker_side=sell, created_at=2019-12-23 06:42:19+00:00)
# Trade(tid=12995731, price=139900.00, amount=0.00049138, maker_side=sell, created_at=2019-12-23 06:42:26+00:00)
# Trade(tid=12995738, price=139914.78, amount=0.00314218, maker_side=buy, created_at=2019-12-23 06:44:20+00:00)
# Trade(tid=12995741, price=140985.96, amount=0.00993007, maker_side=sell, created_at=2019-12-23 06:45:16+00:00)
# Trade(tid=12995748, price=140980.72, amount=0.02837267, maker_side=sell, created_at=2019-12-23 06:47:28+00:00)
# Trade(tid=12995750, price=140000.30, amount=0.00145846, maker_side=buy, created_at=2019-12-23 06:48:16+00:00)
# Trade(tid=12995751, price=140000.30, amount=0.00397215, maker_side=buy, created_at=2019-12-23 06:48:32+00:00)
# Trade(tid=12995758, price=140000.55, amount=0.01178169, maker_side=buy, created_at=2019-12-23 06:53:09+00:00)
# Trade(tid=12995759, price=140000.55, amount=0.01437913, maker_side=buy, created_at=2019-12-23 06:53:14+00:00)
# Trade(tid=12995760, price=141195.07, amount=0.02408016, maker_side=sell, created_at=2019-12-23 06:53:23+00:00)
# Trade(tid=12995765, price=140000.68, amount=0.00440005, maker_side=buy, created_at=2019-12-23 06:54:40+00:00)
# Trade(tid=12995769, price=141011.19, amount=0.00153179, maker_side=sell, created_at=2019-12-23 06:55:31+00:00)
# Trade(tid=12995770, price=140000.00, amount=0.00021119, maker_side=buy, created_at=2019-12-23 06:56:25+00:00)
# Trade(tid=12995771, price=140000.00, amount=0.02121739, maker_side=buy, created_at=2019-12-23 06:57:00+00:00)
# Trade(tid=12995772, price=139666.05, amount=0.15239965, maker_side=buy, created_at=2019-12-23 06:57:20+00:00)
# Trade(tid=12995773, price=139666.05, amount=8.36587553, maker_side=sell, created_at=2019-12-23 06:57:20+00:00)
# Trade(tid=12995775, price=139666.05, amount=0.29359487, maker_side=buy, created_at=2019-12-23 06:57:43+00:00)
# Trade(tid=12995779, price=139999.93, amount=0.00283700, maker_side=sell, created_at=2019-12-23 06:58:01+00:00)
# Trade(tid=12995781, price=139999.93, amount=0.02622700, maker_side=sell, created_at=2019-12-23 06:58:02+00:00)
# Trade(tid=12995785, price=139999.96, amount=0.00199200, maker_side=sell, created_at=2019-12-23 06:58:03+00:00)
# Trade(tid=12995791, price=139899.99, amount=0.00017900, maker_side=sell, created_at=2019-12-23 06:59:00+00:00)
# Trade(tid=12995792, price=139900.00, amount=0.01411693, maker_side=sell, created_at=2019-12-23 06:59:00+00:00)
# Trade(tid=12995795, price=139666.05, amount=0.00229309, maker_side=buy, created_at=2019-12-23 06:59:24+00:00)
# Trade(tid=12995802, price=140000.00, amount=0.00018665, maker_side=sell, created_at=2019-12-23 07:01:37+00:00)
# Trade(tid=12995803, price=140299.95, amount=0.00123927, maker_side=sell, created_at=2019-12-23 07:01:37+00:00)
# Trade(tid=12995804, price=140200.01, amount=0.02139800, maker_side=sell, created_at=2019-12-23 07:02:30+00:00)
# Trade(tid=12995806, price=139781.94, amount=0.00011561, maker_side=buy, created_at=2019-12-23 07:02:40+00:00)
# Trade(tid=12995807, price=140200.01, amount=0.00386117, maker_side=sell, created_at=2019-12-23 07:03:35+00:00)
# Trade(tid=12995808, price=139784.73, amount=0.00131775, maker_side=buy, created_at=2019-12-23 07:03:45+00:00)
# Trade(tid=12995809, price=139785.07, amount=0.00701784, maker_side=buy, created_at=2019-12-23 07:03:52+00:00)
# Trade(tid=12995810, price=140200.01, amount=0.01070327, maker_side=sell, created_at=2019-12-23 07:04:15+00:00)
# Trade(tid=12995811, price=141209.78, amount=0.01522134, maker_side=sell, created_at=2019-12-23 07:04:15+00:00)
# Trade(tid=12995815, price=139787.41, amount=0.12032744, maker_side=buy, created_at=2019-12-23 07:04:49+00:00)
# Trade(tid=12995817, price=141114.84, amount=0.00063778, maker_side=sell, created_at=2019-12-23 07:05:58+00:00)
# Trade(tid=12995818, price=140499.97, amount=0.16376772, maker_side=sell, created_at=2019-12-23 07:07:23+00:00)
# Trade(tid=12995819, price=140499.95, amount=0.01110000, maker_side=sell, created_at=2019-12-23 07:07:25+00:00)
# Trade(tid=12995820, price=140303.00, amount=0.00284600, maker_side=buy, created_at=2019-12-23 07:09:21+00:00)
# Trade(tid=12995821, price=139789.41, amount=0.05274000, maker_side=buy, created_at=2019-12-23 07:10:49+00:00)
# Trade(tid=12995822, price=139789.47, amount=0.00035769, maker_side=buy, created_at=2019-12-23 07:11:53+00:00)
# Trade(tid=12995823, price=139789.47, amount=0.03482310, maker_side=buy, created_at=2019-12-23 07:12:19+00:00)
# Trade(tid=12995827, price=139789.82, amount=0.00383607, maker_side=buy, created_at=2019-12-23 07:15:09+00:00)
# Trade(tid=12995828, price=140499.93, amount=0.01886122, maker_side=sell, created_at=2019-12-23 07:16:24+00:00)
# Trade(tid=12995829, price=139792.47, amount=0.00007869, maker_side=buy, created_at=2019-12-23 07:17:29+00:00)
# Trade(tid=12995832, price=140499.77, amount=0.07117449, maker_side=sell, created_at=2019-12-23 07:19:10+00:00)
# Trade(tid=12995833, price=139796.44, amount=0.04111439, maker_side=buy, created_at=2019-12-23 07:20:35+00:00)
# Trade(tid=12995834, price=139797.14, amount=0.00066871, maker_side=buy, created_at=2019-12-23 07:21:19+00:00)
# Trade(tid=12995836, price=141138.48, amount=0.00163258, maker_side=sell, created_at=2019-12-23 07:22:07+00:00)
# Trade(tid=12995837, price=141138.10, amount=0.00003543, maker_side=sell, created_at=2019-12-23 07:23:02+00:00)
# Trade(tid=12995838, price=139799.73, amount=0.00720000, maker_side=buy, created_at=2019-12-23 07:23:45+00:00)
# Trade(tid=12995839, price=141137.74, amount=0.02550700, maker_side=sell, created_at=2019-12-23 07:23:53+00:00)
# Trade(tid=12995841, price=141137.62, amount=0.02125585, maker_side=sell, created_at=2019-12-23 07:24:16+00:00)
# Trade(tid=12995842, price=141136.36, amount=0.03542673, maker_side=sell, created_at=2019-12-23 07:27:21+00:00)
# Trade(tid=12995848, price=140149.72, amount=0.02191196, maker_side=buy, created_at=2019-12-23 07:36:32+00:00)
# Trade(tid=12995849, price=140149.86, amount=0.00079387, maker_side=buy, created_at=2019-12-23 07:36:39+00:00)
# Trade(tid=12995852, price=140211.92, amount=0.01142339, maker_side=buy, created_at=2019-12-23 07:40:58+00:00)
# Trade(tid=12995856, price=140027.00, amount=0.00718821, maker_side=buy, created_at=2019-12-23 07:46:34+00:00)
# Trade(tid=12995860, price=141389.44, amount=0.14145328, maker_side=sell, created_at=2019-12-23 07:49:17+00:00)
# Trade(tid=12995861, price=141389.30, amount=0.10489728, maker_side=sell, created_at=2019-12-23 07:49:47+00:00)
# Trade(tid=12995862, price=141389.31, amount=0.12508619, maker_side=sell, created_at=2019-12-23 07:49:47+00:00)
# Trade(tid=12995863, price=141389.32, amount=0.16330207, maker_side=sell, created_at=2019-12-23 07:49:47+00:00)
# Trade(tid=12995864, price=141389.32, amount=0.17189692, maker_side=sell, created_at=2019-12-23 07:49:47+00:00)
# Trade(tid=12995865, price=141589.65, amount=0.53664424, maker_side=sell, created_at=2019-12-23 07:49:47+00:00)
# Trade(tid=12995866, price=140126.76, amount=0.06453544, maker_side=buy, created_at=2019-12-23 07:50:13+00:00)
# Trade(tid=12995867, price=141388.99, amount=0.05785348, maker_side=sell, created_at=2019-12-23 07:51:05+00:00)
# Trade(tid=12995868, price=141388.99, amount=0.06089840, maker_side=sell, created_at=2019-12-23 07:51:05+00:00)
# Trade(tid=12995869, price=141389.00, amount=0.59523521, maker_side=sell, created_at=2019-12-23 07:51:05+00:00)
# Trade(tid=12995873, price=140171.32, amount=0.06053417, maker_side=buy, created_at=2019-12-23 07:52:10+00:00)
# Trade(tid=12995874, price=141388.49, amount=0.00495090, maker_side=sell, created_at=2019-12-23 07:52:58+00:00)
# Trade(tid=12995885, price=140271.49, amount=0.00008734, maker_side=buy, created_at=2019-12-23 07:58:10+00:00)
# Trade(tid=12995887, price=141506.59, amount=0.00967125, maker_side=sell, created_at=2019-12-23 07:59:46+00:00)
# Trade(tid=12995888, price=141506.59, amount=0.01018026, maker_side=sell, created_at=2019-12-23 07:59:46+00:00)
# Trade(tid=12995889, price=141506.60, amount=0.22230334, maker_side=sell, created_at=2019-12-23 07:59:46+00:00)
# Trade(tid=12995892, price=140183.90, amount=0.00032487, maker_side=buy, created_at=2019-12-23 08:01:25+00:00)
# Trade(tid=12995893, price=140192.01, amount=0.00026283, maker_side=buy, created_at=2019-12-23 08:03:35+00:00)
# Trade(tid=12995894, price=141314.58, amount=0.02689036, maker_side=sell, created_at=2019-12-23 08:04:32+00:00)
# Trade(tid=12995898, price=139989.20, amount=0.01078522, maker_side=buy, created_at=2019-12-23 08:05:50+00:00)
# Trade(tid=12995899, price=139989.22, amount=0.14301218, maker_side=sell, created_at=2019-12-23 08:05:50+00:00)
# 12996700
#
#
# Trade(tid=12996701, price=142512.00, amount=0.00801643, maker_side=buy, created_at=2019-12-23 13:59:23+00:00)
# Trade(tid=12996703, price=142512.00, amount=0.02706834, maker_side=buy, created_at=2019-12-23 13:59:31+00:00)
# Trade(tid=12996704, price=142214.64, amount=0.00589299, maker_side=buy, created_at=2019-12-23 13:59:31+00:00)
# Trade(tid=12996706, price=143044.24, amount=0.00174771, maker_side=sell, created_at=2019-12-23 13:59:42+00:00)
# Trade(tid=12996707, price=142212.00, amount=0.00007078, maker_side=buy, created_at=2019-12-23 14:00:37+00:00)
# Trade(tid=12996708, price=142486.67, amount=0.00178006, maker_side=sell, created_at=2019-12-23 14:00:47+00:00)
# Trade(tid=12996709, price=142486.68, amount=1.47722135, maker_side=sell, created_at=2019-12-23 14:00:47+00:00)
# Trade(tid=12996710, price=142478.27, amount=0.00070186, maker_side=sell, created_at=2019-12-23 14:00:48+00:00)
# Trade(tid=12996711, price=142212.00, amount=0.07024678, maker_side=buy, created_at=2019-12-23 14:00:54+00:00)
# Trade(tid=12996712, price=142158.00, amount=0.00281200, maker_side=buy, created_at=2019-12-23 14:00:54+00:00)
# Trade(tid=12996713, price=142145.83, amount=0.00180170, maker_side=buy, created_at=2019-12-23 14:00:54+00:00)
# Trade(tid=12996714, price=142145.83, amount=0.00588871, maker_side=buy, created_at=2019-12-23 14:01:23+00:00)
# Trade(tid=12996715, price=142100.00, amount=0.00010556, maker_side=buy, created_at=2019-12-23 14:01:23+00:00)
# Trade(tid=12996716, price=142012.00, amount=0.00552573, maker_side=buy, created_at=2019-12-23 14:01:23+00:00)
# Trade(tid=12996717, price=142412.18, amount=0.00388629, maker_side=sell, created_at=2019-12-23 14:01:47+00:00)
# Trade(tid=12996718, price=142412.21, amount=0.00105024, maker_side=sell, created_at=2019-12-23 14:01:47+00:00)
# Trade(tid=12996719, price=142412.22, amount=0.65545160, maker_side=sell, created_at=2019-12-23 14:01:47+00:00)
# Trade(tid=12996720, price=142418.31, amount=0.04195493, maker_side=sell, created_at=2019-12-23 14:01:47+00:00)
# Trade(tid=12996722, price=142408.61, amount=0.00712878, maker_side=buy, created_at=2019-12-23 14:02:38+00:00)
# Trade(tid=12996724, price=142734.47, amount=0.00666223, maker_side=sell, created_at=2019-12-23 14:03:34+00:00)
# Trade(tid=12996725, price=142734.52, amount=0.00061964, maker_side=sell, created_at=2019-12-23 14:03:34+00:00)
# Trade(tid=12996726, price=142734.52, amount=0.00058866, maker_side=sell, created_at=2019-12-23 14:03:34+00:00)
# Trade(tid=12996727, price=142734.53, amount=0.13223876, maker_side=sell, created_at=2019-12-23 14:03:34+00:00)
# Trade(tid=12996728, price=142408.61, amount=0.00737886, maker_side=buy, created_at=2019-12-23 14:03:51+00:00)
# Trade(tid=12996730, price=142408.61, amount=0.00077748, maker_side=buy, created_at=2019-12-23 14:04:43+00:00)
# Trade(tid=12996738, price=142500.00, amount=0.00182457, maker_side=buy, created_at=2019-12-23 14:06:09+00:00)
# Trade(tid=12996739, price=142408.62, amount=0.02689646, maker_side=buy, created_at=2019-12-23 14:06:09+00:00)
# Trade(tid=12996740, price=142906.60, amount=0.00069976, maker_side=sell, created_at=2019-12-23 14:06:27+00:00)
# Trade(tid=12996741, price=142408.62, amount=0.00043398, maker_side=buy, created_at=2019-12-23 14:06:31+00:00)
# Trade(tid=12996743, price=142500.01, amount=0.03264547, maker_side=buy, created_at=2019-12-23 14:06:50+00:00)
# Trade(tid=12996751, price=142500.01, amount=0.00604146, maker_side=buy, created_at=2019-12-23 14:07:49+00:00)
# Trade(tid=12996752, price=142825.56, amount=0.07405250, maker_side=sell, created_at=2019-12-23 14:08:26+00:00)
# Trade(tid=12996753, price=142825.50, amount=0.00455880, maker_side=sell, created_at=2019-12-23 14:08:31+00:00)
# ...
# Trade(tid=13060736, price=135000.00, amount=0.00100000, maker_side=sell, created_at=2020-01-02 04:06:56+00:00)
# Trade(tid=13060737, price=134667.74, amount=0.01856421, maker_side=sell, created_at=2020-01-02 04:07:05+00:00)
# Trade(tid=13060738, price=134667.77, amount=0.00074743, maker_side=buy, created_at=2020-01-02 04:07:45+00:00)
# Trade(tid=13060740, price=135000.00, amount=0.00569363, maker_side=sell, created_at=2020-01-02 04:09:29+00:00)
# Trade(tid=13060742, price=135000.00, amount=0.00011111, maker_side=sell, created_at=2020-01-02 04:10:40+00:00)
# Trade(tid=13060743, price=134668.03, amount=0.00800000, maker_side=buy, created_at=2020-01-02 04:10:51+00:00)
# Trade(tid=13060744, price=135000.00, amount=0.02543803, maker_side=sell, created_at=2020-01-02 04:11:23+00:00)
# Trade(tid=13060745, price=135299.99, amount=0.03214435, maker_side=sell, created_at=2020-01-02 04:11:23+00:00)
# Trade(tid=13060746, price=135299.99, amount=0.00899287, maker_side=sell, created_at=2020-01-02 04:11:23+00:00)
# Trade(tid=13060752, price=134669.70, amount=0.01000000, maker_side=buy, created_at=2020-01-02 04:15:01+00:00)
# Trade(tid=13060759, price=135299.98, amount=0.00107169, maker_side=sell, created_at=2020-01-02 04:16:22+00:00)
# Trade(tid=13060762, price=135299.98, amount=0.00739098, maker_side=sell, created_at=2020-01-02 04:20:25+00:00)
# Trade(tid=13060765, price=135299.98, amount=0.00107908, maker_side=sell, created_at=2020-01-02 04:21:20+00:00)
# Trade(tid=13060767, price=134714.06, amount=0.00043670, maker_side=buy, created_at=2020-01-02 04:21:30+00:00)
# Trade(tid=13060769, price=135299.98, amount=0.00332594, maker_side=sell, created_at=2020-01-02 04:22:10+00:00)
# Trade(tid=13060773, price=135299.98, amount=0.00073910, maker_side=sell, created_at=2020-01-02 04:25:43+00:00)
# Trade(tid=13060780, price=135299.98, amount=0.00010000, maker_side=sell, created_at=2020-01-02 04:27:38+00:00)
# Trade(tid=13060781, price=135299.98, amount=0.00107517, maker_side=sell, created_at=2020-01-02 04:27:58+00:00)
# Trade(tid=13060782, price=135500.00, amount=0.00040243, maker_side=sell, created_at=2020-01-02 04:27:58+00:00)
# 13060700
#
#
# Trade(tid=13060701, price=134667.64, amount=0.00063427, maker_side=buy, created_at=2020-01-02 03:56:38+00:00)
# Trade(tid=13060702, price=134667.65, amount=0.00063412, maker_side=sell, created_at=2020-01-02 03:56:38+00:00)
# Trade(tid=13060703, price=134667.65, amount=0.00043065, maker_side=buy, created_at=2020-01-02 03:56:38+00:00)
# Trade(tid=13060704, price=134667.64, amount=0.00031713, maker_side=buy, created_at=2020-01-02 03:56:41+00:00)
# Trade(tid=13060705, price=134667.67, amount=0.00021532, maker_side=buy, created_at=2020-01-02 03:56:44+00:00)
# Trade(tid=13060706, price=135266.83, amount=0.00147856, maker_side=sell, created_at=2020-01-02 03:56:48+00:00)
# Trade(tid=13060707, price=134667.64, amount=0.00055318, maker_side=buy, created_at=2020-01-02 03:57:24+00:00)
# Trade(tid=13060708, price=134667.64, amount=0.00027659, maker_side=buy, created_at=2020-01-02 03:57:26+00:00)
# Trade(tid=13060709, price=134667.65, amount=0.00028487, maker_side=buy, created_at=2020-01-02 03:57:29+00:00)
# Trade(tid=13060710, price=134667.66, amount=0.00013830, maker_side=buy, created_at=2020-01-02 03:57:30+00:00)
# Trade(tid=13060711, price=134667.65, amount=0.00013830, maker_side=buy, created_at=2020-01-02 03:57:30+00:00)
# Trade(tid=13060713, price=134667.64, amount=0.01051253, maker_side=buy, created_at=2020-01-02 03:58:16+00:00)
# Trade(tid=13060714, price=135264.51, amount=0.00221788, maker_side=sell, created_at=2020-01-02 03:59:03+00:00)
# Trade(tid=13060715, price=134667.64, amount=0.00017191, maker_side=buy, created_at=2020-01-02 04:01:51+00:00)
# Trade(tid=13060716, price=135000.00, amount=0.00370370, maker_side=sell, created_at=2020-01-02 04:01:56+00:00)
# Trade(tid=13060719, price=134999.56, amount=0.00152250, maker_side=sell, created_at=2020-01-02 04:02:34+00:00)
# Trade(tid=13060733, price=135000.00, amount=0.00175393, maker_side=sell, created_at=2020-01-02 04:06:31+00:00)
# Trade(tid=13060736, price=135000.00, amount=0.00100000, maker_side=sell, created_at=2020-01-02 04:06:56+00:00)
# Trade(tid=13060737, price=134667.74, amount=0.01856421, maker_side=sell, created_at=2020-01-02 04:07:05+00:00)
# Trade(tid=13060738, price=134667.77, amount=0.00074743, maker_side=buy, created_at=2020-01-02 04:07:45+00:00)
# Trade(tid=13060740, price=135000.00, amount=0.00569363, maker_side=sell, created_at=2020-01-02 04:09:29+00:00)
# Trade(tid=13060742, price=135000.00, amount=0.00011111, maker_side=sell, created_at=2020-01-02 04:10:40+00:00)
# Trade(tid=13060743, price=134668.03, amount=0.00800000, maker_side=buy, created_at=2020-01-02 04:10:51+00:00)
# Trade(tid=13060744, price=135000.00, amount=0.02543803, maker_side=sell, created_at=2020-01-02 04:11:23+00:00)
# Trade(tid=13060745, price=135299.99, amount=0.03214435, maker_side=sell, created_at=2020-01-02 04:11:23+00:00)
# Trade(tid=13060746, price=135299.99, amount=0.00899287, maker_side=sell, created_at=2020-01-02 04:11:23+00:00)
# Trade(tid=13060752, price=134669.70, amount=0.01000000, maker_side=buy, created_at=2020-01-02 04:15:01+00:00)
# Trade(tid=13060759, price=135299.98, amount=0.00107169, maker_side=sell, created_at=2020-01-02 04:16:22+00:00)
# Trade(tid=13060762, price=135299.98, amount=0.00739098, maker_side=sell, created_at=2020-01-02 04:20:25+00:00)
# Trade(tid=13060765, price=135299.98, amount=0.00107908, maker_side=sell, created_at=2020-01-02 04:21:20+00:00)
# Trade(tid=13060767, price=134714.06, amount=0.00043670, maker_side=buy, created_at=2020-01-02 04:21:30+00:00)
# Trade(tid=13060769, price=135299.98, amount=0.00332594, maker_side=sell, created_at=2020-01-02 04:22:10+00:00)
# Trade(tid=13060773, price=135299.98, amount=0.00073910, maker_side=sell, created_at=2020-01-02 04:25:43+00:00)
# Trade(tid=13060780, price=135299.98, amount=0.00010000, maker_side=sell, created_at=2020-01-02 04:27:38+00:00)
# Trade(tid=13060781, price=135299.98, amount=0.00107517, maker_side=sell, created_at=2020-01-02 04:27:58+00:00)
# Trade(tid=13060782, price=135500.00, amount=0.00040243, maker_side=sell, created_at=2020-01-02 04:27:58+00:00)
# 13060700
#
#
# Trade(tid=13060701, price=134667.64, amount=0.00063427, maker_side=buy, created_at=2020-01-02 03:56:38+00:00)
# Trade(tid=13060702, price=134667.65, amount=0.00063412, maker_side=sell, created_at=2020-01-02 03:56:38+00:00)
# Trade(tid=13060703, price=134667.65, amount=0.00043065, maker_side=buy, created_at=2020-01-02 03:56:38+00:00)
# Trade(tid=13060704, price=134667.64, amount=0.00031713, maker_side=buy, created_at=2020-01-02 03:56:41+00:00)
# Trade(tid=13060705, price=134667.67, amount=0.00021532, maker_side=buy, created_at=2020-01-02 03:56:44+00:00)
# Trade(tid=13060706, price=135266.83, amount=0.00147856, maker_side=sell, created_at=2020-01-02 03:56:48+00:00)
# Trade(tid=13060707, price=134667.64, amount=0.00055318, maker_side=buy, created_at=2020-01-02 03:57:24+00:00)
# Trade(tid=13060708, price=134667.64, amount=0.00027659, maker_side=buy, created_at=2020-01-02 03:57:26+00:00)
# Trade(tid=13060709, price=134667.65, amount=0.00028487, maker_side=buy, created_at=2020-01-02 03:57:29+00:00)
# Trade(tid=13060710, price=134667.66, amount=0.00013830, maker_side=buy, created_at=2020-01-02 03:57:30+00:00)
# Trade(tid=13060711, price=134667.65, amount=0.00013830, maker_side=buy, created_at=2020-01-02 03:57:30+00:00)
# Trade(tid=13060713, price=134667.64, amount=0.01051253, maker_side=buy, created_at=2020-01-02 03:58:16+00:00)
# Trade(tid=13060714, price=135264.51, amount=0.00221788, maker_side=sell, created_at=2020-01-02 03:59:03+00:00)
# Trade(tid=13060715, price=134667.64, amount=0.00017191, maker_side=buy, created_at=2020-01-02 04:01:51+00:00)
# Trade(tid=13060716, price=135000.00, amount=0.00370370, maker_side=sell, created_at=2020-01-02 04:01:56+00:00)
# Trade(tid=13060719, price=134999.56, amount=0.00152250, maker_side=sell, created_at=2020-01-02 04:02:34+00:00)
# Trade(tid=13060733, price=135000.00, amount=0.00175393, maker_side=sell, created_at=2020-01-02 04:06:31+00:00)
# Trade(tid=13060736, price=135000.00, amount=0.00100000, maker_side=sell, created_at=2020-01-02 04:06:56+00:00)
# Trade(tid=13060737, price=134667.74, amount=0.01856421, maker_side=sell, created_at=2020-01-02 04:07:05+00:00)
# Trade(tid=13060738, price=134667.77, amount=0.00074743, maker_side=buy, created_at=2020-01-02 04:07:45+00:00)
# Trade(tid=13060740, price=135000.00, amount=0.00569363, maker_side=sell, created_at=2020-01-02 04:09:29+00:00)
# Trade(tid=13060742, price=135000.00, amount=0.00011111, maker_side=sell, created_at=2020-01-02 04:10:40+00:00)
# Trade(tid=13060743, price=134668.03, amount=0.00800000, maker_side=buy, created_at=2020-01-02 04:10:51+00:00)
# Trade(tid=13060744, price=135000.00, amount=0.02543803, maker_side=sell, created_at=2020-01-02 04:11:23+00:00)
# Trade(tid=13060745, price=135299.99, amount=0.03214435, maker_side=sell, created_at=2020-01-02 04:11:23+00:00)
# Trade(tid=13060746, price=135299.99, amount=0.00899287, maker_side=sell, created_at=2020-01-02 04:11:23+00:00)
# Trade(tid=13060752, price=134669.70, amount=0.01000000, maker_side=buy, created_at=2020-01-02 04:15:01+00:00)
# Trade(tid=13060759, price=135299.98, amount=0.00107169, maker_side=sell, created_at=2020-01-02 04:16:22+00:00)
# Trade(tid=13060762, price=135299.98, amount=0.00739098, maker_side=sell, created_at=2020-01-02 04:20:25+00:00)
# Trade(tid=13060765, price=135299.98, amount=0.00107908, maker_side=sell, created_at=2020-01-02 04:21:20+00:00)
# Trade(tid=13060767, price=134714.06, amount=0.00043670, maker_side=buy, created_at=2020-01-02 04:21:30+00:00)
# Trade(tid=13060769, price=135299.98, amount=0.00332594, maker_side=sell, created_at=2020-01-02 04:22:10+00:00)
# Trade(tid=13060773, price=135299.98, amount=0.00073910, maker_side=sell, created_at=2020-01-02 04:25:43+00:00)
# Trade(tid=13060780, price=135299.98, amount=0.00010000, maker_side=sell, created_at=2020-01-02 04:27:38+00:00)
# Trade(tid=13060781, price=135299.98, amount=0.00107517, maker_side=sell, created_at=2020-01-02 04:27:58+00:00)
# Trade(tid=13060782, price=135500.00, amount=0.00040243, maker_side=sell, created_at=2020-01-02 04:27:58+00:00)
# 13060700
#
#
# Trade(tid=13060701, price=134667.64, amount=0.00063427, maker_side=buy, created_at=2020-01-02 03:56:38+00:00)
# Trade(tid=13060702, price=134667.65, amount=0.00063412, maker_side=sell, created_at=2020-01-02 03:56:38+00:00)
# Trade(tid=13060703, price=134667.65, amount=0.00043065, maker_side=buy, created_at=2020-01-02 03:56:38+00:00)
# Trade(tid=13060704, price=134667.64, amount=0.00031713, maker_side=buy, created_at=2020-01-02 03:56:41+00:00)
# Trade(tid=13060705, price=134667.67, amount=0.00021532, maker_side=buy, created_at=2020-01-02 03:56:44+00:00)
# Trade(tid=13060706, price=135266.83, amount=0.00147856, maker_side=sell, created_at=2020-01-02 03:56:48+00:00)
# Trade(tid=13060707, price=134667.64, amount=0.00055318, maker_side=buy, created_at=2020-01-02 03:57:24+00:00)
# Trade(tid=13060708, price=134667.64, amount=0.00027659, maker_side=buy, created_at=2020-01-02 03:57:26+00:00)
# Trade(tid=13060709, price=134667.65, amount=0.00028487, maker_side=buy, created_at=2020-01-02 03:57:29+00:00)
# Trade(tid=13060710, price=134667.66, amount=0.00013830, maker_side=buy, created_at=2020-01-02 03:57:30+00:00)
# Trade(tid=13060711, price=134667.65, amount=0.00013830, maker_side=buy, created_at=2020-01-02 03:57:30+00:00)
# Trade(tid=13060713, price=134667.64, amount=0.01051253, maker_side=buy, created_at=2020-01-02 03:58:16+00:00)
# Trade(tid=13060714, price=135264.51, amount=0.00221788, maker_side=sell, created_at=2020-01-02 03:59:03+00:00)
# Trade(tid=13060715, price=134667.64, amount=0.00017191, maker_side=buy, created_at=2020-01-02 04:01:51+00:00)
# Trade(tid=13060716, price=135000.00, amount=0.00370370, maker_side=sell, created_at=2020-01-02 04:01:56+00:00)
# Trade(tid=13060719, price=134999.56, amount=0.00152250, maker_side=sell, created_at=2020-01-02 04:02:34+00:00)
# Trade(tid=13060733, price=135000.00, amount=0.00175393, maker_side=sell, created_at=2020-01-02 04:06:31+00:00)
# Trade(tid=13060736, price=135000.00, amount=0.00100000, maker_side=sell, created_at=2020-01-02 04:06:56+00:00)
# Trade(tid=13060737, price=134667.74, amount=0.01856421, maker_side=sell, created_at=2020-01-02 04:07:05+00:00)
# Trade(tid=13060738, price=134667.77, amount=0.00074743, maker_side=buy, created_at=2020-01-02 04:07:45+00:00)
# Trade(tid=13060740, price=135000.00, amount=0.00569363, maker_side=sell, created_at=2020-01-02 04:09:29+00:00)
# Trade(tid=13060742, price=135000.00, amount=0.00011111, maker_side=sell, created_at=2020-01-02 04:10:40+00:00)
# Trade(tid=13060743, price=134668.03, amount=0.00800000, maker_side=buy, created_at=2020-01-02 04:10:51+00:00)
# Trade(tid=13060744, price=135000.00, amount=0.02543803, maker_side=sell, created_at=2020-01-02 04:11:23+00:00)
# Trade(tid=13060745, price=135299.99, amount=0.03214435, maker_side=sell, created_at=2020-01-02 04:11:23+00:00)
# Trade(tid=13060746, price=135299.99, amount=0.00899287, maker_side=sell, created_at=2020-01-02 04:11:23+00:00)
# Trade(tid=13060752, price=134669.70, amount=0.01000000, maker_side=buy, created_at=2020-01-02 04:15:01+00:00)
# Trade(tid=13060759, price=135299.98, amount=0.00107169, maker_side=sell, created_at=2020-01-02 04:16:22+00:00)
# Trade(tid=13060762, price=135299.98, amount=0.00739098, maker_side=sell, created_at=2020-01-02 04:20:25+00:00)
# Trade(tid=13060765, price=135299.98, amount=0.00107908, maker_side=sell, created_at=2020-01-02 04:21:20+00:00)
# Trade(tid=13060767, price=134714.06, amount=0.00043670, maker_side=buy, created_at=2020-01-02 04:21:30+00:00)
# Trade(tid=13060769, price=135299.98, amount=0.00332594, maker_side=sell, created_at=2020-01-02 04:22:10+00:00)
# Trade(tid=13060773, price=135299.98, amount=0.00073910, maker_side=sell, created_at=2020-01-02 04:25:43+00:00)
# Trade(tid=13060780, price=135299.98, amount=0.00010000, maker_side=sell, created_at=2020-01-02 04:27:38+00:00)
# Trade(tid=13060781, price=135299.98, amount=0.00107517, maker_side=sell, created_at=2020-01-02 04:27:58+00:00)
# Trade(tid=13060782, price=135500.00, amount=0.00040243, maker_side=sell, created_at=2020-01-02 04:27:58+00:00)
# ---------------------------------------------------------------------------
# ApiError                                  Traceback (most recent call last)
# <ipython-input-3-1df1e302f1b5> in <module>
#      21     limit = '100'
#      22     #Calling the api trades, we use sort 'asc' so i't starts on the marker we want.
# ---> 23     trades = api.trades('btc_mxn', sort='asc', limit=limit, marker=mark)
#      24     #Starting the counter so we don't raise the error of too many requests on the api.
#      25     count = 0
#
# ~/Desktop/DataAnalytics/proyectos/proyectos/lib/python3.7/site-packages/bitso/api.py in trades(self, book, **kwargs)
#     184         if 'sort' in kwargs:
#     185             parameters['sort'] = kwargs['sort']
# --> 186         resp = self._request_url(url, 'GET', params=parameters)
#     187         return [Trade._NewFromJsonDict(x) for x in resp['payload']]
#     188
#
# ~/Desktop/DataAnalytics/proyectos/proyectos/lib/python3.7/site-packages/bitso/api.py in _request_url(self, url, verb, params, private)
#     945
#     946         content = resp.content
# --> 947         data = self._parse_json(content if isinstance(content, basestring) else content.decode('utf-8'))
#     948         return data
#     949
#
# ~/Desktop/DataAnalytics/proyectos/proyectos/lib/python3.7/site-packages/bitso/api.py in _parse_json(self, json_data)
#     973         try:
#     974             data = json.loads(json_data)
# --> 975             self._check_for_api_error(data)
#     976         except:
#     977             raise
#
# ~/Desktop/DataAnalytics/proyectos/proyectos/lib/python3.7/site-packages/bitso/api.py in _check_for_api_error(self, data)
#     980     def _check_for_api_error(self, data):
#     981         if data['success'] != True:
# --> 982             raise ApiError(data['error'])
#     983         if 'error' in data:
#     984             raise ApiError(data['error'])
#
# ApiError: {'code': 200, 'message': 'Demasiadas solicitudes.'}

# %%
# creating a new data frame.
df = pd.DataFrame(columns=['price', 'volume', 'hour', 'date', 'side'])
# using the lists we got from the while loop to fill the dataframe.
df.price = btc_mxn_price
df.volume = btc_mxn_volume
df.hour = btc_mxn_hour
df.date = btc_mxn_date
df.side = btc_mxn_side
df.date = df.date.astype('datetime64')
#creating new columns with the month and day of each row.
df['month'] = [i.month for i in df.date]
df['day'] = [i.day for i in df.date]

# %%
#Creating a function that needs a data frame and a number(month) for input.
def extraction(df, m):
    #variable that get's just the row that matches the same month
    f_df = df.loc[df['month'] == m]
    #variable that stores the year
    y = datetime.datetime.today().year
    #variable that creates a list with the numbers of days of the month
    days = list(f_df['day'].unique())
    #varible that creates a empty dictionary
    results = {}
    #list with the names of the keys in the dictionary that the function returns.
    nombres = ['date', '24h_avg', '12h_avg', 'min', 'max', 'volume', 'm_side']
    
    #for loop that creates new keys in the empty dictionary with a empty list as values.
    for i in nombres:
        results[i] = []
    
    #for that loops on each day in the list of the days of the month.
    for e in days:
        #variable that get's just the rows that match the day in the for loop.
        ndf = f_df.loc[f_df.day == e]
        #appending the results in each dictionary key.
        results['date'].append(datetime.date(y, m, e))
        results['24h_avg'].append(ndf.price.mean())
        results['12h_avg'].append(ndf.price.loc[ndf.hour<12].mean())
        results['max'].append(ndf.price.max())
        results['min'].append(ndf.price.min())
        results['volume'].append(ndf.volume.sum())
        weight = ndf.side.value_counts().sum()
        buy = ndf.side.value_counts()['buy']/weight
        sell = ndf.side.value_counts()['sell']/weight
        if buy>sell:
            results['m_side'].append('buy')
        else:
            results['m_side'].append('sell')
            
    #returns the dictionary with the appended elements
    return results

# %%
#creating a variable that stores the month we are in.
month = datetime.datetime.today().month
#creating a new data frame using the dictionary from the above function and the month
df_new = pd.DataFrame.from_dict(extraction(df, month))

# %%
#Reading our csv file where we store the past data
history = pd.read_csv('../csv_files/historic_data.csv')

# %%
btc_df = pd.concat([history, df_new], ignore_index=True)

# %%
btc_df.drop_duplicates(inplace=True)

# %%
btc_df.drop(btc_df.tail(1).index,inplace=True)

# %%
btc_df.to_csv('../csv_files/historic_data.csv', index=False)

# %%
btc_df.date = btc_df.date.astype('datetime64')
btc_df['min'] = btc_df['min'].astype('float')
btc_df['max'] = btc_df['max'].astype('float')
btc_df.volume = btc_df.volume.astype('float')
btc_df['m_side'] = btc_df['m_side'].astype('category')

# %%
df_dum = pd.get_dummies(btc_df)
df_dum.rename(columns={'m_side_buy':'buy', 'm_side_sell':'sell'}, inplace=True)

# %%
change = []
for i in range(1,len(df_dum)):
    if df_dum.sell.iloc[i] != df_dum.sell.iloc[i-1]:
        change.append(df_dum.date.iloc[i])

# %%
#Selecting the columns we need for fbprophet
btc_24h_avg = btc_df[['date', '24h_avg']].copy()
#Changing the columns names for fbprophet to accept it.
btc_24h_avg.rename(columns={'date': 'ds', '24h_avg': 'y'}, inplace=True)

# %%
def inverse_boxcox(y, lambda_):
    return np.exp(y) if lambda_ == 0 else np.exp(np.log(lambda_ * y + 1) / lambda_)

# %%
def make_comparison_dataframe(historical, forecast):
    """Join the history with the forecast.
    
       The resulting dataset will contain columns 'yhat', 'yhat_lower', 'yhat_upper' and 'y'.
    """
    return forecast.set_index('ds')[['yhat', 'yhat_lower', 'yhat_upper']].join(historical.set_index('ds'))

# %%
def calculate_forecast_errors(df, prediction_size):
    """Calculate MAPE and MAE of the forecast.
    
       Args:
           df: joined dataset with 'y' and 'yhat' columns.
           prediction_size: number of days at the end to predict.
    """
    
    df = df.copy()
    df.dropna(inplace=True)
    
    df['e'] = df['y'] - df['yhat']
    df['p'] = 100 * df['e'] / df['y']
    
    predicted_part = df[-prediction_size:]
    
    error_mean = lambda error_name: np.mean(np.abs(predicted_part[error_name]))
    
    return {'MAPE': error_mean('p'), 'MAE': error_mean('e')}

# %%
train_df = btc_24h_avg.copy().set_index('ds')

# %%
train_df['y'], lambda_prophet = boxcox(train_df['y'])
train_df.reset_index(inplace=True)

# %%
m2 = Prophet(changepoints=change, seasonality_mode='multiplicative')
m2.fit(train_df)
future2 = m2.make_future_dataframe(periods=15)
forecast2 = m2.predict(future2)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
for column in ['yhat', 'yhat_lower', 'yhat_upper']:
    forecast2[column] = inverse_boxcox(forecast2[column],
                                       lambda_prophet)

# %%
cmp_df2 = make_comparison_dataframe(btc_24h_avg, forecast2)
for err_name, err_value in calculate_forecast_errors(cmp_df2, 15).items():
     print(err_name, err_value)
# Out:
# MAPE 2.4353291528879817
# MAE 3329.293646615347

# %%
def show_forecast(cmp_df, num_predictions, num_values, title):
    """Visualize the forecast."""
    
    def create_go(name, column, num, **kwargs):
        points = cmp_df.tail(num)
        args = dict(name=name, x=points.index, y=points[column], mode='lines')
        args.update(kwargs)
        return go.Scatter(**args)
    
    lower_bound = create_go('Zona de compra', 'yhat_lower', num_predictions,
                            line=dict(width=0),
                            marker=dict(color="green"))
    upper_bound = create_go('Máximo esperado', 'yhat_upper', num_predictions,
                            line=dict(width=0),
                            marker=dict(color="red"),
                            fillcolor='rgba(68, 68, 68, 0.3)', 
                            fill='tonexty')
    forecast = create_go('Venta sugerida', 'yhat', num_predictions,
                         line=dict(color='rgb(31, 119, 180)'))
    actual = create_go('Actual', 'y', num_values,
                       marker=dict(color="red"))
    
    # In this case the order of the series is important because of the filling
    data = [lower_bound, upper_bound, forecast, actual]

    layout = go.Layout(yaxis=dict(title='MXN'), title=title, showlegend = False)
    fig = go.Figure(data=data, layout=layout)
    plotly.offline.plot(fig, filename='btc_mxn.html', auto_open=False)

show_forecast(cmp_df2, 15, 500, 'BTC')
