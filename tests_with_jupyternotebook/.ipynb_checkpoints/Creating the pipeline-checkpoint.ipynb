# %%
#Necesary imports.
import bitso
import pandas as pd
import numpy as np
from datetime import timezone
import datetime
from dateutil.tz import tzutc
import time
from fbprophet import Prophet
import matplotlib.pyplot as plt
from scipy.stats import boxcox
import warnings
warnings.filterwarnings('ignore')
import plotly.offline
from plotly import graph_objs as go

# %%
#Opening my api key and secret.
with open('../key.txt') as f:
    a = f.readlines()

with open('../secret.txt') as p:
    b = p.readlines()

#Using the api secret and key to call the api.
API_SECRET = [i.split('\n') for i in a][0][0]
API_KEY = [i.split('\n') for i in b][0][0]
api = bitso.Api(API_KEY, API_SECRET)

# %%
'''
marker for last_scrap on 19-12-18: 12974700, i save this marker so i can use it
the next time i'm scrapping
'''
#Defining the empyt lists of the elements we need from the api.
btc_mxn_date = []
btc_mxn_price = []
btc_mxn_volume = []
btc_mxn_hour = []
btc_mxn_side = []

#Marker than changes the time in the api calls.
mark = 12953700

#Datetime when the code is running
now = datetime.datetime.now(timezone.utc)

#While loop for scrapping the information we need
while 1:
    #limit of requests, the max we can get is 100
    limit = '100'
    #Calling the api trades, we use sort 'asc' so i't starts on the marker we want.
    trades = api.trades('btc_mxn', sort='asc', limit=limit, marker=mark)
    #Starting the counter so we don't raise the error of too many requests on the api.
    count = 0
    #printing the mark and the spaces, we need these so we know the last mark we use.
    print(mark)
    print('')
    print('')
    #if statement to break the while loop.
    if trades == []:
        break
    #starting a for loop to append the elements we need from each trade to our lists
    for e in trades:
        #adding to the counter.
        count +=1
        # if statement so we just scrap elements before today.
        if e.created_at < now :
            #scrapping the elements we need
            btc_mxn_price.append(e.price)
            btc_mxn_volume.append(e.amount)
            btc_mxn_hour.append(e.created_at.hour)
            btc_mxn_date.append(e.created_at.date())
            btc_mxn_side.append(e.maker_side)
            #printing each trade so we can see that everythings is working fine.
            print(e)
        #else statement to break the for loop.
        else:
            break
        '''
        if statement that starts a timer when the count reachs 100, we can just get
        300 requests per minute so our timer waits 21 seconds before making the next
        100 requests. It also adds a thousand to our mark so it moves forward in time.
        '''
        if count == 100:
            time.sleep(21)
            count = 0
            mark = mark + 1000
# Out:
# 12953700
#
#
# Trade(tid=12953701, price=125830.00, amount=0.00892085, maker_side=buy, created_at=2019-12-18 01:08:49+00:00)
# Trade(tid=12953702, price=125401.00, amount=0.01126475, maker_side=buy, created_at=2019-12-18 01:08:49+00:00)
# Trade(tid=12953704, price=125841.81, amount=0.00317859, maker_side=sell, created_at=2019-12-18 01:09:03+00:00)
# Trade(tid=12953705, price=125401.00, amount=0.00373525, maker_side=buy, created_at=2019-12-18 01:09:04+00:00)
# Trade(tid=12953706, price=125351.05, amount=0.00053781, maker_side=buy, created_at=2019-12-18 01:09:04+00:00)
# Trade(tid=12953707, price=125351.05, amount=0.01266230, maker_side=buy, created_at=2019-12-18 01:09:04+00:00)
# Trade(tid=12953708, price=125351.05, amount=0.00215126, maker_side=buy, created_at=2019-12-18 01:09:04+00:00)
# Trade(tid=12953709, price=125351.05, amount=0.00230223, maker_side=buy, created_at=2019-12-18 01:09:04+00:00)
# Trade(tid=12953710, price=125200.00, amount=0.00798723, maker_side=buy, created_at=2019-12-18 01:09:04+00:00)
# Trade(tid=12953711, price=125047.21, amount=0.16995469, maker_side=buy, created_at=2019-12-18 01:09:04+00:00)
# Trade(tid=12953714, price=125841.51, amount=0.01986626, maker_side=sell, created_at=2019-12-18 01:09:17+00:00)
# Trade(tid=12953715, price=125057.59, amount=0.00361298, maker_side=buy, created_at=2019-12-18 01:09:21+00:00)
# Trade(tid=12953716, price=125841.34, amount=0.00007947, maker_side=sell, created_at=2019-12-18 01:09:25+00:00)
# Trade(tid=12954747, price=127688.10, amount=0.01858043, maker_side=sell, created_at=2019-12-18 03:12:19+00:00)
# Trade(tid=12954748, price=127688.10, amount=0.00760447, maker_side=sell, created_at=2019-12-18 03:12:20+00:00)
# Trade(tid=12954751, price=127687.93, amount=0.06265275, maker_side=sell, created_at=2019-12-18 03:14:18+00:00)
# Trade(tid=12954752, price=127228.85, amount=0.00009643, maker_side=buy, created_at=2019-12-18 03:14:28+00:00)
# Trade(tid=12954753, price=127075.76, amount=0.03404358, maker_side=buy, created_at=2019-12-18 03:14:28+00:00)
# Trade(tid=12954754, price=127687.91, amount=0.00680741, maker_side=sell, created_at=2019-12-18 03:15:23+00:00)
# Trade(tid=12954755, price=127687.91, amount=0.00784814, maker_side=sell, created_at=2019-12-18 03:15:23+00:00)
# Trade(tid=12954756, price=127687.91, amount=0.00716570, maker_side=sell, created_at=2019-12-18 03:15:23+00:00)
# Trade(tid=12954757, price=127687.91, amount=0.00784814, maker_side=sell, created_at=2019-12-18 03:15:23+00:00)
# Trade(tid=12954758, price=127687.92, amount=0.00948858, maker_side=sell, created_at=2019-12-18 03:15:23+00:00)
# Trade(tid=12954759, price=127687.91, amount=0.00093512, maker_side=sell, created_at=2019-12-18 03:15:33+00:00)
# Trade(tid=12954760, price=127687.91, amount=0.00063120, maker_side=sell, created_at=2019-12-18 03:15:33+00:00)
# Trade(tid=12954761, price=127687.91, amount=0.00015663, maker_side=sell, created_at=2019-12-18 03:15:38+00:00)
# Trade(tid=12954762, price=127200.00, amount=0.00027107, maker_side=buy, created_at=2019-12-18 03:15:39+00:00)
# Trade(tid=12954765, price=127687.91, amount=0.00062790, maker_side=sell, created_at=2019-12-18 03:15:55+00:00)
# Trade(tid=12954766, price=127687.91, amount=0.00057330, maker_side=sell, created_at=2019-12-18 03:15:55+00:00)
# Trade(tid=12954767, price=127687.91, amount=0.00062790, maker_side=sell, created_at=2019-12-18 03:15:55+00:00)
# Trade(tid=12954768, price=127687.91, amount=0.00054464, maker_side=sell, created_at=2019-12-18 03:15:55+00:00)
# Trade(tid=12954769, price=127687.92, amount=0.08718578, maker_side=sell, created_at=2019-12-18 03:15:55+00:00)
# Trade(tid=12954770, price=127687.93, amount=0.05924077, maker_side=sell, created_at=2019-12-18 03:15:55+00:00)
# Trade(tid=12954774, price=127838.70, amount=0.03128943, maker_side=sell, created_at=2019-12-18 03:16:37+00:00)
# Trade(tid=12954776, price=127838.62, amount=0.02424932, maker_side=sell, created_at=2019-12-18 03:17:04+00:00)
# Trade(tid=12954777, price=127838.61, amount=0.00007822, maker_side=sell, created_at=2019-12-18 03:17:09+00:00)
# Trade(tid=12954779, price=127838.59, amount=0.14862492, maker_side=sell, created_at=2019-12-18 03:17:17+00:00)
# Trade(tid=12954780, price=127838.55, amount=0.02346710, maker_side=sell, created_at=2019-12-18 03:17:31+00:00)
# Trade(tid=12954782, price=127628.16, amount=0.00787468, maker_side=sell, created_at=2019-12-18 03:17:50+00:00)
# Trade(tid=12954783, price=127838.51, amount=0.00778302, maker_side=sell, created_at=2019-12-18 03:17:50+00:00)
# Trade(tid=12954785, price=127755.47, amount=0.10814533, maker_side=sell, created_at=2019-12-18 03:18:27+00:00)
# Trade(tid=12954786, price=127755.48, amount=1.51345244, maker_side=sell, created_at=2019-12-18 03:18:27+00:00)
# Trade(tid=12954788, price=127755.47, amount=0.00019569, maker_side=sell, created_at=2019-12-18 03:18:34+00:00)
# Trade(tid=12954790, price=127200.00, amount=0.00901032, maker_side=buy, created_at=2019-12-18 03:18:56+00:00)
# Trade(tid=12954801, price=127747.10, amount=0.02348390, maker_side=sell, created_at=2019-12-18 03:20:47+00:00)
# Trade(tid=12954802, price=127746.80, amount=0.00016356, maker_side=sell, created_at=2019-12-18 03:21:21+00:00)
# Trade(tid=12954803, price=127746.85, amount=0.32861167, maker_side=sell, created_at=2019-12-18 03:21:21+00:00)
# Trade(tid=12954807, price=127220.00, amount=0.03000000, maker_side=buy, created_at=2019-12-18 03:22:07+00:00)
# Trade(tid=12954808, price=127220.00, amount=0.00078604, maker_side=buy, created_at=2019-12-18 03:22:07+00:00)
# Trade(tid=12954809, price=127220.00, amount=0.01572080, maker_side=sell, created_at=2019-12-18 03:22:21+00:00)
# Trade(tid=12954811, price=127220.00, amount=0.00108167, maker_side=sell, created_at=2019-12-18 03:22:25+00:00)
# Trade(tid=12954812, price=127200.00, amount=0.00492985, maker_side=buy, created_at=2019-12-18 03:22:41+00:00)
# Trade(tid=12954815, price=127220.00, amount=0.00157860, maker_side=sell, created_at=2019-12-18 03:23:25+00:00)
# Trade(tid=12954816, price=127200.00, amount=0.01535362, maker_side=buy, created_at=2019-12-18 03:23:40+00:00)
# Trade(tid=12954817, price=127200.00, amount=0.00078617, maker_side=buy, created_at=2019-12-18 03:23:40+00:00)
# Trade(tid=12954818, price=127070.00, amount=0.01573936, maker_side=buy, created_at=2019-12-18 03:23:40+00:00)
# Trade(tid=12954819, price=127027.54, amount=0.01413137, maker_side=buy, created_at=2019-12-18 03:23:40+00:00)
# Trade(tid=12954820, price=127027.69, amount=0.05149990, maker_side=buy, created_at=2019-12-18 03:23:51+00:00)
# Trade(tid=12954822, price=127025.01, amount=0.04186509, maker_side=buy, created_at=2019-12-18 03:25:06+00:00)
# Trade(tid=12954823, price=127597.45, amount=0.00011683, maker_side=sell, created_at=2019-12-18 03:25:14+00:00)
# Trade(tid=12954824, price=127597.46, amount=0.00027503, maker_side=sell, created_at=2019-12-18 03:25:14+00:00)
# Trade(tid=12954828, price=127597.07, amount=0.00008345, maker_side=sell, created_at=2019-12-18 03:25:49+00:00)
# Trade(tid=12954829, price=127597.11, amount=0.02256872, maker_side=sell, created_at=2019-12-18 03:25:49+00:00)
# Trade(tid=12954830, price=127597.11, amount=0.02471813, maker_side=sell, created_at=2019-12-18 03:25:49+00:00)
# Trade(tid=12954831, price=127597.11, amount=0.01532704, maker_side=sell, created_at=2019-12-18 03:25:49+00:00)
# Trade(tid=12954832, price=127033.25, amount=0.00721504, maker_side=buy, created_at=2019-12-18 03:26:00+00:00)
# Trade(tid=12954838, price=127596.66, amount=0.00548604, maker_side=sell, created_at=2019-12-18 03:27:15+00:00)
# Trade(tid=12954841, price=127596.42, amount=0.00186463, maker_side=sell, created_at=2019-12-18 03:28:02+00:00)
# Trade(tid=12954843, price=127596.32, amount=0.00892032, maker_side=sell, created_at=2019-12-18 03:28:22+00:00)
# Trade(tid=12954844, price=127596.32, amount=0.00938981, maker_side=sell, created_at=2019-12-18 03:28:22+00:00)
# Trade(tid=12954845, price=127596.32, amount=0.01028408, maker_side=sell, created_at=2019-12-18 03:28:22+00:00)
# Trade(tid=12954846, price=127596.32, amount=0.01028408, maker_side=sell, created_at=2019-12-18 03:28:22+00:00)
# Trade(tid=12954847, price=127596.33, amount=0.02381944, maker_side=sell, created_at=2019-12-18 03:28:22+00:00)
# Trade(tid=12954848, price=127555.62, amount=0.00134207, maker_side=sell, created_at=2019-12-18 03:29:12+00:00)
# Trade(tid=12954849, price=127555.62, amount=0.00116410, maker_side=sell, created_at=2019-12-18 03:29:12+00:00)
# Trade(tid=12954850, price=127555.62, amount=0.00122537, maker_side=sell, created_at=2019-12-18 03:29:12+00:00)
# Trade(tid=12954851, price=127555.62, amount=0.00134207, maker_side=sell, created_at=2019-12-18 03:29:12+00:00)
# Trade(tid=12954852, price=127555.63, amount=0.03412497, maker_side=sell, created_at=2019-12-18 03:29:12+00:00)
# Trade(tid=12954853, price=127555.61, amount=0.00291638, maker_side=sell, created_at=2019-12-18 03:29:14+00:00)
# Trade(tid=12954854, price=127024.29, amount=0.00758331, maker_side=buy, created_at=2019-12-18 03:29:15+00:00)
# Trade(tid=12954855, price=127024.29, amount=0.00739989, maker_side=buy, created_at=2019-12-18 03:29:15+00:00)
# Trade(tid=12954858, price=127555.62, amount=0.00017514, maker_side=sell, created_at=2019-12-18 03:29:17+00:00)
# Trade(tid=12954859, price=127555.63, amount=0.04686316, maker_side=sell, created_at=2019-12-18 03:29:17+00:00)
# Trade(tid=12954861, price=127491.07, amount=0.00012313, maker_side=sell, created_at=2019-12-18 03:30:20+00:00)
# Trade(tid=12954862, price=127491.07, amount=0.00013486, maker_side=sell, created_at=2019-12-18 03:30:20+00:00)
# Trade(tid=12954863, price=127491.07, amount=0.00013486, maker_side=sell, created_at=2019-12-18 03:30:20+00:00)
# Trade(tid=12954864, price=127491.07, amount=0.00011697, maker_side=sell, created_at=2019-12-18 03:30:20+00:00)
# Trade(tid=12954865, price=127491.08, amount=0.00968697, maker_side=sell, created_at=2019-12-18 03:30:21+00:00)
# Trade(tid=12954867, price=127491.05, amount=0.03921844, maker_side=sell, created_at=2019-12-18 03:30:46+00:00)
# Trade(tid=12954869, price=127491.03, amount=0.01568738, maker_side=sell, created_at=2019-12-18 03:30:51+00:00)
# Trade(tid=12954872, price=127391.84, amount=0.03924898, maker_side=sell, created_at=2019-12-18 03:32:16+00:00)
# Trade(tid=12954874, price=127333.61, amount=0.00070680, maker_side=sell, created_at=2019-12-18 03:32:57+00:00)
# Trade(tid=12954877, price=127024.29, amount=0.00874281, maker_side=buy, created_at=2019-12-18 03:33:10+00:00)
# 12955700
#
#
# Trade(tid=12955702, price=126310.01, amount=0.00281998, maker_side=buy, created_at=2019-12-18 05:47:26+00:00)
# Trade(tid=12955707, price=126349.94, amount=0.00950431, maker_side=buy, created_at=2019-12-18 05:48:15+00:00)
# Trade(tid=12955708, price=126349.94, amount=0.00034641, maker_side=buy, created_at=2019-12-18 05:48:15+00:00)
# Trade(tid=12955710, price=126681.18, amount=0.02920718, maker_side=sell, created_at=2019-12-18 05:48:23+00:00)
# Trade(tid=12955715, price=126387.78, amount=0.04612995, maker_side=buy, created_at=2019-12-18 05:48:45+00:00)
# Trade(tid=12955716, price=126387.77, amount=0.02932769, maker_side=buy, created_at=2019-12-18 05:48:45+00:00)
# Trade(tid=12955717, price=126681.18, amount=0.00152398, maker_side=sell, created_at=2019-12-18 05:48:47+00:00)
# Trade(tid=12955719, price=126681.18, amount=0.02841780, maker_side=sell, created_at=2019-12-18 05:48:59+00:00)
# Trade(tid=12955720, price=126681.18, amount=0.00034322, maker_side=sell, created_at=2019-12-18 05:49:07+00:00)
# Trade(tid=12955734, price=126457.84, amount=0.24692134, maker_side=buy, created_at=2019-12-18 05:51:21+00:00)
# Trade(tid=12955735, price=126681.18, amount=0.03157533, maker_side=sell, created_at=2019-12-18 05:51:22+00:00)
# Trade(tid=12955736, price=126681.18, amount=0.00078938, maker_side=sell, created_at=2019-12-18 05:51:31+00:00)
# Trade(tid=12955737, price=126681.19, amount=0.03946916, maker_side=sell, created_at=2019-12-18 05:51:47+00:00)
# Trade(tid=12955738, price=126681.19, amount=0.02841779, maker_side=sell, created_at=2019-12-18 05:52:25+00:00)
# Trade(tid=12955741, price=126681.19, amount=0.00669545, maker_side=sell, created_at=2019-12-18 05:53:01+00:00)
# Trade(tid=12955742, price=126857.57, amount=0.01696243, maker_side=sell, created_at=2019-12-18 05:53:01+00:00)
# Trade(tid=12955744, price=126477.16, amount=0.01430644, maker_side=buy, created_at=2019-12-18 05:53:57+00:00)
# Trade(tid=12955745, price=126477.79, amount=0.02767780, maker_side=buy, created_at=2019-12-18 05:54:20+00:00)
# Trade(tid=12955747, price=126799.69, amount=0.04149424, maker_side=sell, created_at=2019-12-18 05:54:40+00:00)
# Trade(tid=12955748, price=126799.69, amount=0.03599175, maker_side=sell, created_at=2019-12-18 05:54:40+00:00)
# Trade(tid=12955749, price=126799.69, amount=0.04149424, maker_side=sell, created_at=2019-12-18 05:54:40+00:00)
# Trade(tid=12955750, price=126799.69, amount=0.03788605, maker_side=sell, created_at=2019-12-18 05:54:40+00:00)
# Trade(tid=12955751, price=126816.05, amount=0.05000000, maker_side=sell, created_at=2019-12-18 05:54:40+00:00)
# Trade(tid=12955752, price=126857.51, amount=0.01224772, maker_side=sell, created_at=2019-12-18 05:54:40+00:00)
# Trade(tid=12955753, price=126857.54, amount=0.15478778, maker_side=sell, created_at=2019-12-18 05:54:40+00:00)
# Trade(tid=12955758, price=126694.88, amount=0.00494413, maker_side=sell, created_at=2019-12-18 05:55:37+00:00)
# Trade(tid=12955759, price=126694.88, amount=0.00452744, maker_side=sell, created_at=2019-12-18 05:55:37+00:00)
# Trade(tid=12955760, price=126690.68, amount=0.00291261, maker_side=sell, created_at=2019-12-18 05:55:40+00:00)
# Trade(tid=12955768, price=126699.97, amount=0.00045825, maker_side=sell, created_at=2019-12-18 05:58:53+00:00)
# Trade(tid=12955775, price=126550.00, amount=0.07115500, maker_side=buy, created_at=2019-12-18 06:01:20+00:00)
# Trade(tid=12955778, price=126699.95, amount=0.00789598, maker_side=sell, created_at=2019-12-18 06:02:56+00:00)
# Trade(tid=12955780, price=126550.00, amount=0.21914814, maker_side=buy, created_at=2019-12-18 06:03:00+00:00)
# Trade(tid=12955785, price=126891.40, amount=0.00256664, maker_side=sell, created_at=2019-12-18 06:05:01+00:00)
# Trade(tid=12955786, price=126891.40, amount=0.00222628, maker_side=sell, created_at=2019-12-18 06:05:01+00:00)
# Trade(tid=12955787, price=126891.40, amount=0.00234345, maker_side=sell, created_at=2019-12-18 06:05:01+00:00)
# Trade(tid=12955788, price=126891.40, amount=0.00256664, maker_side=sell, created_at=2019-12-18 06:05:01+00:00)
# Trade(tid=12955789, price=126891.41, amount=0.00541165, maker_side=sell, created_at=2019-12-18 06:05:01+00:00)
# Trade(tid=12955800, price=126550.10, amount=0.15753933, maker_side=buy, created_at=2019-12-18 06:05:28+00:00)
# Trade(tid=12955801, price=126550.01, amount=0.13269714, maker_side=buy, created_at=2019-12-18 06:05:28+00:00)
# Trade(tid=12955802, price=126550.00, amount=0.12586880, maker_side=buy, created_at=2019-12-18 06:05:28+00:00)
# Trade(tid=12955803, price=126550.03, amount=0.00055379, maker_side=buy, created_at=2019-12-18 06:05:28+00:00)
# Trade(tid=12955804, price=126550.03, amount=0.15698554, maker_side=buy, created_at=2019-12-18 06:05:29+00:00)
# Trade(tid=12955805, price=126550.01, amount=0.12603092, maker_side=buy, created_at=2019-12-18 06:05:29+00:00)
# Trade(tid=12955806, price=126550.00, amount=0.05103485, maker_side=buy, created_at=2019-12-18 06:05:29+00:00)
# Trade(tid=12955817, price=126550.71, amount=0.02832568, maker_side=buy, created_at=2019-12-18 06:11:01+00:00)
# Trade(tid=12955818, price=126550.01, amount=0.03681400, maker_side=buy, created_at=2019-12-18 06:11:26+00:00)
# Trade(tid=12955836, price=126912.62, amount=0.00787944, maker_side=sell, created_at=2019-12-18 06:13:01+00:00)
# Trade(tid=12955838, price=126875.18, amount=0.00788176, maker_side=sell, created_at=2019-12-18 06:13:48+00:00)
# Trade(tid=12955839, price=126875.30, amount=0.00352519, maker_side=sell, created_at=2019-12-18 06:14:38+00:00)
# Trade(tid=12955840, price=126875.30, amount=0.02837432, maker_side=sell, created_at=2019-12-18 06:16:06+00:00)
# Trade(tid=12955841, price=126875.31, amount=0.04729052, maker_side=sell, created_at=2019-12-18 06:16:35+00:00)
# Trade(tid=12955842, price=126875.31, amount=0.01683774, maker_side=sell, created_at=2019-12-18 06:17:29+00:00)
# Trade(tid=12955843, price=126999.87, amount=0.01467487, maker_side=sell, created_at=2019-12-18 06:17:29+00:00)
# Trade(tid=12955844, price=126875.21, amount=0.00078818, maker_side=sell, created_at=2019-12-18 06:18:29+00:00)
# Trade(tid=12955860, price=126550.33, amount=0.04468419, maker_side=buy, created_at=2019-12-18 06:18:48+00:00)
# Trade(tid=12955861, price=126550.35, amount=0.23800222, maker_side=buy, created_at=2019-12-18 06:18:48+00:00)
# Trade(tid=12955862, price=126550.33, amount=0.13342789, maker_side=buy, created_at=2019-12-18 06:18:48+00:00)
# Trade(tid=12955863, price=126550.22, amount=0.01267111, maker_side=buy, created_at=2019-12-18 06:19:06+00:00)
# Trade(tid=12955865, price=126550.18, amount=0.01271020, maker_side=buy, created_at=2019-12-18 06:19:14+00:00)
# Trade(tid=12955866, price=126550.23, amount=0.00994213, maker_side=buy, created_at=2019-12-18 06:19:16+00:00)
# Trade(tid=12955870, price=126600.00, amount=0.00019898, maker_side=buy, created_at=2019-12-18 06:22:36+00:00)
# Trade(tid=12955871, price=126550.02, amount=0.06961095, maker_side=buy, created_at=2019-12-18 06:22:36+00:00)
# Trade(tid=12955872, price=126550.01, amount=0.06584554, maker_side=buy, created_at=2019-12-18 06:22:36+00:00)
# Trade(tid=12955873, price=126870.68, amount=0.00394102, maker_side=sell, created_at=2019-12-18 06:22:36+00:00)
# Trade(tid=12955878, price=126850.02, amount=0.00867166, maker_side=sell, created_at=2019-12-18 06:24:40+00:00)
# Trade(tid=12955879, price=126550.01, amount=0.00397686, maker_side=buy, created_at=2019-12-18 06:25:13+00:00)
# Trade(tid=12955880, price=126813.09, amount=0.00315425, maker_side=sell, created_at=2019-12-18 06:27:14+00:00)
# Trade(tid=12955891, price=126550.00, amount=0.31996423, maker_side=buy, created_at=2019-12-18 06:27:27+00:00)
# Trade(tid=12955892, price=126550.05, amount=0.03442837, maker_side=buy, created_at=2019-12-18 06:27:28+00:00)
# Trade(tid=12955893, price=126550.00, amount=0.08626234, maker_side=buy, created_at=2019-12-18 06:27:28+00:00)
# Trade(tid=12955895, price=126550.01, amount=0.00598931, maker_side=buy, created_at=2019-12-18 06:27:56+00:00)
# Trade(tid=12955896, price=126825.15, amount=0.13401210, maker_side=sell, created_at=2019-12-18 06:28:10+00:00)
# Trade(tid=12955897, price=126825.15, amount=0.14106537, maker_side=sell, created_at=2019-12-18 06:28:10+00:00)
# Trade(tid=12955898, price=126825.15, amount=0.15450017, maker_side=sell, created_at=2019-12-18 06:28:10+00:00)
# Trade(tid=12955899, price=126825.15, amount=0.15450017, maker_side=sell, created_at=2019-12-18 06:28:10+00:00)
# Trade(tid=12955900, price=126825.16, amount=1.74545643, maker_side=sell, created_at=2019-12-18 06:28:10+00:00)
# Trade(tid=12955901, price=126870.72, amount=0.05000000, maker_side=sell, created_at=2019-12-18 06:28:10+00:00)
# Trade(tid=12955902, price=126994.94, amount=0.09703109, maker_side=sell, created_at=2019-12-18 06:28:10+00:00)
# Trade(tid=12955903, price=126999.85, amount=0.32197250, maker_side=sell, created_at=2019-12-18 06:28:10+00:00)
# Trade(tid=12955905, price=126793.23, amount=0.00788686, maker_side=sell, created_at=2019-12-18 06:28:30+00:00)
# Trade(tid=12955906, price=126550.00, amount=0.00079538, maker_side=buy, created_at=2019-12-18 06:28:32+00:00)
# Trade(tid=12955907, price=126793.23, amount=0.00343078, maker_side=sell, created_at=2019-12-18 06:28:34+00:00)
# Trade(tid=12955908, price=126550.00, amount=0.01783560, maker_side=buy, created_at=2019-12-18 06:28:45+00:00)
# Trade(tid=12955915, price=126793.23, amount=0.00709139, maker_side=sell, created_at=2019-12-18 06:29:59+00:00)
# Trade(tid=12955916, price=126793.23, amount=0.01748858, maker_side=sell, created_at=2019-12-18 06:29:59+00:00)
# Trade(tid=12955917, price=126793.23, amount=0.00184060, maker_side=sell, created_at=2019-12-18 06:29:59+00:00)
# Trade(tid=12955918, price=126793.23, amount=0.01577371, maker_side=sell, created_at=2019-12-18 06:30:38+00:00)
# Trade(tid=12955919, price=126706.89, amount=0.00197306, maker_side=sell, created_at=2019-12-18 06:32:27+00:00)
# Trade(tid=12955921, price=126771.43, amount=0.00078882, maker_side=sell, created_at=2019-12-18 06:33:58+00:00)
# Trade(tid=12955934, price=126550.00, amount=0.01666739, maker_side=buy, created_at=2019-12-18 06:34:18+00:00)
# Trade(tid=12955935, price=126329.86, amount=0.02248587, maker_side=buy, created_at=2019-12-18 06:34:18+00:00)
# Trade(tid=12955936, price=126329.87, amount=0.00066431, maker_side=buy, created_at=2019-12-18 06:34:19+00:00)
# Trade(tid=12955945, price=126329.81, amount=0.04003687, maker_side=buy, created_at=2019-12-18 06:36:48+00:00)
# Trade(tid=12955946, price=126300.00, amount=0.00004155, maker_side=buy, created_at=2019-12-18 06:36:48+00:00)
# Trade(tid=12955947, price=126045.02, amount=0.05214548, maker_side=buy, created_at=2019-12-18 06:36:48+00:00)
# Trade(tid=12955949, price=126509.53, amount=0.00118877, maker_side=sell, created_at=2019-12-18 06:37:04+00:00)
# Trade(tid=12955950, price=126509.14, amount=0.00790457, maker_side=sell, created_at=2019-12-18 06:37:16+00:00)
# Trade(tid=12955962, price=126300.53, amount=0.00079176, maker_side=sell, created_at=2019-12-18 06:41:04+00:00)
# Trade(tid=12955967, price=126300.58, amount=0.14251716, maker_side=sell, created_at=2019-12-18 06:42:03+00:00)
# Trade(tid=12955970, price=126000.00, amount=0.00015874, maker_side=buy, created_at=2019-12-18 06:43:23+00:00)
# 12956700
#
#
# Trade(tid=12956701, price=125761.96, amount=0.00973695, maker_side=buy, created_at=2019-12-18 10:26:56+00:00)
# Trade(tid=12956702, price=126100.04, amount=0.03013480, maker_side=sell, created_at=2019-12-18 10:32:44+00:00)
# Trade(tid=12956712, price=125855.97, amount=0.06810925, maker_side=buy, created_at=2019-12-18 10:45:27+00:00)
# Trade(tid=12956713, price=125851.56, amount=0.06810925, maker_side=buy, created_at=2019-12-18 10:45:27+00:00)
# Trade(tid=12956714, price=125774.81, amount=0.13258438, maker_side=buy, created_at=2019-12-18 10:45:27+00:00)
# Trade(tid=12956715, price=125765.64, amount=0.63121343, maker_side=buy, created_at=2019-12-18 10:45:27+00:00)
# Trade(tid=12956719, price=125753.89, amount=0.00036858, maker_side=buy, created_at=2019-12-18 10:49:28+00:00)
# Trade(tid=12956720, price=126409.32, amount=0.00101258, maker_side=sell, created_at=2019-12-18 10:50:43+00:00)
# Trade(tid=12956724, price=125961.42, amount=0.30729779, maker_side=buy, created_at=2019-12-18 10:52:50+00:00)
# Trade(tid=12956725, price=126550.00, amount=0.01280435, maker_side=sell, created_at=2019-12-18 10:57:18+00:00)
# Trade(tid=12956727, price=125894.27, amount=0.04112451, maker_side=buy, created_at=2019-12-18 10:59:00+00:00)
# Trade(tid=12956728, price=125894.27, amount=0.01533489, maker_side=buy, created_at=2019-12-18 10:59:00+00:00)
# Trade(tid=12956729, price=125894.27, amount=0.04064178, maker_side=buy, created_at=2019-12-18 10:59:00+00:00)
# Trade(tid=12956730, price=125897.62, amount=0.01533489, maker_side=buy, created_at=2019-12-18 10:59:02+00:00)
# Trade(tid=12956886, price=125499.82, amount=0.00318726, maker_side=sell, created_at=2019-12-18 12:08:48+00:00)
# 12957700
#
#
# Trade(tid=12957704, price=122499.99, amount=0.08163266, maker_side=sell, created_at=2019-12-18 13:20:40+00:00)
# Trade(tid=12957713, price=122500.00, amount=0.00040816, maker_side=sell, created_at=2019-12-18 13:21:50+00:00)
# Trade(tid=12957715, price=122100.02, amount=0.03685504, maker_side=sell, created_at=2019-12-18 13:23:11+00:00)
# Trade(tid=12957730, price=122100.02, amount=0.00081900, maker_side=sell, created_at=2019-12-18 13:23:13+00:00)
# Trade(tid=12957734, price=122100.02, amount=0.00163800, maker_side=sell, created_at=2019-12-18 13:23:48+00:00)
# Trade(tid=12957737, price=122100.02, amount=0.01829074, maker_side=sell, created_at=2019-12-18 13:24:17+00:00)
# Trade(tid=12957743, price=122100.01, amount=0.01319945, maker_side=buy, created_at=2019-12-18 13:25:04+00:00)
# Trade(tid=12957750, price=122100.02, amount=0.05000000, maker_side=sell, created_at=2019-12-18 13:25:57+00:00)
# Trade(tid=12957751, price=122100.01, amount=0.02349000, maker_side=buy, created_at=2019-12-18 13:26:01+00:00)
# Trade(tid=12957754, price=122100.01, amount=0.02100000, maker_side=buy, created_at=2019-12-18 13:26:08+00:00)
# Trade(tid=12957772, price=122100.02, amount=0.10000000, maker_side=sell, created_at=2019-12-18 13:26:53+00:00)
# Trade(tid=12957778, price=122100.02, amount=0.09038709, maker_side=sell, created_at=2019-12-18 13:27:05+00:00)
# Trade(tid=12957784, price=123111.57, amount=0.03333333, maker_side=sell, created_at=2019-12-18 13:27:32+00:00)
# Trade(tid=12957785, price=123111.54, amount=0.03333333, maker_side=sell, created_at=2019-12-18 13:27:33+00:00)
# Trade(tid=12957786, price=123111.54, amount=0.03333333, maker_side=sell, created_at=2019-12-18 13:27:33+00:00)
# Trade(tid=12957794, price=123000.00, amount=0.00409164, maker_side=buy, created_at=2019-12-18 13:27:49+00:00)
# Trade(tid=12957817, price=123120.74, amount=0.00812211, maker_side=sell, created_at=2019-12-18 13:28:31+00:00)
# Trade(tid=12957826, price=123120.74, amount=0.01582001, maker_side=sell, created_at=2019-12-18 13:28:56+00:00)
# Trade(tid=12957829, price=123120.74, amount=0.09250995, maker_side=sell, created_at=2019-12-18 13:28:59+00:00)
# Trade(tid=12957834, price=123120.74, amount=0.19224592, maker_side=sell, created_at=2019-12-18 13:29:05+00:00)
# Trade(tid=12957835, price=123120.74, amount=0.17220668, maker_side=sell, created_at=2019-12-18 13:29:05+00:00)
# Trade(tid=12957836, price=123120.75, amount=0.54105973, maker_side=sell, created_at=2019-12-18 13:29:05+00:00)
# Trade(tid=12957840, price=123120.74, amount=0.00081221, maker_side=sell, created_at=2019-12-18 13:29:41+00:00)
# Trade(tid=12957841, price=123120.74, amount=0.08350593, maker_side=sell, created_at=2019-12-18 13:29:45+00:00)
# Trade(tid=12957842, price=123120.74, amount=0.07624455, maker_side=sell, created_at=2019-12-18 13:29:45+00:00)
maker_side=buy, created_at=2019-12-20 14:18:22+00:00)
# Trade(tid=12977766, price=135356.61, amount=0.01215173, maker_side=buy, created_at=2019-12-20 14:18:22+00:00)
# Trade(tid=12977767, price=135356.61, amount=0.01275931, maker_side=buy, created_at=2019-12-20 14:18:22+00:00)
# Trade(tid=12977768, price=135356.61, amount=0.01215173, maker_side=buy, created_at=2019-12-20 14:18:22+00:00)
# Trade(tid=12977769, price=135356.60, amount=0.18132316, maker_side=buy, created_at=2019-12-20 14:18:22+00:00)
# Trade(tid=12977771, price=135687.30, amount=0.08216942, maker_side=buy, created_at=2019-12-20 14:20:01+00:00)
# Trade(tid=12977772, price=135340.01, amount=0.00118103, maker_side=buy, created_at=2019-12-20 14:20:01+00:00)
# Trade(tid=12977773, price=135312.00, amount=0.05542746, maker_side=buy, created_at=2019-12-20 14:20:02+00:00)
# Trade(tid=12977774, price=135146.73, amount=0.36122209, maker_side=buy, created_at=2019-12-20 14:20:02+00:00)
# Trade(tid=12977775, price=135885.00, amount=0.00150863, maker_side=sell, created_at=2019-12-20 14:20:04+00:00)
# Trade(tid=12977776, price=135146.88, amount=0.00149882, maker_side=buy, created_at=2019-12-20 14:20:18+00:00)
# Trade(tid=12977778, price=135744.52, amount=0.11050170, maker_side=sell, created_at=2019-12-20 14:21:28+00:00)
# Trade(tid=12977785, price=135147.43, amount=0.00790914, maker_side=buy, created_at=2019-12-20 14:23:57+00:00)
# Trade(tid=12977788, price=135704.45, amount=0.01326412, maker_side=sell, created_at=2019-12-20 14:25:43+00:00)
# Trade(tid=12977789, price=135169.49, amount=0.01779642, maker_side=buy, created_at=2019-12-20 14:26:08+00:00)
# Trade(tid=12977793, price=135730.00, amount=0.00986000, maker_side=buy, created_at=2019-12-20 14:27:44+00:00)
# Trade(tid=12977795, price=135170.55, amount=0.13483233, maker_side=buy, created_at=2019-12-20 14:29:45+00:00)
# Trade(tid=12977796, price=135170.53, amount=0.01516767, maker_side=buy, created_at=2019-12-20 14:29:45+00:00)
# Trade(tid=12977797, price=135170.54, amount=0.00244299, maker_side=buy, created_at=2019-12-20 14:29:46+00:00)
# Trade(tid=12977804, price=135171.45, amount=0.01185000, maker_side=buy, created_at=2019-12-20 14:31:46+00:00)
# Trade(tid=12977805, price=135801.29, amount=0.02945480, maker_side=sell, created_at=2019-12-20 14:32:06+00:00)
# Trade(tid=12977806, price=135877.80, amount=0.02129303, maker_side=sell, created_at=2019-12-20 14:32:30+00:00)
# Trade(tid=12977807, price=135172.30, amount=0.00184670, maker_side=buy, created_at=2019-12-20 14:32:57+00:00)
# Trade(tid=12977810, price=135173.05, amount=0.00048724, maker_side=buy, created_at=2019-12-20 14:34:28+00:00)
# Trade(tid=12977812, price=135173.33, amount=0.00515762, maker_side=buy, created_at=2019-12-20 14:35:19+00:00)
# ---------------------------------------------------------------------------
# ApiError                                  Traceback (most recent call last)
# <ipython-input-3-3ac703860610> in <module>
#      21     limit = '100'
#      22     #Calling the api trades, we use sort 'asc' so i't starts on the marker we want.
# ---> 23     trades = api.trades('btc_mxn', sort='asc', limit=limit, marker=mark)
#      24     #Starting the counter so we don't raise the error of too many requests on the api.
#      25     count = 0
#
# ~/Desktop/DataAnalytics/proyectos/proyectos/lib/python3.7/site-packages/bitso/api.py in trades(self, book, **kwargs)
#     184         if 'sort' in kwargs:
#     185             parameters['sort'] = kwargs['sort']
# --> 186         resp = self._request_url(url, 'GET', params=parameters)
#     187         return [Trade._NewFromJsonDict(x) for x in resp['payload']]
#     188
#
# ~/Desktop/DataAnalytics/proyectos/proyectos/lib/python3.7/site-packages/bitso/api.py in _request_url(self, url, verb, params, private)
#     945
#     946         content = resp.content
# --> 947         data = self._parse_json(content if isinstance(content, basestring) else content.decode('utf-8'))
#     948         return data
#     949
#
# ~/Desktop/DataAnalytics/proyectos/proyectos/lib/python3.7/site-packages/bitso/api.py in _parse_json(self, json_data)
#     973         try:
#     974             data = json.loads(json_data)
# --> 975             self._check_for_api_error(data)
#     976         except:
#     977             raise
#
# ~/Desktop/DataAnalytics/proyectos/proyectos/lib/python3.7/site-packages/bitso/api.py in _check_for_api_error(self, data)
#     980     def _check_for_api_error(self, data):
#     981         if data['success'] != True:
# --> 982             raise ApiError(data['error'])
#     983         if 'error' in data:
#     984             raise ApiError(data['error'])
#
# ApiError: {'code': 200, 'message': 'Demasiadas solicitudes.'}

# %%
# creating a new data frame.
df = pd.DataFrame(columns=['price', 'volume', 'hour', 'date', 'side'])
# using the lists we got from the while loop to fill the dataframe.
df.price = btc_mxn_price
df.volume = btc_mxn_volume
df.hour = btc_mxn_hour
df.date = btc_mxn_date
df.side = btc_mxn_side
df.date = df.date.astype('datetime64')
#creating new columns with the month and day of each row.
df['month'] = [i.month for i in df.date]
df['day'] = [i.day for i in df.date]

# %%
#Creating a function that needs a data frame and a number(month) for input.
def extraction(df, m):
    #variable that get's just the row that matches the same month
    f_df = df.loc[df['month'] == m]
    #variable that stores the year
    y = datetime.datetime.today().year
    #variable that creates a list with the numbers of days of the month
    days = list(f_df['day'].unique())
    #varible that creates a empty dictionary
    results = {}
    #list with the names of the keys in the dictionary that the function returns.
    nombres = ['date', '24h_avg', '12h_avg', 'min', 'max', 'volume', 'm_side']
    
    #for loop that creates new keys in the empty dictionary with a empty list as values.
    for i in nombres:
        results[i] = []
    
    #for that loops on each day in the list of the days of the month.
    for e in days:
        #variable that get's just the rows that match the day in the for loop.
        ndf = f_df.loc[f_df.day == e]
        #appending the results in each dictionary key.
        results['date'].append(datetime.date(y, m, e))
        results['24h_avg'].append(ndf.price.mean())
        results['12h_avg'].append(ndf.price.loc[ndf.hour<12].mean())
        results['max'].append(ndf.price.max())
        results['min'].append(ndf.price.min())
        results['volume'].append(ndf.volume.sum())
        weight = ndf.side.value_counts().sum()
        buy = ndf.side.value_counts()['buy']/weight
        sell = ndf.side.value_counts()['sell']/weight
        if buy>sell:
            results['m_side'].append('buy')
        else:
            results['m_side'].append('sell')
            
    #returns the dictionary with the appended elements
    return results

# %%
#creating a variable that stores the month we are in.
month = datetime.datetime.today().month
#creating a new data frame using the dictionary from the above function and the month
df_new = pd.DataFrame.from_dict(extraction(df, month))

# %%
#Reading our csv file where we store the past data
history = pd.read_csv('../csv_files/historic_data.csv')

# %%
btc_df = pd.concat([history, df_new], ignore_index=True)

# %%
btc_df.drop_duplicates(inplace=True)

# %%
btc_df.drop(btc_df.tail(1).index,inplace=True)

# %%
btc_df.to_csv('../csv_files/historic_data.csv', index=False)

# %%
btc_df.date = btc_df.date.astype('datetime64')
btc_df['min'] = btc_df['min'].astype('float')
btc_df['max'] = btc_df['max'].astype('float')
btc_df.volume = btc_df.volume.astype('float')
btc_df['m_side'] = btc_df['m_side'].astype('category')

# %%
df_dum = pd.get_dummies(btc_df)
df_dum.rename(columns={'m_side_buy':'buy', 'm_side_sell':'sell'}, inplace=True)

# %%
change = []
for i in range(1,len(df_dum)):
    if df_dum.sell.iloc[i] != df_dum.sell.iloc[i-1]:
        change.append(df_dum.date.iloc[i])

# %%
#Selecting the columns we need for fbprophet
btc_24h_avg = btc_df[['date', '24h_avg']].copy()
#Changing the columns names for fbprophet to accept it.
btc_24h_avg.rename(columns={'date': 'ds', '24h_avg': 'y'}, inplace=True)

# %%
def inverse_boxcox(y, lambda_):
    return np.exp(y) if lambda_ == 0 else np.exp(np.log(lambda_ * y + 1) / lambda_)

# %%
def make_comparison_dataframe(historical, forecast):
    """Join the history with the forecast.
    
       The resulting dataset will contain columns 'yhat', 'yhat_lower', 'yhat_upper' and 'y'.
    """
    return forecast.set_index('ds')[['yhat', 'yhat_lower', 'yhat_upper']].join(historical.set_index('ds'))

# %%
def calculate_forecast_errors(df, prediction_size):
    """Calculate MAPE and MAE of the forecast.
    
       Args:
           df: joined dataset with 'y' and 'yhat' columns.
           prediction_size: number of days at the end to predict.
    """
    
    # Make a copy
    df = df.copy()
    df.dropna(inplace=True)
    
    # Now we calculate the values of e_i and p_i according to the formulas given in the article above.
    df['e'] = df['y'] - df['yhat']
    df['p'] = 100 * df['e'] / df['y']
    
    # Now cut out the part of the data which we made our prediction for.
    predicted_part = df[-prediction_size:]
    
    # Define the function that averages absolute error values over the predicted part.
    error_mean = lambda error_name: np.mean(np.abs(predicted_part[error_name]))
    
    # Now we can calculate MAPE and MAE and return the resulting dictionary of errors.
    return {'MAPE': error_mean('p'), 'MAE': error_mean('e')}

# %%
train_df = btc_24h_avg.copy().set_index('ds')

# %%
train_df['y'], lambda_prophet = boxcox(train_df['y'])
train_df.reset_index(inplace=True)

# %%
m2 = Prophet(changepoints=change, seasonality_mode='multiplicative')
m2.fit(train_df)
future2 = m2.make_future_dataframe(periods=15)
forecast2 = m2.predict(future2)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
for column in ['yhat', 'yhat_lower', 'yhat_upper']:
    forecast2[column] = inverse_boxcox(forecast2[column],
                                       lambda_prophet)

# %%
cmp_df2 = make_comparison_dataframe(btc_24h_avg, forecast2)
for err_name, err_value in calculate_forecast_errors(cmp_df2, 15).items():
     print(err_name, err_value)
# Out:
# MAPE 4.262431978981491
# MAE 5538.511119111796

# %%
def show_forecast(cmp_df, num_predictions, num_values, title):
    """Visualize the forecast."""
    
    def create_go(name, column, num, **kwargs):
        points = cmp_df.tail(num)
        args = dict(name=name, x=points.index, y=points[column], mode='lines')
        args.update(kwargs)
        return go.Scatter(**args)
    
    lower_bound = create_go('Zona de compra', 'yhat_lower', num_predictions,
                            line=dict(width=0),
                            marker=dict(color="green"))
    upper_bound = create_go('Máximo esperado', 'yhat_upper', num_predictions,
                            line=dict(width=0),
                            marker=dict(color="red"),
                            fillcolor='rgba(68, 68, 68, 0.3)', 
                            fill='tonexty')
    forecast = create_go('Venta sugerida', 'yhat', num_predictions,
                         line=dict(color='rgb(31, 119, 180)'))
    actual = create_go('Actual', 'y', num_values,
                       marker=dict(color="red"))
    
    # In this case the order of the series is important because of the filling
    data = [lower_bound, upper_bound, forecast, actual]

    layout = go.Layout(yaxis=dict(title='MXN'), title=title, showlegend = False)
    fig = go.Figure(data=data, layout=layout)
    plotly.offline.plot(fig, filename='btc_mxn.html', auto_open=False)

show_forecast(cmp_df2, 15, 500, 'BTC')
