# %%
#Necesary imports.
import bitso
import pandas as pd
import numpy as np
from datetime import timezone
import datetime
from dateutil.tz import tzutc
import time
from fbprophet import Prophet
import matplotlib.pyplot as plt
from scipy.stats import boxcox
import warnings
warnings.filterwarnings('ignore')
import plotly.offline
from plotly import graph_objs as go

# %%
#Opening my api key and secret.
with open('../key.txt') as f:
    a = f.readlines()

with open('../secret.txt') as p:
    b = p.readlines()

#Using the api secret and key to call the api.
API_SECRET = [i.split('\n') for i in a][0][0]
API_KEY = [i.split('\n') for i in b][0][0]
api = bitso.Api(API_KEY, API_SECRET)

# %%
'''
marker for last_scrap on 19-12-22: 12992700, i save this marker so i can use it
the next time i'm scrapping
'''
#Defining the empyt lists of the elements we need from the api.
btc_mxn_date = []
btc_mxn_price = []
btc_mxn_volume = []
btc_mxn_hour = []
btc_mxn_side = []

#Marker than changes the time in the api calls.
mark = 12974700

#Datetime when the code is running
now = datetime.datetime.now(timezone.utc)

#While loop for scrapping the information we need
while 1:
    #limit of requests, the max we can get is 100
    limit = '100'
    #Calling the api trades, we use sort 'asc' so i't starts on the marker we want.
    trades = api.trades('btc_mxn', sort='asc', limit=limit, marker=mark)
    #Starting the counter so we don't raise the error of too many requests on the api.
    count = 0
    #printing the mark and the spaces, we need these so we know the last mark we use.
    print(mark)
    print('')
    print('')
    #if statement to break the while loop.
    if trades != []:
        #starting a for loop to append the elements we need from each trade to our lists
        for e in trades:
            #adding to the counter.
            count +=1
            # if statement so we just scrap elements before today.
            if e.created_at < now :
                #printing each trade so we can see that everythings is working fine.
                print(e)
                #scrapping the elements we need
                btc_mxn_price.append(e.price)
                btc_mxn_volume.append(e.amount)
                btc_mxn_hour.append(e.created_at.hour)
                btc_mxn_date.append(e.created_at.date())
                btc_mxn_side.append(e.maker_side)
        '''
        if statement that starts a timer when the count reachs 100, we can just get
        300 requests per minute so our timer waits 21 seconds before making the next
        100 requests. It also adds a thousand to our mark so it moves forward in time.
        '''
        if count == 100:
            time.sleep(21)
            count = 0
            mark = mark + 1000
            
    #else statement to break the loop.
    else:
        break
# Out:
# 12974700
#
#
# Trade(tid=12974701, price=134789.65, amount=0.00580247, maker_side=sell, created_at=2019-12-20 00:56:42+00:00)
# Trade(tid=12974702, price=134789.65, amount=0.00551235, maker_side=sell, created_at=2019-12-20 00:56:43+00:00)
# Trade(tid=12974703, price=134789.65, amount=0.00021129, maker_side=sell, created_at=2019-12-20 00:56:43+00:00)
# Trade(tid=12974705, price=134999.99, amount=0.01185185, maker_side=sell, created_at=2019-12-20 00:58:49+00:00)
# Trade(tid=12974706, price=134474.61, amount=0.00264331, maker_side=buy, created_at=2019-12-20 00:58:59+00:00)
# Trade(tid=12974709, price=134999.99, amount=0.05032713, maker_side=sell, created_at=2019-12-20 00:59:22+00:00)
# Trade(tid=12974710, price=135000.00, amount=0.03703704, maker_side=sell, created_at=2019-12-20 00:59:27+00:00)
# Trade(tid=12974711, price=135000.00, amount=0.01767489, maker_side=sell, created_at=2019-12-20 00:59:35+00:00)
# Trade(tid=12974712, price=134600.26, amount=0.00222459, maker_side=buy, created_at=2019-12-20 00:59:49+00:00)
# Trade(tid=12974826, price=134863.01, amount=0.00225365, maker_side=buy, created_at=2019-12-20 01:18:56+00:00)
# Trade(tid=12974827, price=134788.16, amount=0.00322567, maker_side=buy, created_at=2019-12-20 01:18:56+00:00)
# Trade(tid=12974828, price=134788.16, amount=0.00004689, maker_side=buy, created_at=2019-12-20 01:19:05+00:00)
# Trade(tid=12974829, price=134580.00, amount=0.00296200, maker_side=buy, created_at=2019-12-20 01:19:05+00:00)
# Trade(tid=12974830, price=134425.93, amount=0.00456472, maker_side=buy, created_at=2019-12-20 01:19:05+00:00)
# Trade(tid=12974832, price=135074.22, amount=0.00074033, maker_side=sell, created_at=2019-12-20 01:19:41+00:00)
# Trade(tid=12974834, price=135167.89, amount=0.00748654, maker_side=sell, created_at=2019-12-20 01:20:07+00:00)
# Trade(tid=12974838, price=135111.76, amount=0.00074013, maker_side=sell, created_at=2019-12-20 01:21:18+00:00)
# Trade(tid=12974840, price=135058.48, amount=0.03109764, maker_side=sell, created_at=2019-12-20 01:21:48+00:00)
# Trade(tid=12974841, price=135085.68, amount=0.00370135, maker_side=sell, created_at=2019-12-20 01:22:21+00:00)
# Trade(tid=12974843, price=135249.50, amount=0.00358966, maker_side=sell, created_at=2019-12-20 01:22:41+00:00)
# Trade(tid=12974844, price=135212.66, amount=0.00073958, maker_side=sell, created_at=2019-12-20 01:22:51+00:00)
# Trade(tid=12974845, price=134811.76, amount=0.00027900, maker_side=buy, created_at=2019-12-20 01:23:03+00:00)
# Trade(tid=12974846, price=134508.01, amount=0.01186511, maker_side=buy, created_at=2019-12-20 01:23:03+00:00)
# Trade(tid=12974848, price=135050.60, amount=0.00074029, maker_side=sell, created_at=2019-12-20 01:23:41+00:00)
# Trade(tid=12974853, price=135120.37, amount=0.00518057, maker_side=sell, created_at=2019-12-20 01:24:16+00:00)
# Trade(tid=12974857, price=134551.07, amount=0.01570957, maker_side=buy, created_at=2019-12-20 01:25:13+00:00)
# Trade(tid=12974858, price=134363.54, amount=0.00743788, maker_side=buy, created_at=2019-12-20 01:25:47+00:00)
# Trade(tid=12974860, price=134970.75, amount=0.00862172, maker_side=sell, created_at=2019-12-20 01:26:24+00:00)
# Trade(tid=12974861, price=134981.48, amount=0.04815475, maker_side=sell, created_at=2019-12-20 01:26:51+00:00)
# Trade(tid=12974869, price=134702.47, amount=0.00074238, maker_side=sell, created_at=2019-12-20 01:29:57+00:00)
# Trade(tid=12974872, price=134407.58, amount=0.00748874, maker_side=buy, created_at=2019-12-20 01:30:26+00:00)
# Trade(tid=12974874, price=134702.47, amount=0.00403675, maker_side=sell, created_at=2019-12-20 01:30:44+00:00)
# Trade(tid=12974878, price=134410.11, amount=0.09249009, maker_side=buy, created_at=2019-12-20 01:31:22+00:00)
# Trade(tid=12974879, price=134408.06, amount=0.03029695, maker_side=buy, created_at=2019-12-20 01:31:22+00:00)
# Trade(tid=12974880, price=134408.05, amount=0.06975126, maker_side=buy, created_at=2019-12-20 01:31:22+00:00)
# Trade(tid=12974881, price=134702.47, amount=0.01229554, maker_side=sell, created_at=2019-12-20 01:31:34+00:00)
# Trade(tid=12974882, price=134977.56, amount=0.04699863, maker_side=sell, created_at=2019-12-20 01:31:34+00:00)
# Trade(tid=12974884, price=134887.48, amount=0.00148272, maker_side=sell, created_at=2019-12-20 01:31:57+00:00)
# Trade(tid=12974891, price=134360.01, amount=0.00074914, maker_side=buy, created_at=2019-12-20 01:32:55+00:00)
# Trade(tid=12974893, price=134360.01, amount=0.02632966, maker_side=buy, created_at=2019-12-20 01:33:08+00:00)
# Trade(tid=12974900, price=134848.60, amount=0.02877301, maker_side=sell, created_at=2019-12-20 01:33:54+00:00)
# Trade(tid=12974902, price=134360.01, amount=0.00079528, maker_side=buy, created_at=2019-12-20 01:34:07+00:00)
# Trade(tid=12974903, price=134784.11, amount=0.00348468, maker_side=sell, created_at=2019-12-20 01:34:25+00:00)
# Trade(tid=12974905, price=134360.01, amount=0.00364081, maker_side=buy, created_at=2019-12-20 01:34:52+00:00)
# 12975700
#
#
# Trade(tid=12975702, price=135000.00, amount=0.00018297, maker_side=buy, created_at=2019-12-20 04:32:52+00:00)
# Trade(tid=12975703, price=134900.00, amount=0.00034803, maker_side=buy, created_at=2019-12-20 04:32:52+00:00)
# Trade(tid=12975705, price=135471.75, amount=0.00811977, maker_side=sell, created_at=2019-12-20 04:34:46+00:00)
# Trade(tid=12975707, price=134900.00, amount=0.00007462, maker_side=buy, created_at=2019-12-20 04:36:13+00:00)
# Trade(tid=12975711, price=135384.97, amount=0.00003693, maker_side=sell, created_at=2019-12-20 04:36:43+00:00)
# Trade(tid=12975712, price=135383.10, amount=0.00062936, maker_side=sell, created_at=2019-12-20 04:37:27+00:00)
# Trade(tid=12975718, price=135490.57, amount=0.01074983, maker_side=sell, created_at=2019-12-20 04:38:10+00:00)
# Trade(tid=12975719, price=135407.88, amount=0.00369255, maker_side=sell, created_at=2019-12-20 04:38:54+00:00)
# Trade(tid=12975722, price=134900.95, amount=0.00197934, maker_side=buy, created_at=2019-12-20 04:39:43+00:00)
# Trade(tid=12975723, price=135464.85, amount=0.00562170, maker_side=sell, created_at=2019-12-20 04:39:47+00:00)
# Trade(tid=12975727, price=134902.30, amount=0.08819130, maker_side=buy, created_at=2019-12-20 04:40:37+00:00)
# Trade(tid=12975728, price=134904.42, amount=0.00035678, maker_side=buy, created_at=2019-12-20 04:41:26+00:00)
# Trade(tid=12975729, price=134905.13, amount=0.00030591, maker_side=buy, created_at=2019-12-20 04:41:41+00:00)
# Trade(tid=12975730, price=135340.91, amount=0.00251107, maker_side=sell, created_at=2019-12-20 04:42:08+00:00)
# Trade(tid=12975736, price=134905.95, amount=0.00339955, maker_side=buy, created_at=2019-12-20 04:42:54+00:00)
# Trade(tid=12975738, price=135378.53, amount=0.00120196, maker_side=sell, created_at=2019-12-20 04:44:28+00:00)
# Trade(tid=12975739, price=134911.94, amount=0.00618498, maker_side=buy, created_at=2019-12-20 04:44:52+00:00)
# Trade(tid=12978765, price=135445.43, amount=0.00738305, maker_side=sell, created_at=2019-12-20 16:41:55+00:00)
# Trade(tid=12978769, price=135058.48, amount=0.01450000, maker_side=buy, created_at=2019-12-20 16:42:10+00:00)
# Trade(tid=12978774, price=135445.01, amount=0.00373583, maker_side=sell, created_at=2019-12-20 16:43:17+00:00)
# ...
# Trade(tid=13000867, price=138200.27, amount=0.14614548, maker_side=buy, created_at=2019-12-23 19:01:56+00:00)
# Trade(tid=13000868, price=138200.26, amount=0.00010000, maker_side=buy, created_at=2019-12-23 19:01:56+00:00)
# Trade(tid=13000869, price=138200.26, amount=0.15383736, maker_side=buy, created_at=2019-12-23 19:01:56+00:00)
# Trade(tid=13000870, price=138200.24, amount=3.54607979, maker_side=buy, created_at=2019-12-23 19:01:56+00:00)
# Trade(tid=13000871, price=138200.00, amount=0.00010000, maker_side=buy, created_at=2019-12-23 19:01:58+00:00)
# Trade(tid=13000872, price=138200.31, amount=0.00010000, maker_side=buy, created_at=2019-12-23 19:01:58+00:00)
# Trade(tid=13000873, price=138667.80, amount=0.08359285, maker_side=sell, created_at=2019-12-23 19:02:07+00:00)
# Trade(tid=13000874, price=138667.82, amount=0.18601764, maker_side=sell, created_at=2019-12-23 19:02:07+00:00)
# Trade(tid=13000875, price=138667.84, amount=0.31456234, maker_side=sell, created_at=2019-12-23 19:02:07+00:00)
# Trade(tid=13000876, price=138667.80, amount=0.18601764, maker_side=sell, created_at=2019-12-23 19:02:10+00:00)
# Trade(tid=13000877, price=138667.82, amount=0.00089907, maker_side=sell, created_at=2019-12-23 19:02:10+00:00)
# Trade(tid=13000878, price=138200.15, amount=0.01460000, maker_side=buy, created_at=2019-12-23 19:02:11+00:00)
# Trade(tid=13000879, price=138667.81, amount=0.03180902, maker_side=sell, created_at=2019-12-23 19:02:12+00:00)
# Trade(tid=13000880, price=138667.81, amount=0.00015374, maker_side=sell, created_at=2019-12-23 19:02:12+00:00)
# Trade(tid=13000881, price=138667.79, amount=0.03180902, maker_side=sell, created_at=2019-12-23 19:02:15+00:00)
# Trade(tid=13000882, price=138667.80, amount=0.00015374, maker_side=sell, created_at=2019-12-23 19:02:15+00:00)
# Trade(tid=13000883, price=138667.79, amount=0.01331676, maker_side=sell, created_at=2019-12-23 19:02:17+00:00)
# Trade(tid=13000884, price=138667.80, amount=0.00006436, maker_side=sell, created_at=2019-12-23 19:02:17+00:00)
# Trade(tid=13000885, price=138667.77, amount=0.01331676, maker_side=sell, created_at=2019-12-23 19:02:19+00:00)
# Trade(tid=13000886, price=138667.78, amount=1.76877295, maker_side=sell, created_at=2019-12-23 19:02:19+00:00)
# Trade(tid=13000887, price=138667.78, amount=1.77351786, maker_side=sell, created_at=2019-12-23 19:02:22+00:00)
# Trade(tid=13000888, price=138667.79, amount=0.00857185, maker_side=sell, created_at=2019-12-23 19:02:22+00:00)
# Trade(tid=13000891, price=138667.66, amount=0.00239702, maker_side=sell, created_at=2019-12-23 19:02:46+00:00)
# Trade(tid=13000892, price=138667.66, amount=0.00120728, maker_side=sell, created_at=2019-12-23 19:02:46+00:00)
# Trade(tid=13000893, price=138667.62, amount=0.00091926, maker_side=sell, created_at=2019-12-23 19:02:52+00:00)
# Trade(tid=13000894, price=138667.62, amount=0.00087329, maker_side=sell, created_at=2019-12-23 19:02:52+00:00)
# Trade(tid=13000895, price=138667.63, amount=0.32993591, maker_side=sell, created_at=2019-12-23 19:02:52+00:00)
# Trade(tid=13000899, price=138667.54, amount=0.00057107, maker_side=sell, created_at=2019-12-23 19:03:15+00:00)
# Trade(tid=13000902, price=138667.47, amount=0.00017510, maker_side=sell, created_at=2019-12-23 19:03:30+00:00)
# Trade(tid=13000903, price=138667.47, amount=0.00018431, maker_side=sell, created_at=2019-12-23 19:03:30+00:00)
# Trade(tid=13000904, price=138667.48, amount=0.06797652, maker_side=sell, created_at=2019-12-23 19:03:30+00:00)
# Trade(tid=13000906, price=138667.46, amount=0.00432690, maker_side=sell, created_at=2019-12-23 19:03:38+00:00)
# Trade(tid=13000907, price=138667.70, amount=0.00383240, maker_side=sell, created_at=2019-12-23 19:03:47+00:00)
# Trade(tid=13000908, price=138667.69, amount=0.07799850, maker_side=sell, created_at=2019-12-23 19:04:04+00:00)
# Trade(tid=13000909, price=138667.69, amount=0.40193330, maker_side=sell, created_at=2019-12-23 19:04:06+00:00)
# Trade(tid=13000910, price=138667.70, amount=0.60289995, maker_side=sell, created_at=2019-12-23 19:04:09+00:00)
# Trade(tid=13000911, price=138667.70, amount=0.20096665, maker_side=sell, created_at=2019-12-23 19:04:11+00:00)
# Trade(tid=13000912, price=138667.69, amount=0.10048332, maker_side=sell, created_at=2019-12-23 19:04:14+00:00)
# Trade(tid=13000913, price=138667.70, amount=0.10048332, maker_side=sell, created_at=2019-12-23 19:04:17+00:00)
# Trade(tid=13000914, price=138667.97, amount=0.00721147, maker_side=sell, created_at=2019-12-23 19:04:36+00:00)
# Trade(tid=13000917, price=138667.97, amount=0.00721147, maker_side=sell, created_at=2019-12-23 19:04:40+00:00)
# Trade(tid=13000921, price=138600.00, amount=0.00721501, maker_side=buy, created_at=2019-12-23 19:04:55+00:00)
# Trade(tid=13000922, price=138500.05, amount=0.10000000, maker_side=buy, created_at=2019-12-23 19:05:17+00:00)
# Trade(tid=13000923, price=138500.05, amount=0.00112310, maker_side=buy, created_at=2019-12-23 19:05:21+00:00)
# 13001700
#
#
# Trade(tid=13001701, price=139792.91, amount=0.00946702, maker_side=sell, created_at=2019-12-23 20:36:10+00:00)
# Trade(tid=13001702, price=139792.92, amount=0.00729169, maker_side=sell, created_at=2019-12-23 20:36:10+00:00)
# Trade(tid=13001703, price=139112.28, amount=0.00060000, maker_side=buy, created_at=2019-12-23 20:36:16+00:00)
# Trade(tid=13001705, price=139113.51, amount=0.08682486, maker_side=buy, created_at=2019-12-23 20:36:39+00:00)
# Trade(tid=13001706, price=139113.52, amount=0.00614219, maker_side=buy, created_at=2019-12-23 20:37:08+00:00)
# Trade(tid=13001708, price=139792.63, amount=0.00065490, maker_side=sell, created_at=2019-12-23 20:37:12+00:00)
# Trade(tid=13001713, price=139113.80, amount=0.00072354, maker_side=buy, created_at=2019-12-23 20:37:44+00:00)
# Trade(tid=13001714, price=139113.66, amount=0.01374727, maker_side=buy, created_at=2019-12-23 20:37:55+00:00)
# Trade(tid=13001715, price=139792.58, amount=0.03219055, maker_side=sell, created_at=2019-12-23 20:37:57+00:00)
# Trade(tid=13001716, price=139792.48, amount=0.00005723, maker_side=sell, created_at=2019-12-23 20:38:21+00:00)
# Trade(tid=13001717, price=139113.60, amount=0.00120000, maker_side=buy, created_at=2019-12-23 20:38:45+00:00)
# Trade(tid=13001720, price=139113.60, amount=0.00023768, maker_side=buy, created_at=2019-12-23 20:39:17+00:00)
# Trade(tid=13001721, price=139110.89, amount=0.00030997, maker_side=buy, created_at=2019-12-23 20:39:17+00:00)
# Trade(tid=13001722, price=139100.01, amount=0.00505540, maker_side=buy, created_at=2019-12-23 20:39:17+00:00)
# Trade(tid=13001723, price=139789.98, amount=0.02718364, maker_side=sell, created_at=2019-12-23 20:39:29+00:00)
# Trade(tid=13001724, price=139789.55, amount=0.00715361, maker_side=sell, created_at=2019-12-23 20:39:55+00:00)
# Trade(tid=13001725, price=139789.47, amount=0.00611282, maker_side=sell, created_at=2019-12-23 20:40:04+00:00)
# Trade(tid=13001726, price=139789.49, amount=0.02653285, maker_side=sell, created_at=2019-12-23 20:40:04+00:00)
# Trade(tid=13001727, price=139789.50, amount=0.03755481, maker_side=sell, created_at=2019-12-23 20:40:04+00:00)
# Trade(tid=13001728, price=139789.50, amount=0.03953138, maker_side=sell, created_at=2019-12-23 20:40:04+00:00)
# Trade(tid=13001729, price=139789.51, amount=0.60562941, maker_side=sell, created_at=2019-12-23 20:40:04+00:00)
# Trade(tid=13001731, price=139789.36, amount=0.00752974, maker_side=sell, created_at=2019-12-23 20:40:26+00:00)
# Trade(tid=13001732, price=139789.36, amount=0.00792604, maker_side=sell, created_at=2019-12-23 20:40:26+00:00)
# Trade(tid=13001733, price=139789.37, amount=0.25995858, maker_side=sell, created_at=2019-12-23 20:40:26+00:00)
# Trade(tid=13001734, price=139100.00, amount=0.00300000, maker_side=buy, created_at=2019-12-23 20:40:41+00:00)
# Trade(tid=13001742, price=139787.84, amount=0.00357685, maker_side=sell, created_at=2019-12-23 20:41:34+00:00)
# Trade(tid=13001743, price=139100.00, amount=0.00233515, maker_side=buy, created_at=2019-12-23 20:41:35+00:00)
# Trade(tid=13001744, price=139100.10, amount=0.06693688, maker_side=buy, created_at=2019-12-23 20:41:47+00:00)
# Trade(tid=13001747, price=139100.02, amount=0.00143782, maker_side=buy, created_at=2019-12-23 20:42:01+00:00)
# Trade(tid=13001748, price=139100.01, amount=0.28213799, maker_side=buy, created_at=2019-12-23 20:42:01+00:00)
# Trade(tid=13001749, price=139100.01, amount=0.29698736, maker_side=buy, created_at=2019-12-23 20:42:01+00:00)
# Trade(tid=13001750, price=139100.00, amount=0.13844638, maker_side=buy, created_at=2019-12-23 20:42:01+00:00)
# Trade(tid=13001753, price=139099.99, amount=0.02587065, maker_side=sell, created_at=2019-12-23 20:42:04+00:00)
# Trade(tid=13001754, price=139099.99, amount=0.01007471, maker_side=sell, created_at=2019-12-23 20:42:04+00:00)
# Trade(tid=13001755, price=139100.00, amount=0.28099045, maker_side=sell, created_at=2019-12-23 20:42:04+00:00)
# Trade(tid=13001761, price=139786.62, amount=0.09654608, maker_side=sell, created_at=2019-12-23 20:43:50+00:00)
# Trade(tid=13001762, price=139101.96, amount=0.13020254, maker_side=buy, created_at=2019-12-23 20:44:05+00:00)
# Trade(tid=13001763, price=139101.96, amount=0.08969666, maker_side=buy, created_at=2019-12-23 20:44:05+00:00)
# Trade(tid=13001764, price=139101.95, amount=0.13020254, maker_side=buy, created_at=2019-12-23 20:44:05+00:00)
# Trade(tid=13001765, price=139101.92, amount=0.00248499, maker_side=buy, created_at=2019-12-23 20:44:05+00:00)
# Trade(tid=13001770, price=139786.27, amount=0.00071538, maker_side=sell, created_at=2019-12-23 20:44:58+00:00)
# Trade(tid=13001775, price=139786.09, amount=0.03150528, maker_side=sell, created_at=2019-12-23 20:45:33+00:00)
# Trade(tid=13001776, price=139107.89, amount=0.07203893, maker_side=buy, created_at=2019-12-23 20:45:58+00:00)
# Trade(tid=13001777, price=139107.88, amount=0.06604357, maker_side=buy, created_at=2019-12-23 20:45:58+00:00)
# Trade(tid=13001778, price=139107.88, amount=0.06951954, maker_side=buy, created_at=2019-12-23 20:45:58+00:00)
# Trade(tid=13001779, price=139107.87, amount=0.07203893, maker_side=buy, created_at=2019-12-23 20:45:58+00:00)
# Trade(tid=13001780, price=139107.85, amount=0.06951954, maker_side=buy, created_at=2019-12-23 20:45:58+00:00)
# Trade(tid=13001781, price=139107.84, amount=0.07203893, maker_side=buy, created_at=2019-12-23 20:45:58+00:00)
# Trade(tid=13001782, price=139100.00, amount=0.00002992, maker_side=buy, created_at=2019-12-23 20:45:58+00:00)
# Trade(tid=13001783, price=139000.00, amount=0.01784733, maker_side=buy, created_at=2019-12-23 20:45:58+00:00)
# Trade(tid=13001784, price=138870.00, amount=0.00129618, maker_side=buy, created_at=2019-12-23 20:45:58+00:00)
# Trade(tid=13001785, price=138671.47, amount=0.47975783, maker_side=buy, created_at=2019-12-23 20:45:58+00:00)
# Trade(tid=13001786, price=139785.88, amount=0.06331112, maker_side=sell, created_at=2019-12-23 20:46:15+00:00)
# Trade(tid=13001787, price=138673.89, amount=0.02649172, maker_side=buy, created_at=2019-12-23 20:47:03+00:00)
# Trade(tid=13001788, price=138673.87, amount=0.00544928, maker_side=buy, created_at=2019-12-23 20:47:03+00:00)
# Trade(tid=13001790, price=139785.55, amount=0.00064384, maker_side=sell, created_at=2019-12-23 20:47:19+00:00)
# Trade(tid=13001791, price=138674.77, amount=0.01739310, maker_side=buy, created_at=2019-12-23 20:47:22+00:00)
# Trade(tid=13001792, price=138674.74, amount=0.01739310, maker_side=buy, created_at=2019-12-23 20:47:22+00:00)
# Trade(tid=13001793, price=138674.73, amount=0.01104536, maker_side=buy, created_at=2019-12-23 20:47:22+00:00)
# Trade(tid=13001794, price=138674.73, amount=0.01162670, maker_side=buy, created_at=2019-12-23 20:47:22+00:00)
# Trade(tid=13001795, price=138674.68, amount=0.01739310, maker_side=buy, created_at=2019-12-23 20:47:22+00:00)
# Trade(tid=13001796, price=138673.00, amount=0.00144225, maker_side=buy, created_at=2019-12-23 20:47:22+00:00)
# Trade(tid=13001797, price=138672.83, amount=0.01739310, maker_side=sell, created_at=2019-12-23 20:47:22+00:00)
# Trade(tid=13001798, price=138672.83, amount=0.49704592, maker_side=sell, created_at=2019-12-23 20:47:23+00:00)
# Trade(tid=13001800, price=138672.83, amount=0.02924701, maker_side=sell, created_at=2019-12-23 20:47:24+00:00)
# Trade(tid=13001803, price=138672.82, amount=0.00018035, maker_side=sell, created_at=2019-12-23 20:47:39+00:00)
# Trade(tid=13001805, price=138672.83, amount=0.00000209, maker_side=sell, created_at=2019-12-23 20:47:39+00:00)
# Trade(tid=13001810, price=138617.00, amount=0.00288400, maker_side=buy, created_at=2019-12-23 20:48:08+00:00)
# Trade(tid=13001811, price=138478.15, amount=0.00780395, maker_side=buy, created_at=2019-12-23 20:48:08+00:00)
# Trade(tid=13001812, price=138478.15, amount=0.00031205, maker_side=buy, created_at=2019-12-23 20:48:08+00:00)
# Trade(tid=13001813, price=138672.83, amount=0.00001827, maker_side=sell, created_at=2019-12-23 20:48:18+00:00)
# Trade(tid=13001814, price=139785.48, amount=0.24339056, maker_side=sell, created_at=2019-12-23 20:48:18+00:00)
# Trade(tid=13001819, price=138480.66, amount=0.00284410, maker_side=buy, created_at=2019-12-23 20:49:05+00:00)
# Trade(tid=13001820, price=138480.87, amount=0.00036343, maker_side=buy, created_at=2019-12-23 20:49:09+00:00)
# Trade(tid=13001821, price=138481.38, amount=0.00669100, maker_side=buy, created_at=2019-12-23 20:49:16+00:00)
# Trade(tid=13001823, price=139785.16, amount=0.00107308, maker_side=sell, created_at=2019-12-23 20:49:30+00:00)
# Trade(tid=13001824, price=139785.16, amount=0.00017885, maker_side=sell, created_at=2019-12-23 20:49:31+00:00)
# Trade(tid=13001825, price=138482.97, amount=0.02543923, maker_side=buy, created_at=2019-12-23 20:49:40+00:00)
# Trade(tid=13001827, price=139785.06, amount=0.00207461, maker_side=sell, created_at=2019-12-23 20:49:55+00:00)
# Trade(tid=13001829, price=139000.00, amount=0.00013041, maker_side=sell, created_at=2019-12-23 20:50:09+00:00)
# Trade(tid=13001831, price=138999.99, amount=0.00018052, maker_side=sell, created_at=2019-12-23 20:50:12+00:00)
# Trade(tid=13001832, price=139000.00, amount=0.00000206, maker_side=sell, created_at=2019-12-23 20:50:12+00:00)
# Trade(tid=13001833, price=138485.61, amount=0.02201760, maker_side=buy, created_at=2019-12-23 20:50:21+00:00)
# Trade(tid=13001834, price=138485.92, amount=0.00508774, maker_side=buy, created_at=2019-12-23 20:50:24+00:00)
# Trade(tid=13001839, price=139000.00, amount=0.00000262, maker_side=sell, created_at=2019-12-23 20:51:08+00:00)
# Trade(tid=13001840, price=139784.72, amount=0.00357432, maker_side=sell, created_at=2019-12-23 20:51:08+00:00)
# Trade(tid=13001842, price=138490.62, amount=0.04360769, maker_side=buy, created_at=2019-12-23 20:51:46+00:00)
# Trade(tid=13001844, price=138491.61, amount=0.00508753, maker_side=buy, created_at=2019-12-23 20:52:10+00:00)
# Trade(tid=13001847, price=139100.00, amount=0.06604372, maker_side=sell, created_at=2019-12-23 20:52:33+00:00)
# Trade(tid=13001848, price=139100.00, amount=0.00581205, maker_side=sell, created_at=2019-12-23 20:52:33+00:00)
# Trade(tid=13001849, price=138492.50, amount=0.22605053, maker_side=buy, created_at=2019-12-23 20:52:37+00:00)
# Trade(tid=13001850, price=139100.00, amount=0.00003496, maker_side=sell, created_at=2019-12-23 20:53:05+00:00)
# Trade(tid=13001851, price=139723.39, amount=0.00272064, maker_side=sell, created_at=2019-12-23 20:53:05+00:00)
# Trade(tid=13001852, price=138493.81, amount=0.00700000, maker_side=buy, created_at=2019-12-23 20:53:11+00:00)
# Trade(tid=13001853, price=138493.81, amount=0.00161800, maker_side=buy, created_at=2019-12-23 20:53:12+00:00)
# Trade(tid=13001855, price=138495.02, amount=0.01310474, maker_side=buy, created_at=2019-12-23 20:53:43+00:00)
# Trade(tid=13001857, price=139297.58, amount=0.00071789, maker_side=sell, created_at=2019-12-23 20:54:14+00:00)
# Trade(tid=13001858, price=138496.76, amount=0.00200000, maker_side=buy, created_at=2019-12-23 20:54:29+00:00)
# Trade(tid=13001864, price=139722.27, amount=0.00958094, maker_side=sell, created_at=2019-12-23 20:55:11+00:00)
# Trade(tid=13001871, price=139717.87, amount=0.10735921, maker_side=sell, created_at=2019-12-23 20:57:02+00:00)
# 13002700

# %%
# creating a new data frame.
df = pd.DataFrame(columns=['price', 'volume', 'hour', 'date', 'side'])
# using the lists we got from the while loop to fill the dataframe.
df.price = btc_mxn_price
df.volume = btc_mxn_volume
df.hour = btc_mxn_hour
df.date = btc_mxn_date
df.side = btc_mxn_side
df.date = df.date.astype('datetime64')
#creating new columns with the month and day of each row.
df['month'] = [i.month for i in df.date]
df['day'] = [i.day for i in df.date]

# %%
#Creating a function that needs a data frame and a number(month) for input.
def extraction(df, m):
    #variable that get's just the row that matches the same month
    f_df = df.loc[df['month'] == m]
    #variable that stores the year
    y = datetime.datetime.today().year
    #variable that creates a list with the numbers of days of the month
    days = list(f_df['day'].unique())
    #varible that creates a empty dictionary
    results = {}
    #list with the names of the keys in the dictionary that the function returns.
    nombres = ['date', '24h_avg', '12h_avg', 'min', 'max', 'volume', 'm_side']
    
    #for loop that creates new keys in the empty dictionary with a empty list as values.
    for i in nombres:
        results[i] = []
    
    #for that loops on each day in the list of the days of the month.
    for e in days:
        #variable that get's just the rows that match the day in the for loop.
        ndf = f_df.loc[f_df.day == e]
        #appending the results in each dictionary key.
        results['date'].append(datetime.date(y, m, e))
        results['24h_avg'].append(ndf.price.mean())
        results['12h_avg'].append(ndf.price.loc[ndf.hour<12].mean())
        results['max'].append(ndf.price.max())
        results['min'].append(ndf.price.min())
        results['volume'].append(ndf.volume.sum())
        weight = ndf.side.value_counts().sum()
        buy = ndf.side.value_counts()['buy']/weight
        sell = ndf.side.value_counts()['sell']/weight
        if buy>sell:
            results['m_side'].append('buy')
        else:
            results['m_side'].append('sell')
            
    #returns the dictionary with the appended elements
    return results

# %%
#creating a variable that stores the month we are in.
month = datetime.datetime.today().month
#creating a new data frame using the dictionary from the above function and the month
df_new = pd.DataFrame.from_dict(extraction(df, month))

# %%
#Reading our csv file where we store the past data
history = pd.read_csv('../csv_files/historic_data.csv')

# %%
btc_df = pd.concat([history, df_new], ignore_index=True)

# %%
btc_df.drop_duplicates(inplace=True)

# %%
btc_df.drop(btc_df.tail(1).index,inplace=True)

# %%
btc_df.to_csv('../csv_files/historic_data.csv', index=False)

# %%
btc_df.date = btc_df.date.astype('datetime64')
btc_df['min'] = btc_df['min'].astype('float')
btc_df['max'] = btc_df['max'].astype('float')
btc_df.volume = btc_df.volume.astype('float')
btc_df['m_side'] = btc_df['m_side'].astype('category')

# %%
df_dum = pd.get_dummies(btc_df)
df_dum.rename(columns={'m_side_buy':'buy', 'm_side_sell':'sell'}, inplace=True)

# %%
change = []
for i in range(1,len(df_dum)):
    if df_dum.sell.iloc[i] != df_dum.sell.iloc[i-1]:
        change.append(df_dum.date.iloc[i])

# %%
#Selecting the columns we need for fbprophet
btc_24h_avg = btc_df[['date', '24h_avg']].copy()
#Changing the columns names for fbprophet to accept it.
btc_24h_avg.rename(columns={'date': 'ds', '24h_avg': 'y'}, inplace=True)

# %%
def inverse_boxcox(y, lambda_):
    return np.exp(y) if lambda_ == 0 else np.exp(np.log(lambda_ * y + 1) / lambda_)

# %%
def make_comparison_dataframe(historical, forecast):
    """Join the history with the forecast.
    
       The resulting dataset will contain columns 'yhat', 'yhat_lower', 'yhat_upper' and 'y'.
    """
    return forecast.set_index('ds')[['yhat', 'yhat_lower', 'yhat_upper']].join(historical.set_index('ds'))

# %%
def calculate_forecast_errors(df, prediction_size):
    """Calculate MAPE and MAE of the forecast.
    
       Args:
           df: joined dataset with 'y' and 'yhat' columns.
           prediction_size: number of days at the end to predict.
    """
    
    # Make a copy
    df = df.copy()
    df.dropna(inplace=True)
    
    # Now we calculate the values of e_i and p_i according to the formulas given in the article above.
    df['e'] = df['y'] - df['yhat']
    df['p'] = 100 * df['e'] / df['y']
    
    # Now cut out the part of the data which we made our prediction for.
    predicted_part = df[-prediction_size:]
    
    # Define the function that averages absolute error values over the predicted part.
    error_mean = lambda error_name: np.mean(np.abs(predicted_part[error_name]))
    
    # Now we can calculate MAPE and MAE and return the resulting dictionary of errors.
    return {'MAPE': error_mean('p'), 'MAE': error_mean('e')}

# %%
train_df = btc_24h_avg.copy().set_index('ds')

# %%
train_df['y'], lambda_prophet = boxcox(train_df['y'])
train_df.reset_index(inplace=True)

# %%
m2 = Prophet(changepoints=change, seasonality_mode='multiplicative')
m2.fit(train_df)
future2 = m2.make_future_dataframe(periods=15)
forecast2 = m2.predict(future2)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
for column in ['yhat', 'yhat_lower', 'yhat_upper']:
    forecast2[column] = inverse_boxcox(forecast2[column],
                                       lambda_prophet)

# %%
cmp_df2 = make_comparison_dataframe(btc_24h_avg, forecast2)
for err_name, err_value in calculate_forecast_errors(cmp_df2, 15).items():
     print(err_name, err_value)
# Out:
# MAPE 2.214534513894387
# MAE 2954.3483734151155

# %%
def show_forecast(cmp_df, num_predictions, num_values, title):
    """Visualize the forecast."""
    
    def create_go(name, column, num, **kwargs):
        points = cmp_df.tail(num)
        args = dict(name=name, x=points.index, y=points[column], mode='lines')
        args.update(kwargs)
        return go.Scatter(**args)
    
    lower_bound = create_go('Zona de compra', 'yhat_lower', num_predictions,
                            line=dict(width=0),
                            marker=dict(color="green"))
    upper_bound = create_go('Máximo esperado', 'yhat_upper', num_predictions,
                            line=dict(width=0),
                            marker=dict(color="red"),
                            fillcolor='rgba(68, 68, 68, 0.3)', 
                            fill='tonexty')
    forecast = create_go('Venta sugerida', 'yhat', num_predictions,
                         line=dict(color='rgb(31, 119, 180)'))
    actual = create_go('Actual', 'y', num_values,
                       marker=dict(color="red"))
    
    # In this case the order of the series is important because of the filling
    data = [lower_bound, upper_bound, forecast, actual]

    layout = go.Layout(yaxis=dict(title='MXN'), title=title, showlegend = False)
    fig = go.Figure(data=data, layout=layout)
    plotly.offline.plot(fig, filename='btc_mxn.html', auto_open=False)

show_forecast(cmp_df2, 15, 500, 'BTC')
