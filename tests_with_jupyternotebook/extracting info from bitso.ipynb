# %%
#Necesary imports.
import bitso
import pandas as pd
import numpy as np
from datetime import timezone
import datetime
from dateutil.tz import tzutc
import time
from fbprophet import Prophet
import matplotlib.pyplot as plt
from scipy.stats import boxcox
import warnings
warnings.filterwarnings('ignore')
import plotly.offline
from plotly import graph_objs as go

# %%
#Opening my api key and secret.
with open('../key.txt') as f:
    a = f.readlines()

with open('../secret.txt') as p:
    b = p.readlines()

#Using the api secret and key to call the api.
API_SECRET = [i.split('\n') for i in a][0][0]
API_KEY = [i.split('\n') for i in b][0][0]
api = bitso.Api(API_KEY, API_SECRET)

# %%
'''
marker for last_scrap on 22-1-2020: 9315734, I save this marker so i can use it
the next time i'm scrapping
'''
#Defining the empyt lists of the elements we need from the api.
btc_mxn_date = []
btc_mxn_price = []
btc_mxn_volume = []
btc_mxn_hour = []
btc_mxn_side = []

#Marker than changes the time in the api calls.
mark = 9428934


#While loop for scrapping the information we need
while 1:
    #limit of requests, the max we can get is 100
    limit = '100'
    #Calling the api trades, we use sort 'asc' so i't starts on the marker we want.
    trades = api.trades('btc_mxn', sort='asc', limit=limit, marker=mark)
    #Starting the counter so we don't raise the error of too many requests on the api.
    count = 0
    #printing the mark and the spaces, we need these so we know the last mark we use.
    print(mark)
    print('')
    print('')
    #if statement to break the while loop.
    if trades != []:
        #starting a for loop to append the elements we need from each trade to our lists
        for e in trades:
            #adding to the counter.
            count +=1
            # if statement so we just scrap elements before today.
            if e.created_at.year < 2019 :
                #printing each trade so we can see that everythings is working fine.
                print(e)
                #scrapping the elements we need
                btc_mxn_price.append(e.price)
                btc_mxn_volume.append(e.amount)
                btc_mxn_hour.append(e.created_at.hour)
                btc_mxn_date.append(e.created_at.date())
                btc_mxn_side.append(e.maker_side)
            else:
                break
        '''
        if statement that starts a timer when the count reachs 100, we can just get
        300 requests per minute so our timer waits 21 seconds before making the next
        100 requests. It also adds a thousand to our mark so it moves forward in time.
        '''
        if count == 100:
            time.sleep(21)
            count = 0
            mark = mark + 1000
            
    #else statement to break the loop.
    else:
        break
# Out:
# 9428934
#
#
# Trade(tid=9428941, price=84500.00, amount=0.00118343, maker_side=sell, created_at=2018-11-29 05:53:48+00:00)
# Trade(tid=9428942, price=84500.00, amount=0.00591716, maker_side=sell, created_at=2018-11-29 05:54:21+00:00)
# Trade(tid=9428961, price=84500.00, amount=0.01264395, maker_side=sell, created_at=2018-11-29 05:55:54+00:00)
# Trade(tid=9428962, price=85000.00, amount=0.00176471, maker_side=sell, created_at=2018-11-29 05:55:54+00:00)
# Trade(tid=9428963, price=85000.00, amount=0.00176471, maker_side=sell, created_at=2018-11-29 05:55:54+00:00)
# Trade(tid=9428964, price=85000.00, amount=0.00251366, maker_side=sell, created_at=2018-11-29 05:55:54+00:00)
# Trade(tid=9428965, price=85300.14, amount=0.03000000, maker_side=sell, created_at=2018-11-29 05:55:54+00:00)
# Trade(tid=9428966, price=85500.00, amount=0.00292398, maker_side=sell, created_at=2018-11-29 05:55:54+00:00)
# Trade(tid=9428967, price=85500.00, amount=0.00712187, maker_side=sell, created_at=2018-11-29 05:55:54+00:00)
# Trade(tid=9428970, price=85495.90, amount=0.00231996, maker_side=sell, created_at=2018-11-29 05:56:42+00:00)
# Trade(tid=9428971, price=85499.96, amount=0.00221996, maker_side=sell, created_at=2018-11-29 05:56:42+00:00)
# Trade(tid=9428972, price=85499.97, amount=0.00221996, maker_side=sell, created_at=2018-11-29 05:56:42+00:00)
# Trade(tid=9428973, price=85500.00, amount=0.00341567, maker_side=sell, created_at=2018-11-29 05:56:42+00:00)
# Trade(tid=9428975, price=84142.85, amount=0.00235896, maker_side=buy, created_at=2018-11-29 05:57:17+00:00)
# Trade(tid=9428983, price=84243.98, amount=0.01100000, maker_side=buy, created_at=2018-11-29 05:59:56+00:00)
# Trade(tid=9428988, price=85495.88, amount=0.00328328, maker_side=sell, created_at=2018-11-29 06:02:34+00:00)
# Trade(tid=9428989, price=85499.96, amount=0.00313328, maker_side=sell, created_at=2018-11-29 06:02:34+00:00)
# Trade(tid=9428990, price=85500.00, amount=0.01285428, maker_side=sell, created_at=2018-11-29 06:02:34+00:00)
# Trade(tid=9428991, price=85988.00, amount=0.00596415, maker_side=sell, created_at=2018-11-29 06:02:34+00:00)
# Trade(tid=9428992, price=85990.00, amount=0.01024637, maker_side=sell, created_at=2018-11-29 06:02:34+00:00)
# Trade(tid=9428993, price=86000.00, amount=0.00116280, maker_side=sell, created_at=2018-11-29 06:02:34+00:00)
# Trade(tid=9428994, price=86100.00, amount=0.00078006, maker_side=sell, created_at=2018-11-29 06:02:34+00:00)
# Trade(tid=9428995, price=86300.02, amount=0.00148599, maker_side=sell, created_at=2018-11-29 06:02:34+00:00)
# Trade(tid=9428996, price=86458.62, amount=0.08863224, maker_side=sell, created_at=2018-11-29 06:02:34+00:00)
# Trade(tid=9428997, price=86454.51, amount=0.00328328, maker_side=sell, created_at=2018-11-29 06:03:12+00:00)
# Trade(tid=9428998, price=86458.58, amount=0.00016916, maker_side=sell, created_at=2018-11-29 06:03:12+00:00)
# Trade(tid=9428999, price=86458.58, amount=0.00296412, maker_side=sell, created_at=2018-11-29 06:03:31+00:00)
# Trade(tid=9429000, price=86458.61, amount=0.99703588, maker_side=sell, created_at=2018-11-29 06:03:31+00:00)
# Trade(tid=9429003, price=84433.70, amount=0.01071236, maker_side=buy, created_at=2018-11-29 06:05:27+00:00)
# Trade(tid=9429016, price=84553.20, amount=0.00848000, maker_side=buy, created_at=2018-11-29 06:07:55+00:00)
# Trade(tid=9429018, price=84553.21, amount=0.00480700, maker_side=buy, created_at=2018-11-29 06:07:56+00:00)
# Trade(tid=9429019, price=84553.21, amount=0.00780500, maker_side=buy, created_at=2018-11-29 06:07:57+00:00)
# Trade(tid=9429021, price=84584.13, amount=0.01648493, maker_side=buy, created_at=2018-11-29 06:10:00+00:00)
# Trade(tid=9429022, price=86454.48, amount=0.00853320, maker_side=sell, created_at=2018-11-29 06:11:26+00:00)
# Trade(tid=9429023, price=86454.50, amount=0.00853320, maker_side=sell, created_at=2018-11-29 06:11:26+00:00)
# Trade(tid=9429024, price=86458.57, amount=0.00813332, maker_side=sell, created_at=2018-11-29 06:11:26+00:00)
# Trade(tid=9429025, price=86458.60, amount=0.00834316, maker_side=sell, created_at=2018-11-29 06:11:26+00:00)
# Trade(tid=9429028, price=86450.33, amount=1.01828807, maker_side=sell, created_at=2018-11-29 06:12:01+00:00)
# Trade(tid=9429042, price=86418.76, amount=0.00271932, maker_side=sell, created_at=2018-11-29 06:15:45+00:00)
# Trade(tid=9429044, price=84654.12, amount=0.00159759, maker_side=buy, created_at=2018-11-29 06:16:57+00:00)
# Trade(tid=9429059, price=86360.89, amount=0.00294332, maker_side=sell, created_at=2018-11-29 06:19:51+00:00)
# Trade(tid=9429060, price=86360.92, amount=0.05842703, maker_side=sell, created_at=2018-11-29 06:19:51+00:00)
# Trade(tid=9429065, price=84654.12, amount=0.01181277, maker_side=sell, created_at=2018-11-29 06:21:49+00:00)
# Trade(tid=9429070, price=84654.12, amount=0.00005906, maker_side=sell, created_at=2018-11-29 06:23:20+00:00)
# Trade(tid=9429072, price=84654.12, amount=0.00011813, maker_side=sell, created_at=2018-11-29 06:25:27+00:00)
# Trade(tid=9429074, price=84654.12, amount=0.02111200, maker_side=sell, created_at=2018-11-29 06:26:52+00:00)
# Trade(tid=9429075, price=86089.99, amount=0.15231483, maker_side=sell, created_at=2018-11-29 06:26:52+00:00)
# Trade(tid=9429078, price=84650.00, amount=0.00010049, maker_side=buy, created_at=2018-11-29 06:28:45+00:00)
# Trade(tid=9429082, price=84654.12, amount=0.00023781, maker_side=buy, created_at=2018-11-29 06:32:25+00:00)
# Trade(tid=9429088, price=85002.93, amount=0.00142900, maker_side=buy, created_at=2018-11-29 06:32:54+00:00)
# Trade(tid=9429090, price=85000.00, amount=0.00035295, maker_side=buy, created_at=2018-11-29 06:32:55+00:00)
# Trade(tid=9429091, price=84654.12, amount=0.00196405, maker_side=buy, created_at=2018-11-29 06:32:55+00:00)
# Trade(tid=9429092, price=85002.93, amount=0.00228399, maker_side=buy, created_at=2018-11-29 06:32:56+00:00)
# Trade(tid=9429093, price=84654.12, amount=0.00114001, maker_side=buy, created_at=2018-11-29 06:32:56+00:00)
# Trade(tid=9429096, price=84658.24, amount=0.00345900, maker_side=buy, created_at=2018-11-29 06:32:58+00:00)
# Trade(tid=9429109, price=84654.12, amount=0.00107400, maker_side=buy, created_at=2018-11-29 06:33:27+00:00)
# Trade(tid=9429112, price=84652.93, amount=0.00202399, maker_side=buy, created_at=2018-11-29 06:33:28+00:00)
# Trade(tid=9429113, price=84580.00, amount=0.00038716, maker_side=buy, created_at=2018-11-29 06:33:28+00:00)
# Trade(tid=9429116, price=84582.93, amount=0.00204399, maker_side=buy, created_at=2018-11-29 06:33:46+00:00)
# Trade(tid=9429117, price=84580.00, amount=0.00153601, maker_side=buy, created_at=2018-11-29 06:33:46+00:00)
# Trade(tid=9429119, price=84582.93, amount=0.00213990, maker_side=buy, created_at=2018-11-29 06:33:47+00:00)
# Trade(tid=9429120, price=84580.00, amount=0.00000400, maker_side=buy, created_at=2018-11-29 06:33:47+00:00)
# Trade(tid=9429122, price=84200.01, amount=0.00150000, maker_side=buy, created_at=2018-11-29 06:35:37+00:00)
# Trade(tid=9429124, price=84900.00, amount=0.00031200, maker_side=sell, created_at=2018-11-29 06:36:38+00:00)
# Trade(tid=9429127, price=84900.00, amount=0.00530035, maker_side=sell, created_at=2018-11-29 06:37:44+00:00)
# Trade(tid=9429130, price=84350.00, amount=0.00752400, maker_side=buy, created_at=2018-11-29 06:39:05+00:00)
# Trade(tid=9429136, price=84350.00, amount=0.09247600, maker_side=buy, created_at=2018-11-29 06:39:51+00:00)
# Trade(tid=9429137, price=84200.00, amount=0.00058647, maker_side=buy, created_at=2018-11-29 06:39:51+00:00)
# Trade(tid=9429138, price=84200.00, amount=0.05938243, maker_side=buy, created_at=2018-11-29 06:39:51+00:00)
# Trade(tid=9429139, price=84075.29, amount=0.03251527, maker_side=buy, created_at=2018-11-29 06:39:51+00:00)
# Trade(tid=9429140, price=84066.87, amount=0.00118953, maker_side=buy, created_at=2018-11-29 06:39:51+00:00)
# Trade(tid=9429141, price=84000.00, amount=0.00595239, maker_side=buy, created_at=2018-11-29 06:39:51+00:00)
# Trade(tid=9429142, price=84000.00, amount=0.00095900, maker_side=buy, created_at=2018-11-29 06:39:51+00:00)
# Trade(tid=9429143, price=83616.50, amount=0.05828244, maker_side=buy, created_at=2018-11-29 06:39:51+00:00)
# Trade(tid=9429146, price=84000.00, amount=0.00023821, maker_side=sell, created_at=2018-11-29 06:42:01+00:00)
# Trade(tid=9429148, price=83783.79, amount=0.00490000, maker_side=buy, created_at=2018-11-29 06:44:05+00:00)
# Trade(tid=9429151, price=84000.00, amount=0.00059524, maker_side=sell, created_at=2018-11-29 06:44:58+00:00)
# Trade(tid=9429155, price=84000.00, amount=0.00668825, maker_side=sell, created_at=2018-11-29 06:45:09+00:00)
# Trade(tid=9429156, price=84850.00, amount=0.01511288, maker_side=sell, created_at=2018-11-29 06:45:09+00:00)
# Trade(tid=9429157, price=85500.00, amount=0.00009999, maker_side=sell, created_at=2018-11-29 06:45:09+00:00)
# Trade(tid=9429158, price=86429.21, amount=0.20649628, maker_side=sell, created_at=2018-11-29 06:45:09+00:00)
# Trade(tid=9429159, price=84850.00, amount=0.00118200, maker_side=buy, created_at=2018-11-29 06:46:41+00:00)
# Trade(tid=9429160, price=83722.57, amount=0.00121800, maker_side=buy, created_at=2018-11-29 06:46:41+00:00)
# Trade(tid=9429161, price=86404.80, amount=0.00448998, maker_side=sell, created_at=2018-11-29 06:47:38+00:00)
# Trade(tid=9429162, price=86408.90, amount=0.02351002, maker_side=sell, created_at=2018-11-29 06:47:38+00:00)
# Trade(tid=9429164, price=84011.17, amount=0.73914832, maker_side=buy, created_at=2018-11-29 06:48:03+00:00)
# Trade(tid=9429167, price=86368.68, amount=0.05621251, maker_side=sell, created_at=2018-11-29 06:49:20+00:00)
# Trade(tid=9429168, price=86356.22, amount=0.01389593, maker_side=sell, created_at=2018-11-29 06:49:57+00:00)
# Trade(tid=9429169, price=84127.41, amount=0.01421041, maker_side=buy, created_at=2018-11-29 06:51:58+00:00)
# Trade(tid=9429178, price=86400.00, amount=0.00035736, maker_side=sell, created_at=2018-11-29 07:00:27+00:00)
# Trade(tid=9429179, price=86426.75, amount=0.00204164, maker_side=sell, created_at=2018-11-29 07:00:27+00:00)
# Trade(tid=9429180, price=86429.68, amount=0.01236360, maker_side=sell, created_at=2018-11-29 07:00:27+00:00)
# Trade(tid=9429181, price=86373.51, amount=0.15675328, maker_side=sell, created_at=2018-11-29 07:01:52+00:00)
# Trade(tid=9429182, price=86377.59, amount=0.14993328, maker_side=sell, created_at=2018-11-29 07:01:52+00:00)
# Trade(tid=9429183, price=86377.63, amount=0.61948671, maker_side=sell, created_at=2018-11-29 07:01:52+00:00)
# Trade(tid=9429184, price=86275.83, amount=0.00159012, maker_side=sell, created_at=2018-11-29 07:02:14+00:00)
# Trade(tid=9429186, price=84504.12, amount=0.00200000, maker_side=buy, created_at=2018-11-29 07:09:01+00:00)
# Trade(tid=9429198, price=84234.13, amount=0.01466665, maker_side=buy, created_at=2018-11-29 07:12:00+00:00)
# Trade(tid=9429201, price=85489.16, amount=0.00076033, maker_side=sell, created_at=2018-11-29 07:12:34+00:00)
# Trade(tid=9429203, price=84234.12, amount=0.02000828, maker_side=buy, created_at=2018-11-29 07:12:57+00:00)
# 9429934
#
#
# Trade(tid=9429935, price=87700.00, amount=0.00107100, maker_side=sell, created_at=2018-11-29 12:48:23+00:00)
# Trade(tid=9429938, price=87300.00, amount=0.04870600, maker_side=buy, created_at=2018-11-29 12:49:30+00:00)
# Trade(tid=9429942, price=87500.00, amount=0.02311406, maker_side=buy, created_at=2018-11-29 12:52:32+00:00)
# Trade(tid=9429947, price=87700.00, amount=0.01377500, maker_side=sell, created_at=2018-11-29 12:53:51+00:00)
# Trade(tid=9429948, price=87700.00, amount=0.00601200, maker_side=sell, created_at=2018-11-29 12:53:51+00:00)
# Trade(tid=9429949, price=87700.00, amount=0.01260100, maker_side=sell, created_at=2018-11-29 12:53:52+00:00)
# Trade(tid=9429950, price=87500.00, amount=0.00501166, maker_side=buy, created_at=2018-11-29 12:53:55+00:00)
# Trade(tid=9429951, price=87400.00, amount=0.11678434, maker_side=buy, created_at=2018-11-29 12:53:55+00:00)
# Trade(tid=9429954, price=87700.00, amount=0.04166400, maker_side=sell, created_at=2018-11-29 12:54:21+00:00)
# Trade(tid=9429955, price=87400.00, amount=0.11534610, maker_side=buy, created_at=2018-11-29 12:54:36+00:00)
# Trade(tid=9429956, price=87000.00, amount=0.00061771, maker_side=buy, created_at=2018-11-29 12:54:36+00:00)
# Trade(tid=9429959, price=86900.00, amount=0.00505100, maker_side=sell, created_at=2018-11-29 12:54:42+00:00)
# Trade(tid=9429960, price=86900.00, amount=0.00891700, maker_side=sell, created_at=2018-11-29 12:54:42+00:00)
# Trade(tid=9429962, price=86800.00, amount=0.34562212, maker_side=buy, created_at=2018-11-29 12:55:24+00:00)
# Trade(tid=9429963, price=86500.02, amount=2.50949620, maker_side=buy, created_at=2018-11-29 12:55:24+00:00)
# Trade(tid=9429965, price=86514.68, amount=0.00030000, maker_side=buy, created_at=2018-11-29 12:56:06+00:00)
# Trade(tid=9429971, price=86500.00, amount=0.02658960, maker_side=buy, created_at=2018-11-29 12:57:19+00:00)
# Trade(tid=9429979, price=86500.00, amount=0.14541040, maker_side=sell, created_at=2018-11-29 12:57:27+00:00)
# Trade(tid=9429980, price=88393.75, amount=0.01983860, maker_side=sell, created_at=2018-11-29 12:57:27+00:00)
# Trade(tid=9429997, price=88389.63, amount=0.08177000, maker_side=sell, created_at=2018-11-29 12:57:28+00:00)
# Trade(tid=9430008, price=87000.00, amount=0.00475500, maker_side=buy, created_at=2018-11-29 12:58:05+00:00)
# Trade(tid=9430040, price=87000.00, amount=0.05754386, maker_side=buy, created_at=2018-11-29 12:59:26+00:00)
# Trade(tid=9430083, price=86000.00, amount=0.00579300, maker_side=sell, created_at=2018-11-29 12:59:41+00:00)
# Trade(tid=9430085, price=86000.00, amount=0.00545700, maker_side=sell, created_at=2018-11-29 12:59:42+00:00)
# Trade(tid=9430086, price=86000.00, amount=0.00537200, maker_side=sell, created_at=2018-11-29 12:59:44+00:00)
# Trade(tid=9430089, price=86000.00, amount=0.00528800, maker_side=sell, created_at=2018-11-29 13:00:01+00:00)
# Trade(tid=9430090, price=86000.00, amount=0.00520500, maker_side=sell, created_at=2018-11-29 13:00:03+00:00)
# Trade(tid=9430093, price=86000.00, amount=0.00512400, maker_side=sell, created_at=2018-11-29 13:00:06+00:00)
# Trade(tid=9430094, price=86000.00, amount=0.04459500, maker_side=sell, created_at=2018-11-29 13:00:07+00:00)
# Trade(tid=9430098, price=85921.90, amount=0.00673200, maker_side=buy, created_at=2018-11-29 13:00:51+00:00)
# Trade(tid=9430099, price=85556.02, amount=0.02338270, maker_side=buy, created_at=2018-11-29 13:00:51+00:00)
# Trade(tid=9430100, price=85555.00, amount=0.04675356, maker_side=buy, created_at=2018-11-29 13:00:51+00:00)
# Trade(tid=9430101, price=85500.66, amount=0.04198797, maker_side=buy, created_at=2018-11-29 13:00:51+00:00)
# Trade(tid=9430102, price=85500.66, amount=0.00100000, maker_side=sell, created_at=2018-11-29 13:00:52+00:00)
# Trade(tid=9430105, price=85600.00, amount=0.00408100, maker_side=sell, created_at=2018-11-29 13:00:54+00:00)
# Trade(tid=9430106, price=85600.00, amount=0.01677100, maker_side=sell, created_at=2018-11-29 13:00:54+00:00)
# Trade(tid=9430108, price=85600.00, amount=0.00481400, maker_side=sell, created_at=2018-11-29 13:00:58+00:00)
# Trade(tid=9430110, price=85600.00, amount=0.00443800, maker_side=sell, created_at=2018-11-29 13:00:59+00:00)
# Trade(tid=9430120, price=85600.00, amount=0.03223900, maker_side=sell, created_at=2018-11-29 13:01:11+00:00)
# Trade(tid=9430121, price=85600.00, amount=0.01912500, maker_side=sell, created_at=2018-11-29 13:01:12+00:00)
# Trade(tid=9430122, price=85500.70, amount=0.64612768, maker_side=buy, created_at=2018-11-29 13:01:26+00:00)
# Trade(tid=9430150, price=85921.90, amount=0.00200500, maker_side=sell, created_at=2018-11-29 13:02:51+00:00)
# Trade(tid=9430152, price=85921.90, amount=0.00116200, maker_side=sell, created_at=2018-11-29 13:02:53+00:00)
# Trade(tid=9430154, price=85921.90, amount=0.00397900, maker_side=sell, created_at=2018-11-29 13:03:18+00:00)
# Trade(tid=9430156, price=85921.90, amount=0.00193200, maker_side=sell, created_at=2018-11-29 13:03:20+00:00)
# Trade(tid=9430157, price=85506.93, amount=0.11213403, maker_side=buy, created_at=2018-11-29 13:03:38+00:00)
# Trade(tid=9430165, price=85921.90, amount=0.00428600, maker_side=sell, created_at=2018-11-29 13:05:37+00:00)
# Trade(tid=9430166, price=85500.65, amount=0.04678328, maker_side=buy, created_at=2018-11-29 13:05:42+00:00)
# Trade(tid=9430167, price=85500.00, amount=0.04678363, maker_side=buy, created_at=2018-11-29 13:05:42+00:00)
# Trade(tid=9430168, price=85269.57, amount=0.10182472, maker_side=buy, created_at=2018-11-29 13:05:42+00:00)
# Trade(tid=9430169, price=85263.46, amount=0.00027635, maker_side=buy, created_at=2018-11-29 13:06:17+00:00)
# Trade(tid=9430171, price=85921.90, amount=0.01075696, maker_side=sell, created_at=2018-11-29 13:06:43+00:00)
# Trade(tid=9430172, price=85921.90, amount=0.15953915, maker_side=sell, created_at=2018-11-29 13:06:43+00:00)
# Trade(tid=9430173, price=87900.95, amount=0.40236010, maker_side=sell, created_at=2018-11-29 13:06:43+00:00)
# Trade(tid=9430178, price=85500.65, amount=0.00116800, maker_side=sell, created_at=2018-11-29 13:08:23+00:00)
# Trade(tid=9430180, price=85500.65, amount=0.00115730, maker_side=sell, created_at=2018-11-29 13:08:32+00:00)
# Trade(tid=9430185, price=85251.05, amount=0.00639893, maker_side=buy, created_at=2018-11-29 13:09:00+00:00)
# Trade(tid=9430188, price=85251.41, amount=0.24403100, maker_side=buy, created_at=2018-11-29 13:09:49+00:00)
# Trade(tid=9430189, price=85251.47, amount=0.75383041, maker_side=buy, created_at=2018-11-29 13:10:03+00:00)
# Trade(tid=9430190, price=85251.53, amount=0.01399228, maker_side=buy, created_at=2018-11-29 13:10:10+00:00)
# Trade(tid=9430191, price=85251.53, amount=1.37785302, maker_side=buy, created_at=2018-11-29 13:10:10+00:00)
# Trade(tid=9430194, price=85268.65, amount=0.11804369, maker_side=buy, created_at=2018-11-29 13:11:25+00:00)
# Trade(tid=9430196, price=85285.21, amount=0.12742332, maker_side=buy, created_at=2018-11-29 13:11:42+00:00)
# Trade(tid=9430197, price=85281.06, amount=1.22257668, maker_side=buy, created_at=2018-11-29 13:11:42+00:00)
# Trade(tid=9430205, price=86476.37, amount=0.00115639, maker_side=sell, created_at=2018-11-29 13:12:40+00:00)
# Trade(tid=9430209, price=86362.90, amount=0.00093790, maker_side=sell, created_at=2018-11-29 13:15:49+00:00)
# Trade(tid=9430226, price=86329.89, amount=0.00011477, maker_side=sell, created_at=2018-11-29 13:17:04+00:00)
# Trade(tid=9430227, price=86320.00, amount=0.02209755, maker_side=buy, created_at=2018-11-29 13:17:18+00:00)
# Trade(tid=9430245, price=85300.05, amount=0.15983992, maker_side=buy, created_at=2018-11-29 13:21:28+00:00)
# Trade(tid=9430247, price=86207.00, amount=0.00369667, maker_side=sell, created_at=2018-11-29 13:22:08+00:00)
# Trade(tid=9430248, price=86245.88, amount=0.03108927, maker_side=sell, created_at=2018-11-29 13:22:08+00:00)
# Trade(tid=9430257, price=86245.90, amount=0.11467212, maker_side=sell, created_at=2018-11-29 13:24:09+00:00)
# Trade(tid=9430258, price=86241.78, amount=0.00579765, maker_side=sell, created_at=2018-11-29 13:24:14+00:00)
# Trade(tid=9430264, price=86195.90, amount=0.02320296, maker_side=sell, created_at=2018-11-29 13:25:13+00:00)
# Trade(tid=9430265, price=85327.54, amount=2.63870265, maker_side=buy, created_at=2018-11-29 13:25:25+00:00)
# Trade(tid=9430275, price=86195.90, amount=0.34804440, maker_side=sell, created_at=2018-11-29 13:28:22+00:00)
# Trade(tid=9430276, price=86195.88, amount=0.03942764, maker_side=sell, created_at=2018-11-29 13:28:31+00:00)
# Trade(tid=9430277, price=85504.17, amount=0.01976994, maker_side=buy, created_at=2018-11-29 13:29:08+00:00)
# Trade(tid=9430278, price=85500.11, amount=0.53205203, maker_side=buy, created_at=2018-11-29 13:29:08+00:00)
# Trade(tid=9430279, price=86195.88, amount=0.52206672, maker_side=sell, created_at=2018-11-29 13:29:27+00:00)
# Trade(tid=9430280, price=85537.47, amount=0.01040522, maker_side=buy, created_at=2018-11-29 13:30:33+00:00)
# Trade(tid=9430281, price=86500.00, amount=0.22027873, maker_side=sell, created_at=2018-11-29 13:32:49+00:00)
# Trade(tid=9430289, price=85800.17, amount=0.64817652, maker_side=buy, created_at=2018-11-29 13:34:35+00:00)
# Trade(tid=9430290, price=86000.00, amount=0.01155349, maker_side=sell, created_at=2018-11-29 13:35:03+00:00)
# Trade(tid=9430291, price=85610.17, amount=0.04702911, maker_side=buy, created_at=2018-11-29 13:36:12+00:00)
# Trade(tid=9430292, price=85610.41, amount=0.00151210, maker_side=buy, created_at=2018-11-29 13:36:37+00:00)
# Trade(tid=9430297, price=85610.78, amount=0.00420615, maker_side=buy, created_at=2018-11-29 13:37:28+00:00)
# Trade(tid=9430299, price=85613.53, amount=3.00000000, maker_side=buy, created_at=2018-11-29 13:39:18+00:00)
# Trade(tid=9430300, price=86000.00, amount=1.00000000, maker_side=sell, created_at=2018-11-29 13:39:33+00:00)
# Trade(tid=9430301, price=86000.00, amount=0.50351013, maker_side=sell, created_at=2018-11-29 13:40:08+00:00)
# Trade(tid=9430302, price=86000.00, amount=0.49648987, maker_side=sell, created_at=2018-11-29 13:40:08+00:00)
# Trade(tid=9430303, price=86000.00, amount=0.32205813, maker_side=sell, created_at=2018-11-29 13:40:43+00:00)
# Trade(tid=9430313, price=86000.05, amount=0.00114699, maker_side=buy, created_at=2018-11-29 13:42:08+00:00)
# Trade(tid=9430315, price=86500.00, amount=0.00283596, maker_side=sell, created_at=2018-11-29 13:43:27+00:00)
# Trade(tid=9430316, price=86500.00, amount=0.00578035, maker_side=sell, created_at=2018-11-29 13:44:48+00:00)
# Trade(tid=9430317, price=86500.00, amount=0.27110496, maker_side=sell, created_at=2018-11-29 13:44:55+00:00)
# Trade(tid=9430318, price=86500.67, amount=0.00635164, maker_side=sell, created_at=2018-11-29 13:44:55+00:00)
# Trade(tid=9430319, price=86497.66, amount=0.00146399, maker_side=sell, created_at=2018-11-29 13:45:43+00:00)
# Trade(tid=9430320, price=86497.74, amount=0.00264399, maker_side=sell, created_at=2018-11-29 13:45:43+00:00)
# Trade(tid=9430321, price=86500.67, amount=0.42016633, maker_side=sell, created_at=2018-11-29 13:45:43+00:00)
# 9430934
#
#
# Trade(tid=9430935, price=86500.00, amount=0.19087862, maker_side=sell, created_at=2018-11-29 15:44:29+00:00)
# Trade(tid=9430938, price=86500.00, amount=0.00280636, maker_side=sell, created_at=2018-11-29 15:45:00+00:00)
# Trade(tid=9430940, price=86500.00, amount=0.05000000, maker_side=sell, created_at=2018-11-29 15:45:08+00:00)
# Trade(tid=9430942, price=86500.00, amount=0.04689299, maker_side=sell, created_at=2018-11-29 15:45:37+00:00)
# Trade(tid=9430943, price=86504.12, amount=0.00645000, maker_side=sell, created_at=2018-11-29 15:45:37+00:00)
# Trade(tid=9430944, price=86600.00, amount=0.00278066, maker_side=sell, created_at=2018-11-29 15:45:37+00:00)
# Trade(tid=9430945, price=86585.88, amount=0.01154923, maker_side=sell, created_at=2018-11-29 15:48:20+00:00)
# Trade(tid=9430948, price=86437.00, amount=0.25000000, maker_side=buy, created_at=2018-11-29 15:49:03+00:00)
# Trade(tid=9430950, price=86585.90, amount=0.14578598, maker_side=sell, created_at=2018-11-29 15:49:05+00:00)
# Trade(tid=9430951, price=86585.88, amount=0.00948192, maker_side=sell, created_at=2018-11-29 15:49:14+00:00)
# Trade(tid=9430952, price=86437.00, amount=0.00032879, maker_side=buy, created_at=2018-11-29 15:49:21+00:00)
# Trade(tid=9430953, price=86585.84, amount=0.42154699, maker_side=sell, created_at=2018-11-29 15:49:44+00:00)
# Trade(tid=9430954, price=86437.00, amount=0.01200000, maker_side=buy, created_at=2018-11-29 15:49:53+00:00)
# Trade(tid=9430956, price=86582.89, amount=0.00149475, maker_side=sell, created_at=2018-11-29 15:50:14+00:00)
# Trade(tid=9430957, price=86585.90, amount=0.45487103, maker_side=sell, created_at=2018-11-29 15:50:48+00:00)
# Trade(tid=9430966, price=86585.88, amount=0.01282218, maker_side=sell, created_at=2018-11-29 15:51:53+00:00)
# Trade(tid=9430974, price=86437.00, amount=0.01000829, maker_side=buy, created_at=2018-11-29 15:52:44+00:00)
# Trade(tid=9430975, price=86400.00, amount=0.16552171, maker_side=buy, created_at=2018-11-29 15:52:44+00:00)
# Trade(tid=9430976, price=86585.90, amount=0.00672858, maker_side=sell, created_at=2018-11-29 15:52:58+00:00)
# Trade(tid=9430978, price=86400.00, amount=0.01097494, maker_side=buy, created_at=2018-11-29 15:53:18+00:00)
# Trade(tid=9430983, price=86545.90, amount=0.00115546, maker_side=sell, created_at=2018-11-29 15:53:59+00:00)
# Trade(tid=9430984, price=86400.00, amount=0.01100000, maker_side=buy, created_at=2018-11-29 15:54:02+00:00)
# Trade(tid=9430985, price=86545.88, amount=0.01155457, maker_side=sell, created_at=2018-11-29 15:54:14+00:00)
# Trade(tid=9430989, price=86400.00, amount=0.14362800, maker_side=buy, created_at=2018-11-29 15:54:52+00:00)
# Trade(tid=9430994, price=86400.00, amount=0.00601852, maker_side=buy, created_at=2018-11-29 15:56:29+00:00)
# Trade(tid=9430999, price=86400.00, amount=0.03000000, maker_side=buy, created_at=2018-11-29 15:58:36+00:00)
# Trade(tid=9431004, price=86401.00, amount=0.00119406, maker_side=buy, created_at=2018-11-29 16:00:36+00:00)
# Trade(tid=9431007, price=86476.94, amount=0.00301164, maker_side=sell, created_at=2018-11-29 16:00:53+00:00)
# Trade(tid=9431008, price=86479.95, amount=0.29039372, maker_side=sell, created_at=2018-11-29 16:00:53+00:00)
# Trade(tid=9431009, price=86477.02, amount=0.00535164, maker_side=sell, created_at=2018-11-29 16:00:53+00:00)
# Trade(tid=9431010, price=86476.94, amount=0.00112284, maker_side=sell, created_at=2018-11-29 16:01:09+00:00)
# Trade(tid=9431012, price=86476.94, amount=0.00143164, maker_side=sell, created_at=2018-11-29 16:02:00+00:00)
# Trade(tid=9431013, price=86477.02, amount=0.00259164, maker_side=sell, created_at=2018-11-29 16:02:00+00:00)
# Trade(tid=9431014, price=86479.95, amount=0.00754023, maker_side=sell, created_at=2018-11-29 16:02:00+00:00)
# Trade(tid=9431020, price=86401.00, amount=0.00227813, maker_side=buy, created_at=2018-11-29 16:03:34+00:00)
# Trade(tid=9431021, price=86400.00, amount=0.00349283, maker_side=buy, created_at=2018-11-29 16:03:34+00:00)
# Trade(tid=9431022, price=86400.00, amount=0.55282993, maker_side=buy, created_at=2018-11-29 16:03:40+00:00)
# Trade(tid=9431023, price=86395.90, amount=0.00032409, maker_side=sell, created_at=2018-11-29 16:03:51+00:00)
# Trade(tid=9431032, price=86395.88, amount=0.00270233, maker_side=sell, created_at=2018-11-29 16:04:04+00:00)
# Trade(tid=9431033, price=86395.88, amount=0.39695328, maker_side=sell, created_at=2018-11-29 16:04:17+00:00)
# Trade(tid=9431034, price=86395.90, amount=0.39695328, maker_side=sell, created_at=2018-11-29 16:04:17+00:00)
# Trade(tid=9431035, price=86399.96, amount=0.26118723, maker_side=sell, created_at=2018-11-29 16:04:17+00:00)
# Trade(tid=9431045, price=86395.90, amount=0.00403550, maker_side=sell, created_at=2018-11-29 16:04:33+00:00)
# Trade(tid=9431047, price=85782.67, amount=0.04823570, maker_side=buy, created_at=2018-11-29 16:04:50+00:00)
# Trade(tid=9431048, price=85782.67, amount=0.04502323, maker_side=buy, created_at=2018-11-29 16:04:57+00:00)
# Trade(tid=9431049, price=85701.01, amount=0.46579128, maker_side=buy, created_at=2018-11-29 16:04:57+00:00)
# Trade(tid=9431063, price=86385.90, amount=0.00023152, maker_side=sell, created_at=2018-11-29 16:07:49+00:00)
# Trade(tid=9431066, price=86385.90, amount=0.00111395, maker_side=sell, created_at=2018-11-29 16:08:03+00:00)
# Trade(tid=9431071, price=85701.00, amount=0.01423554, maker_side=buy, created_at=2018-11-29 16:08:58+00:00)
# Trade(tid=9431072, price=85700.00, amount=0.00556124, maker_side=buy, created_at=2018-11-29 16:08:58+00:00)
# Trade(tid=9431073, price=85700.00, amount=0.00291716, maker_side=buy, created_at=2018-11-29 16:08:58+00:00)
# Trade(tid=9431074, price=85606.00, amount=0.01433381, maker_side=buy, created_at=2018-11-29 16:08:58+00:00)
# Trade(tid=9431075, price=85602.00, amount=0.00292050, maker_side=buy, created_at=2018-11-29 16:08:58+00:00)
# Trade(tid=9431076, price=85600.01, amount=0.00305980, maker_side=buy, created_at=2018-11-29 16:08:58+00:00)
# Trade(tid=9431077, price=85600.01, amount=0.00460338, maker_side=buy, created_at=2018-11-29 16:09:00+00:00)
# Trade(tid=9431079, price=86384.00, amount=0.00106910, maker_side=sell, created_at=2018-11-29 16:09:59+00:00)
# Trade(tid=9431080, price=86390.00, amount=0.01904010, maker_side=sell, created_at=2018-11-29 16:09:59+00:00)
# Trade(tid=9431081, price=86544.40, amount=0.00069164, maker_side=sell, created_at=2018-11-29 16:09:59+00:00)
# Trade(tid=9431082, price=86547.00, amount=0.00804874, maker_side=sell, created_at=2018-11-29 16:09:59+00:00)
# Trade(tid=9431083, price=86550.00, amount=0.02310804, maker_side=sell, created_at=2018-11-29 16:09:59+00:00)
# Trade(tid=9431084, price=86590.00, amount=0.00584733, maker_side=sell, created_at=2018-11-29 16:09:59+00:00)
# Trade(tid=9431087, price=85626.73, amount=0.06426881, maker_side=buy, created_at=2018-11-29 16:10:37+00:00)
# Trade(tid=9431088, price=86500.00, amount=0.00400000, maker_side=sell, created_at=2018-11-29 16:11:00+00:00)
# Trade(tid=9431089, price=86585.88, amount=0.16410632, maker_side=sell, created_at=2018-11-29 16:11:00+00:00)
# Trade(tid=9431091, price=85648.17, amount=0.03248920, maker_side=buy, created_at=2018-11-29 16:11:19+00:00)
# Trade(tid=9431093, price=86495.89, amount=0.02000858, maker_side=sell, created_at=2018-11-29 16:12:00+00:00)
# Trade(tid=9431094, price=86295.89, amount=0.06141660, maker_side=sell, created_at=2018-11-29 16:12:37+00:00)
# Trade(tid=9431097, price=86299.97, amount=0.02632840, maker_side=sell, created_at=2018-11-29 16:13:43+00:00)
# Trade(tid=9431100, price=86000.00, amount=0.05813954, maker_side=buy, created_at=2018-11-29 16:14:44+00:00)
# Trade(tid=9431101, price=85802.60, amount=0.06232660, maker_side=buy, created_at=2018-11-29 16:14:44+00:00)
# Trade(tid=9431102, price=85800.00, amount=0.01522920, maker_side=buy, created_at=2018-11-29 16:14:44+00:00)
# Trade(tid=9431105, price=85800.00, amount=0.00240748, maker_side=buy, created_at=2018-11-29 16:16:58+00:00)
# Trade(tid=9431107, price=86300.00, amount=0.02428582, maker_side=sell, created_at=2018-11-29 16:17:10+00:00)
# Trade(tid=9431108, price=86300.00, amount=0.00178602, maker_side=sell, created_at=2018-11-29 16:17:10+00:00)
# Trade(tid=9431111, price=86300.00, amount=0.01125145, maker_side=sell, created_at=2018-11-29 16:17:33+00:00)
# Trade(tid=9431122, price=86250.00, amount=0.00231884, maker_side=sell, created_at=2018-11-29 16:20:10+00:00)
# Trade(tid=9431125, price=86245.88, amount=0.10524994, maker_side=sell, created_at=2018-11-29 16:20:59+00:00)
# Trade(tid=9431126, price=86245.90, amount=0.10524994, maker_side=sell, created_at=2018-11-29 16:20:59+00:00)
# Trade(tid=9431127, price=86249.96, amount=0.10066994, maker_side=sell, created_at=2018-11-29 16:20:59+00:00)
# Trade(tid=9431128, price=86249.97, amount=0.10066994, maker_side=sell, created_at=2018-11-29 16:20:59+00:00)
# Trade(tid=9431129, price=86250.00, amount=0.17768116, maker_side=sell, created_at=2018-11-29 16:20:59+00:00)
# Trade(tid=9431130, price=86299.99, amount=0.02317498, maker_side=sell, created_at=2018-11-29 16:20:59+00:00)
# Trade(tid=9431131, price=86300.01, amount=0.54641306, maker_side=sell, created_at=2018-11-29 16:20:59+00:00)
# Trade(tid=9431135, price=86000.00, amount=0.00084980, maker_side=buy, created_at=2018-11-29 16:21:58+00:00)
# Trade(tid=9431138, price=86295.89, amount=0.01052994, maker_side=sell, created_at=2018-11-29 16:22:09+00:00)
# Trade(tid=9431139, price=86295.91, amount=0.00337570, maker_side=sell, created_at=2018-11-29 16:22:09+00:00)
# Trade(tid=9431143, price=86295.91, amount=0.00732994, maker_side=sell, created_at=2018-11-29 16:22:46+00:00)
# Trade(tid=9431144, price=86297.00, amount=0.01638197, maker_side=sell, created_at=2018-11-29 16:22:46+00:00)
# Trade(tid=9431145, price=86297.08, amount=0.00062275, maker_side=sell, created_at=2018-11-29 16:22:46+00:00)
# Trade(tid=9431149, price=86295.91, amount=0.00101268, maker_side=sell, created_at=2018-11-29 16:23:27+00:00)
# Trade(tid=9431156, price=86297.00, amount=0.00574516, maker_side=sell, created_at=2018-11-29 16:25:10+00:00)
# Trade(tid=9431158, price=86295.89, amount=0.00549940, maker_side=sell, created_at=2018-11-29 16:26:17+00:00)
# Trade(tid=9431159, price=86295.91, amount=0.00549940, maker_side=sell, created_at=2018-11-29 16:26:17+00:00)
# Trade(tid=9431160, price=86297.00, amount=0.00488197, maker_side=sell, created_at=2018-11-29 16:26:17+00:00)
# Trade(tid=9431161, price=86297.08, amount=0.00864197, maker_side=sell, created_at=2018-11-29 16:26:17+00:00)
# Trade(tid=9431162, price=86299.98, amount=0.00023143, maker_side=sell, created_at=2018-11-29 16:26:17+00:00)
# Trade(tid=9431163, price=86050.00, amount=0.05810576, maker_side=buy, created_at=2018-11-29 16:26:44+00:00)
# Trade(tid=9431164, price=86000.01, amount=0.03885779, maker_side=buy, created_at=2018-11-29 16:26:44+00:00)
# Trade(tid=9431165, price=86000.01, amount=4.90303645, maker_side=buy, created_at=2018-11-29 16:26:44+00:00)
# Trade(tid=9431166, price=86300.01, amount=0.11588875, maker_side=sell, created_at=2018-11-29 16:27:22+00:00)
# 9431934
#
#
# Trade(tid=9431950, price=87386.99, amount=0.00022887, maker_side=sell, created_at=2018-11-29 17:55:08+00:00)
# Trade(tid=9431961, price=87351.00, amount=0.00066807, maker_side=sell, created_at=2018-11-29 17:56:13+00:00)
# Trade(tid=9431962, price=87356.37, amount=0.00088798, maker_side=sell, created_at=2018-11-29 17:56:13+00:00)
# Trade(tid=9431963, price=87356.37, amount=0.00164798, maker_side=sell, created_at=2018-11-29 17:56:13+00:00)
# Trade(tid=9431964, price=87387.40, amount=0.00314798, maker_side=sell, created_at=2018-11-29 17:56:13+00:00)
# Trade(tid=9431965, price=87390.00, amount=0.01825171, maker_side=sell, created_at=2018-11-29 17:56:13+00:00)
# Trade(tid=9431971, price=87390.00, amount=0.04754222, maker_side=sell, created_at=2018-11-29 17:57:16+00:00)
# Trade(tid=9431972, price=87397.00, amount=0.00626862, maker_side=sell, created_at=2018-11-29 17:57:16+00:00)
# Trade(tid=9431973, price=87399.97, amount=0.00174401, maker_side=sell, created_at=2018-11-29 17:57:16+00:00)
# Trade(tid=9431974, price=87201.00, amount=0.40609316, maker_side=buy, created_at=2018-11-29 17:58:10+00:00)
# Trade(tid=9431975, price=87200.00, amount=0.00086927, maker_side=buy, created_at=2018-11-29 17:58:10+00:00)
# Trade(tid=9431977, price=87200.00, amount=0.02752294, maker_side=sell, created_at=2018-11-29 17:58:27+00:00)
# Trade(tid=9431978, price=87000.00, amount=0.00344828, maker_side=buy, created_at=2018-11-29 17:58:34+00:00)
# Trade(tid=9431979, price=87000.00, amount=0.00126281, maker_side=buy, created_at=2018-11-29 17:58:34+00:00)
# Trade(tid=9431994, price=87200.00, amount=0.00908500, maker_side=sell, created_at=2018-11-29 18:00:34+00:00)
# Trade(tid=9431995, price=87000.10, amount=0.00335632, maker_side=buy, created_at=2018-11-29 18:00:43+00:00)
# Trade(tid=9431996, price=87000.00, amount=0.00050282, maker_side=buy, created_at=2018-11-29 18:00:43+00:00)
# Trade(tid=9431998, price=87199.99, amount=0.01422900, maker_side=sell, created_at=2018-11-29 18:01:26+00:00)
# Trade(tid=9431999, price=87000.00, amount=0.05570564, maker_side=buy, created_at=2018-11-29 18:01:31+00:00)
# Trade(tid=9432000, price=86750.00, amount=0.00036550, maker_side=buy, created_at=2018-11-29 18:01:31+00:00)
# Trade(tid=9432003, price=87200.00, amount=0.01146789, maker_side=sell, created_at=2018-11-29 18:02:48+00:00)
# Trade(tid=9432004, price=87200.00, amount=0.01433486, maker_side=sell, created_at=2018-11-29 18:02:50+00:00)
# Trade(tid=9432006, price=87200.00, amount=0.00222970, maker_side=sell, created_at=2018-11-29 18:03:29+00:00)
# Trade(tid=9432013, price=86750.00, amount=0.00200000, maker_side=buy, created_at=2018-11-29 18:05:27+00:00)
# Trade(tid=9432015, price=87000.00, amount=0.05747126, maker_side=sell, created_at=2018-11-29 18:05:48+00:00)
# Trade(tid=9432017, price=86750.00, amount=0.03345237, maker_side=buy, created_at=2018-11-29 18:07:00+00:00)
# Trade(tid=9432018, price=86602.01, amount=0.00154763, maker_side=buy, created_at=2018-11-29 18:07:00+00:00)
# Trade(tid=9432024, price=87000.00, amount=0.00114100, maker_side=sell, created_at=2018-11-29 18:08:11+00:00)
# Trade(tid=9432025, price=86634.00, amount=0.00600000, maker_side=buy, created_at=2018-11-29 18:08:34+00:00)
# Trade(tid=9432026, price=87000.00, amount=0.00898322, maker_side=sell, created_at=2018-11-29 18:08:44+00:00)
# Trade(tid=9432029, price=87000.00, amount=0.00689655, maker_side=sell, created_at=2018-11-29 18:09:09+00:00)
# Trade(tid=9432030, price=87000.00, amount=0.42550797, maker_side=sell, created_at=2018-11-29 18:09:18+00:00)
# Trade(tid=9432031, price=87200.00, amount=0.37822748, maker_side=sell, created_at=2018-11-29 18:09:18+00:00)
# Trade(tid=9432034, price=87200.00, amount=0.12041284, maker_side=sell, created_at=2018-11-29 18:09:56+00:00)
# Trade(tid=9432038, price=86608.94, amount=0.00357266, maker_side=buy, created_at=2018-11-29 18:11:16+00:00)
# Trade(tid=9432039, price=86609.02, amount=0.00203266, maker_side=buy, created_at=2018-11-29 18:11:16+00:00)
# Trade(tid=9432040, price=86606.01, amount=0.09632894, maker_side=buy, created_at=2018-11-29 18:11:16+00:00)
# Trade(tid=9432041, price=87000.00, amount=0.39270000, maker_side=sell, created_at=2018-11-29 18:11:19+00:00)
# Trade(tid=9432042, price=87200.00, amount=0.17012729, maker_side=sell, created_at=2018-11-29 18:11:19+00:00)
# Trade(tid=9432052, price=87200.00, amount=0.00035550, maker_side=sell, created_at=2018-11-29 18:12:03+00:00)
# Trade(tid=9432053, price=87200.00, amount=0.01593550, maker_side=sell, created_at=2018-11-29 18:12:08+00:00)
# Trade(tid=9432054, price=87200.01, amount=0.00369397, maker_side=sell, created_at=2018-11-29 18:12:18+00:00)
# Trade(tid=9432055, price=87236.94, amount=0.00298596, maker_side=sell, created_at=2018-11-29 18:12:18+00:00)
# Trade(tid=9432057, price=87200.00, amount=0.00076543, maker_side=buy, created_at=2018-11-29 18:13:31+00:00)
# Trade(tid=9432058, price=87236.94, amount=0.00301404, maker_side=sell, created_at=2018-11-29 18:13:48+00:00)
# Trade(tid=9432059, price=87400.00, amount=0.05419982, maker_side=sell, created_at=2018-11-29 18:13:48+00:00)
# Trade(tid=9432060, price=87400.00, amount=0.06421785, maker_side=sell, created_at=2018-11-29 18:14:09+00:00)
# Trade(tid=9432063, price=87496.99, amount=0.00071266, maker_side=sell, created_at=2018-11-29 18:15:07+00:00)
# Trade(tid=9432064, price=87497.07, amount=0.00133266, maker_side=sell, created_at=2018-11-29 18:15:07+00:00)
# Trade(tid=9432065, price=87499.94, amount=0.00481190, maker_side=sell, created_at=2018-11-29 18:15:07+00:00)
# Trade(tid=9432074, price=87299.00, amount=0.00040081, maker_side=sell, created_at=2018-11-29 18:17:01+00:00)
# Trade(tid=9432075, price=87499.94, amount=0.11288416, maker_side=sell, created_at=2018-11-29 18:17:01+00:00)
# Trade(tid=9432077, price=87499.94, amount=0.00040081, maker_side=sell, created_at=2018-11-29 18:17:11+00:00)
# Trade(tid=9432078, price=87500.00, amount=0.00211348, maker_side=sell, created_at=2018-11-29 18:17:11+00:00)
# Trade(tid=9432081, price=87500.00, amount=0.41164538, maker_side=sell, created_at=2018-11-29 18:17:38+00:00)
# Trade(tid=9432085, price=87100.00, amount=0.00020467, maker_side=buy, created_at=2018-11-29 18:18:03+00:00)
# Trade(tid=9432086, price=87100.00, amount=0.00070252, maker_side=buy, created_at=2018-11-29 18:18:22+00:00)
# Trade(tid=9432087, price=87500.00, amount=0.00765703, maker_side=sell, created_at=2018-11-29 18:18:34+00:00)
# Trade(tid=9432090, price=87100.00, amount=0.00049030, maker_side=buy, created_at=2018-11-29 18:18:48+00:00)
# Trade(tid=9432091, price=87100.00, amount=0.01395635, maker_side=buy, created_at=2018-11-29 18:18:59+00:00)
# Trade(tid=9432093, price=87100.00, amount=0.10287751, maker_side=buy, created_at=2018-11-29 18:19:28+00:00)
# Trade(tid=9432094, price=87000.00, amount=0.00574713, maker_side=buy, created_at=2018-11-29 18:19:28+00:00)
# Trade(tid=9432095, price=87000.00, amount=0.02298851, maker_side=buy, created_at=2018-11-29 18:19:28+00:00)
# Trade(tid=9432096, price=86875.74, amount=0.04838685, maker_side=buy, created_at=2018-11-29 18:19:28+00:00)
# Trade(tid=9432101, price=87499.00, amount=0.17023100, maker_side=sell, created_at=2018-11-29 18:20:38+00:00)
# Trade(tid=9432103, price=87100.00, amount=0.05740529, maker_side=buy, created_at=2018-11-29 18:21:03+00:00)
# Trade(tid=9432104, price=87044.31, amount=0.00259471, maker_side=buy, created_at=2018-11-29 18:21:03+00:00)
# Trade(tid=9432106, price=87000.00, amount=0.00010000, maker_side=buy, created_at=2018-11-29 18:21:28+00:00)
# Trade(tid=9432113, price=87499.00, amount=0.00171431, maker_side=sell, created_at=2018-11-29 18:22:05+00:00)
# Trade(tid=9432116, price=87000.00, amount=0.00337800, maker_side=buy, created_at=2018-11-29 18:22:15+00:00)
# Trade(tid=9432117, price=87000.00, amount=0.00425800, maker_side=buy, created_at=2018-11-29 18:22:15+00:00)
# Trade(tid=9432118, price=87002.93, amount=0.00773639, maker_side=buy, created_at=2018-11-29 18:22:40+00:00)
# Trade(tid=9432119, price=87499.00, amount=0.08812398, maker_side=sell, created_at=2018-11-29 18:23:00+00:00)
# Trade(tid=9432123, price=87002.93, amount=0.03565197, maker_side=buy, created_at=2018-11-29 18:23:20+00:00)
# Trade(tid=9432124, price=87000.00, amount=0.07317633, maker_side=buy, created_at=2018-11-29 18:23:20+00:00)
# Trade(tid=9432125, price=87000.00, amount=0.01104170, maker_side=buy, created_at=2018-11-29 18:23:20+00:00)
# Trade(tid=9432126, price=86881.60, amount=0.04043197, maker_side=buy, created_at=2018-11-29 18:23:20+00:00)
# Trade(tid=9432127, price=86879.00, amount=0.00368904, maker_side=buy, created_at=2018-11-29 18:23:20+00:00)
# Trade(tid=9432128, price=86875.74, amount=0.00274865, maker_side=buy, created_at=2018-11-29 18:23:20+00:00)
# Trade(tid=9432135, price=87499.00, amount=0.00048481, maker_side=sell, created_at=2018-11-29 18:23:51+00:00)
# Trade(tid=9432136, price=86878.75, amount=0.04433197, maker_side=buy, created_at=2018-11-29 18:24:02+00:00)
# Trade(tid=9432137, price=86878.67, amount=0.01359605, maker_side=buy, created_at=2018-11-29 18:24:02+00:00)
# Trade(tid=9432138, price=86878.67, amount=0.01200000, maker_side=buy, created_at=2018-11-29 18:24:02+00:00)
# Trade(tid=9432139, price=87499.00, amount=0.05257203, maker_side=sell, created_at=2018-11-29 18:24:16+00:00)
# Trade(tid=9432140, price=86878.75, amount=0.03542197, maker_side=buy, created_at=2018-11-29 18:24:19+00:00)
# Trade(tid=9432141, price=86878.67, amount=0.02250606, maker_side=buy, created_at=2018-11-29 18:24:19+00:00)
# Trade(tid=9432142, price=86878.67, amount=0.02363197, maker_side=buy, created_at=2018-11-29 18:24:26+00:00)
# Trade(tid=9432143, price=86875.74, amount=0.03429725, maker_side=buy, created_at=2018-11-29 18:24:26+00:00)
# Trade(tid=9432144, price=86878.67, amount=0.00463425, maker_side=buy, created_at=2018-11-29 18:24:27+00:00)
# Trade(tid=9432147, price=86878.75, amount=0.02171197, maker_side=buy, created_at=2018-11-29 18:24:55+00:00)
# Trade(tid=9432148, price=86878.67, amount=0.03587182, maker_side=buy, created_at=2018-11-29 18:24:55+00:00)
# Trade(tid=9432150, price=86878.75, amount=0.01216197, maker_side=buy, created_at=2018-11-29 18:25:11+00:00)
# Trade(tid=9432151, price=86878.67, amount=0.02129197, maker_side=buy, created_at=2018-11-29 18:25:11+00:00)
# Trade(tid=9432152, price=86875.74, amount=0.02412985, maker_side=buy, created_at=2018-11-29 18:25:11+00:00)
# Trade(tid=9432153, price=86875.74, amount=0.03430956, maker_side=buy, created_at=2018-11-29 18:25:12+00:00)
# Trade(tid=9432154, price=86633.76, amount=0.03956197, maker_side=buy, created_at=2018-11-29 18:25:12+00:00)
# Trade(tid=9432155, price=86631.16, amount=0.01271292, maker_side=buy, created_at=2018-11-29 18:25:12+00:00)
# Trade(tid=9432156, price=87499.00, amount=0.01027387, maker_side=sell, created_at=2018-11-29 18:25:16+00:00)
# Trade(tid=9432157, price=87499.10, amount=0.00367060, maker_side=sell, created_at=2018-11-29 18:25:16+00:00)
# Trade(tid=9432158, price=87500.00, amount=0.04154140, maker_side=sell, created_at=2018-11-29 18:25:16+00:00)
# 9432934
#
#
# Trade(tid=9432939, price=85535.59, amount=0.06196251, maker_side=sell, created_at=2018-11-29 19:56:05+00:00)
# Trade(tid=9432943, price=85546.99, amount=0.00164798, maker_side=sell, created_at=2018-11-29 19:56:36+00:00)
# Trade(tid=9432944, price=85547.07, amount=0.00296798, maker_side=sell, created_at=2018-11-29 19:56:36+00:00)
# Trade(tid=9432945, price=85550.00, amount=0.02453154, maker_side=sell, created_at=2018-11-29 19:56:36+00:00)
# Trade(tid=9432946, price=85595.88, amount=0.00600018, maker_side=sell, created_at=2018-11-29 19:56:36+00:00)
# Trade(tid=9432947, price=85600.00, amount=0.01273919, maker_side=sell, created_at=2018-11-29 19:56:36+00:00)
# Trade(tid=9432948, price=85600.00, amount=0.00175234, maker_side=sell, created_at=2018-11-29 19:57:18+00:00)
# Trade(tid=9432949, price=85300.00, amount=0.00545000, maker_side=buy, created_at=2018-11-29 19:58:20+00:00)
# Trade(tid=9432954, price=85600.00, amount=0.01004673, maker_side=sell, created_at=2018-11-29 19:59:30+00:00)
# Trade(tid=9432955, price=85600.00, amount=0.01136682, maker_side=sell, created_at=2018-11-29 19:59:34+00:00)
# Trade(tid=9432956, price=85600.00, amount=0.01409492, maker_side=sell, created_at=2018-11-29 19:59:36+00:00)
# Trade(tid=9432957, price=85800.00, amount=0.00117002, maker_side=sell, created_at=2018-11-29 19:59:36+00:00)
# Trade(tid=9432958, price=85800.00, amount=0.00113673, maker_side=sell, created_at=2018-11-29 19:59:36+00:00)
# Trade(tid=9432959, price=85926.91, amount=0.01003825, maker_side=sell, created_at=2018-11-29 19:59:36+00:00)
# Trade(tid=9432967, price=85300.00, amount=0.00703400, maker_side=buy, created_at=2018-11-29 20:01:55+00:00)
# Trade(tid=9432971, price=85736.34, amount=0.02915916, maker_side=sell, created_at=2018-11-29 20:02:31+00:00)
# Trade(tid=9432980, price=85300.00, amount=0.00117234, maker_side=buy, created_at=2018-11-29 20:03:08+00:00)
# Trade(tid=9432981, price=85876.47, amount=0.00116446, maker_side=sell, created_at=2018-11-29 20:03:51+00:00)
# Trade(tid=9432984, price=85806.38, amount=0.01357708, maker_side=sell, created_at=2018-11-29 20:05:01+00:00)
# Trade(tid=9432987, price=85300.00, amount=0.00200000, maker_side=buy, created_at=2018-11-29 20:06:21+00:00)
# Trade(tid=9432991, price=85703.17, amount=0.02333636, maker_side=sell, created_at=2018-11-29 20:06:38+00:00)
# Trade(tid=9433001, price=85593.90, amount=0.03069763, maker_side=sell, created_at=2018-11-29 20:08:08+00:00)
# Trade(tid=9433004, price=85563.16, amount=0.10065425, maker_side=sell, created_at=2018-11-29 20:08:31+00:00)
# Trade(tid=9433012, price=85310.00, amount=0.03516590, maker_side=buy, created_at=2018-11-29 20:09:35+00:00)
# Trade(tid=9433013, price=85309.00, amount=0.11835530, maker_side=buy, created_at=2018-11-29 20:09:36+00:00)
# Trade(tid=9433014, price=85309.00, amount=0.11835530, maker_side=buy, created_at=2018-11-29 20:09:39+00:00)
# Trade(tid=9433015, price=85309.00, amount=0.11840247, maker_side=buy, created_at=2018-11-29 20:09:42+00:00)
# Trade(tid=9433016, price=85309.00, amount=0.11840247, maker_side=buy, created_at=2018-11-29 20:09:44+00:00)
# Trade(tid=9433017, price=85309.00, amount=0.11837973, maker_side=buy, created_at=2018-11-29 20:09:45+00:00)
# Trade(tid=9433018, price=85309.00, amount=0.11837973, maker_side=buy, created_at=2018-11-29 20:09:46+00:00)
# Trade(tid=9433019, price=85309.00, amount=0.11837973, maker_side=buy, created_at=2018-11-29 20:09:47+00:00)
# Trade(tid=9433020, price=85309.00, amount=0.11837973, maker_side=buy, created_at=2018-11-29 20:09:48+00:00)
# Trade(tid=9433021, price=85435.90, amount=0.18175332, maker_side=sell, created_at=2018-11-29 20:10:04+00:00)
# Trade(tid=9433022, price=85439.96, amount=0.17384332, maker_side=sell, created_at=2018-11-29 20:10:04+00:00)
# Trade(tid=9433023, price=85439.97, amount=0.17384332, maker_side=sell, created_at=2018-11-29 20:10:04+00:00)
# Trade(tid=9433024, price=85439.99, amount=0.64023332, maker_side=sell, created_at=2018-11-29 20:10:04+00:00)
# Trade(tid=9433025, price=85418.50, amount=0.00117071, maker_side=sell, created_at=2018-11-29 20:10:30+00:00)
# Trade(tid=9433026, price=85384.93, amount=0.05971332, maker_side=sell, created_at=2018-11-29 20:11:00+00:00)
# Trade(tid=9433027, price=85384.95, amount=0.00001619, maker_side=sell, created_at=2018-11-29 20:11:00+00:00)
# Trade(tid=9433039, price=85984.71, amount=0.00155842, maker_side=sell, created_at=2018-11-29 20:11:30+00:00)
# Trade(tid=9433040, price=85964.22, amount=0.00101659, maker_side=sell, created_at=2018-11-29 20:11:57+00:00)
# ...
# Trade(tid=9683135, price=73004.12, amount=0.03917300, maker_side=buy, created_at=2018-12-31 19:40:39+00:00)
# Trade(tid=9683136, price=73000.00, amount=0.10057320, maker_side=buy, created_at=2018-12-31 19:40:39+00:00)
# Trade(tid=9683137, price=73004.12, amount=0.10642680, maker_side=buy, created_at=2018-12-31 19:40:39+00:00)
# Trade(tid=9683138, price=73004.12, amount=0.04750000, maker_side=buy, created_at=2018-12-31 19:40:46+00:00)
# Trade(tid=9683140, price=73008.24, amount=0.00120600, maker_side=buy, created_at=2018-12-31 19:40:49+00:00)
# Trade(tid=9683146, price=73697.65, amount=0.19674983, maker_side=sell, created_at=2018-12-31 19:42:25+00:00)
# Trade(tid=9683147, price=73000.00, amount=0.00125001, maker_side=buy, created_at=2018-12-31 19:42:36+00:00)
# Trade(tid=9683150, price=73667.09, amount=0.00195399, maker_side=sell, created_at=2018-12-31 19:43:07+00:00)
# Trade(tid=9683151, price=73667.17, amount=0.00351399, maker_side=sell, created_at=2018-12-31 19:43:07+00:00)
# Trade(tid=9683152, price=73667.50, amount=0.00661399, maker_side=sell, created_at=2018-12-31 19:43:07+00:00)
# Trade(tid=9683153, price=73670.06, amount=0.00090109, maker_side=sell, created_at=2018-12-31 19:43:07+00:00)
# Trade(tid=9683158, price=73004.12, amount=0.01619980, maker_side=buy, created_at=2018-12-31 19:43:52+00:00)
# Trade(tid=9683159, price=73000.06, amount=0.02842998, maker_side=buy, created_at=2018-12-31 19:43:52+00:00)
# Trade(tid=9683160, price=73000.00, amount=0.37537022, maker_side=buy, created_at=2018-12-31 19:43:52+00:00)
# Trade(tid=9683170, price=73005.01, amount=0.08492568, maker_side=buy, created_at=2018-12-31 19:44:40+00:00)
# Trade(tid=9683179, price=73000.00, amount=0.48905956, maker_side=buy, created_at=2018-12-31 19:44:50+00:00)
# Trade(tid=9683187, price=72650.00, amount=0.02421423, maker_side=buy, created_at=2018-12-31 19:45:00+00:00)
# Trade(tid=9683188, price=72654.95, amount=0.06052568, maker_side=buy, created_at=2018-12-31 19:45:00+00:00)
# Trade(tid=9683189, price=73000.77, amount=0.04389406, maker_side=sell, created_at=2018-12-31 19:45:01+00:00)
# Trade(tid=9683191, price=72650.00, amount=0.04261303, maker_side=buy, created_at=2018-12-31 19:45:01+00:00)
# Trade(tid=9683208, price=72605.00, amount=0.13704291, maker_side=buy, created_at=2018-12-31 19:45:14+00:00)
# Trade(tid=9683209, price=72601.00, amount=0.13773915, maker_side=buy, created_at=2018-12-31 19:45:15+00:00)
# Trade(tid=9683215, price=72600.00, amount=0.13852286, maker_side=buy, created_at=2018-12-31 19:45:21+00:00)
# 9683934
#
#
# Trade(tid=9683936, price=71805.00, amount=0.00125119, maker_side=buy, created_at=2018-12-31 21:06:52+00:00)
# Trade(tid=9683937, price=71805.00, amount=0.02103895, maker_side=buy, created_at=2018-12-31 21:07:03+00:00)
# Trade(tid=9683938, price=71800.00, amount=0.05596105, maker_side=buy, created_at=2018-12-31 21:07:03+00:00)
# Trade(tid=9683942, price=71804.12, amount=0.00139268, maker_side=sell, created_at=2018-12-31 21:08:01+00:00)
# Trade(tid=9683944, price=72698.75, amount=0.00412700, maker_side=sell, created_at=2018-12-31 21:08:35+00:00)
# Trade(tid=9683945, price=72695.74, amount=0.00521640, maker_side=sell, created_at=2018-12-31 21:08:40+00:00)
# Trade(tid=9683946, price=72701.67, amount=0.20110666, maker_side=sell, created_at=2018-12-31 21:08:40+00:00)
# Trade(tid=9683953, price=72645.85, amount=0.01212164, maker_side=sell, created_at=2018-12-31 21:09:58+00:00)
# Trade(tid=9683954, price=72646.87, amount=0.01594719, maker_side=sell, created_at=2018-12-31 21:09:58+00:00)
# Trade(tid=9683966, price=72597.58, amount=0.06887282, maker_side=sell, created_at=2018-12-31 21:11:46+00:00)
# Trade(tid=9683968, price=72565.48, amount=0.00163266, maker_side=sell, created_at=2018-12-31 21:12:41+00:00)
# Trade(tid=9683969, price=72565.56, amount=0.00293266, maker_side=sell, created_at=2018-12-31 21:12:41+00:00)
# Trade(tid=9683970, price=72572.52, amount=0.03442332, maker_side=sell, created_at=2018-12-31 21:12:41+00:00)
# Trade(tid=9683971, price=72572.55, amount=0.00115096, maker_side=sell, created_at=2018-12-31 21:12:41+00:00)
# Trade(tid=9683983, price=72494.19, amount=0.01366206, maker_side=sell, created_at=2018-12-31 21:15:15+00:00)
# Trade(tid=9683984, price=72480.97, amount=0.00803797, maker_side=sell, created_at=2018-12-31 21:15:36+00:00)
# Trade(tid=9683986, price=71826.51, amount=0.06845332, maker_side=buy, created_at=2018-12-31 21:16:25+00:00)
# Trade(tid=9683987, price=71826.52, amount=0.07032332, maker_side=buy, created_at=2018-12-31 21:16:25+00:00)
# Trade(tid=9683988, price=71822.46, amount=0.12884332, maker_side=buy, created_at=2018-12-31 21:16:25+00:00)
# Trade(tid=9683989, price=71822.45, amount=0.12081332, maker_side=buy, created_at=2018-12-31 21:16:25+00:00)
# Trade(tid=9683990, price=71810.00, amount=0.19495892, maker_side=buy, created_at=2018-12-31 21:16:25+00:00)
# Trade(tid=9683991, price=71800.00, amount=0.01165734, maker_side=buy, created_at=2018-12-31 21:16:25+00:00)
# Trade(tid=9683995, price=71700.00, amount=0.00410267, maker_side=sell, created_at=2018-12-31 21:16:29+00:00)
# Trade(tid=9684014, price=71554.12, amount=0.00020600, maker_side=sell, created_at=2018-12-31 21:17:56+00:00)
# Trade(tid=9684021, price=71570.00, amount=0.04000000, maker_side=buy, created_at=2018-12-31 21:18:20+00:00)
# Trade(tid=9684023, price=71578.23, amount=0.00496991, maker_side=buy, created_at=2018-12-31 21:18:49+00:00)
# Trade(tid=9684024, price=72000.00, amount=0.05000000, maker_side=sell, created_at=2018-12-31 21:19:02+00:00)
# Trade(tid=9684025, price=72662.07, amount=0.00550494, maker_side=sell, created_at=2018-12-31 21:19:02+00:00)
# Trade(tid=9684026, price=71578.29, amount=0.00300000, maker_side=buy, created_at=2018-12-31 21:19:13+00:00)
# Trade(tid=9684030, price=71572.93, amount=0.00516197, maker_side=buy, created_at=2018-12-31 21:20:55+00:00)
# Trade(tid=9684031, price=71570.05, amount=0.00193803, maker_side=buy, created_at=2018-12-31 21:20:55+00:00)
# Trade(tid=9684033, price=72480.90, amount=0.11545994, maker_side=sell, created_at=2018-12-31 21:21:13+00:00)
# Trade(tid=9684034, price=72484.91, amount=0.05699613, maker_side=sell, created_at=2018-12-31 21:21:13+00:00)
# Trade(tid=9684035, price=71576.72, amount=0.16521592, maker_side=buy, created_at=2018-12-31 21:21:32+00:00)
# Trade(tid=9684037, price=72456.01, amount=0.06700617, maker_side=sell, created_at=2018-12-31 21:21:55+00:00)
# Trade(tid=9684052, price=72380.31, amount=0.00737839, maker_side=sell, created_at=2018-12-31 21:22:58+00:00)
# Trade(tid=9684053, price=72371.99, amount=0.00483613, maker_side=sell, created_at=2018-12-31 21:23:19+00:00)
# Trade(tid=9684057, price=71586.96, amount=0.02006994, maker_side=buy, created_at=2018-12-31 21:24:35+00:00)
# Trade(tid=9684058, price=71586.90, amount=0.05024006, maker_side=buy, created_at=2018-12-31 21:24:35+00:00)
# Trade(tid=9684059, price=72319.08, amount=0.07328633, maker_side=sell, created_at=2018-12-31 21:25:02+00:00)
# Trade(tid=9684060, price=72314.85, amount=0.06700270, maker_side=sell, created_at=2018-12-31 21:25:12+00:00)
# Trade(tid=9684069, price=71586.90, amount=0.07014900, maker_side=buy, created_at=2018-12-31 21:26:25+00:00)
# Trade(tid=9684074, price=72173.35, amount=0.00069200, maker_side=sell, created_at=2018-12-31 21:26:45+00:00)
# Trade(tid=9684079, price=72173.37, amount=0.00133731, maker_side=sell, created_at=2018-12-31 21:26:47+00:00)
# Trade(tid=9684081, price=72173.36, amount=0.00069200, maker_side=sell, created_at=2018-12-31 21:26:48+00:00)
# Trade(tid=9684082, price=72173.35, amount=0.00069200, maker_side=buy, created_at=2018-12-31 21:26:49+00:00)
# Trade(tid=9684083, price=72169.23, amount=0.00560800, maker_side=sell, created_at=2018-12-31 21:26:49+00:00)
# Trade(tid=9684084, price=72169.23, amount=0.00069200, maker_side=sell, created_at=2018-12-31 21:26:50+00:00)
# Trade(tid=9684085, price=72169.23, amount=0.00069200, maker_side=sell, created_at=2018-12-31 21:26:53+00:00)
# Trade(tid=9684088, price=71586.90, amount=0.00157166, maker_side=buy, created_at=2018-12-31 21:27:32+00:00)
# Trade(tid=9684091, price=71586.90, amount=0.28334000, maker_side=buy, created_at=2018-12-31 21:27:49+00:00)
# Trade(tid=9684094, price=72000.00, amount=0.01387620, maker_side=sell, created_at=2018-12-31 21:28:25+00:00)
# Trade(tid=9684096, price=72735.40, amount=0.00172197, maker_side=sell, created_at=2018-12-31 21:29:01+00:00)
# Trade(tid=9684097, price=72735.48, amount=0.00239803, maker_side=sell, created_at=2018-12-31 21:29:01+00:00)
# Trade(tid=9684099, price=71591.02, amount=0.00140000, maker_side=buy, created_at=2018-12-31 21:30:02+00:00)
# Trade(tid=9684100, price=72389.95, amount=0.06706732, maker_side=sell, created_at=2018-12-31 21:30:28+00:00)
# Trade(tid=9684106, price=71586.90, amount=0.07000000, maker_side=buy, created_at=2018-12-31 21:31:51+00:00)
# Trade(tid=9684107, price=71586.90, amount=0.00370000, maker_side=buy, created_at=2018-12-31 21:31:58+00:00)
# Trade(tid=9684108, price=71895.90, amount=0.00118936, maker_side=sell, created_at=2018-12-31 21:31:59+00:00)
# Trade(tid=9684110, price=71891.75, amount=0.03755100, maker_side=sell, created_at=2018-12-31 21:32:10+00:00)
# Trade(tid=9684113, price=71800.00, amount=0.01485864, maker_side=sell, created_at=2018-12-31 21:34:20+00:00)
# Trade(tid=9684114, price=71980.00, amount=0.02083913, maker_side=sell, created_at=2018-12-31 21:34:30+00:00)
# Trade(tid=9684115, price=72389.99, amount=0.04634618, maker_side=sell, created_at=2018-12-31 21:34:30+00:00)
# Trade(tid=9684117, price=72362.09, amount=0.00442221, maker_side=sell, created_at=2018-12-31 21:35:08+00:00)
# Trade(tid=9684120, price=72351.96, amount=0.03151055, maker_side=sell, created_at=2018-12-31 21:35:20+00:00)
# Trade(tid=9684129, price=72147.63, amount=0.00020721, maker_side=sell, created_at=2018-12-31 21:36:55+00:00)
# Trade(tid=9684134, price=71991.75, amount=0.02134100, maker_side=sell, created_at=2018-12-31 21:37:29+00:00)
# Trade(tid=9684136, price=71800.00, amount=0.19405501, maker_side=buy, created_at=2018-12-31 21:37:59+00:00)
# Trade(tid=9684137, price=71800.00, amount=0.00594499, maker_side=sell, created_at=2018-12-31 21:38:00+00:00)
# Trade(tid=9684138, price=71983.48, amount=0.00002639, maker_side=sell, created_at=2018-12-31 21:38:00+00:00)
# Trade(tid=9684139, price=71983.48, amount=0.00597138, maker_side=sell, created_at=2018-12-31 21:38:01+00:00)
# Trade(tid=9684140, price=71979.39, amount=0.00360376, maker_side=sell, created_at=2018-12-31 21:38:08+00:00)
# Trade(tid=9684142, price=72717.54, amount=0.06676518, maker_side=sell, created_at=2018-12-31 21:39:45+00:00)
# Trade(tid=9684144, price=71586.90, amount=0.62131512, maker_side=buy, created_at=2018-12-31 21:39:51+00:00)
# Trade(tid=9684145, price=71586.90, amount=0.02868488, maker_side=sell, created_at=2018-12-31 21:39:52+00:00)
# Trade(tid=9684146, price=72710.77, amount=0.00364399, maker_side=sell, created_at=2018-12-31 21:39:52+00:00)
# Trade(tid=9684147, price=72713.37, amount=0.02516824, maker_side=sell, created_at=2018-12-31 21:39:52+00:00)
# Trade(tid=9684148, price=71554.12, amount=0.00118163, maker_side=buy, created_at=2018-12-31 21:40:02+00:00)
# Trade(tid=9684149, price=72694.10, amount=0.00068781, maker_side=sell, created_at=2018-12-31 21:40:16+00:00)
# Trade(tid=9684155, price=71559.12, amount=0.01052073, maker_side=buy, created_at=2018-12-31 21:42:43+00:00)
# Trade(tid=9684159, price=72499.52, amount=0.00649563, maker_side=sell, created_at=2018-12-31 21:45:37+00:00)
# Trade(tid=9684161, price=71559.12, amount=0.01825095, maker_side=buy, created_at=2018-12-31 21:46:08+00:00)
# Trade(tid=9684162, price=71555.06, amount=0.05069268, maker_side=buy, created_at=2018-12-31 21:46:12+00:00)
# Trade(tid=9684167, price=71559.18, amount=0.00500000, maker_side=buy, created_at=2018-12-31 21:46:45+00:00)
# Trade(tid=9684168, price=72466.05, amount=0.04675803, maker_side=sell, created_at=2018-12-31 21:46:50+00:00)
# Trade(tid=9684169, price=71559.12, amount=0.02017731, maker_side=buy, created_at=2018-12-31 21:47:16+00:00)
# Trade(tid=9684173, price=72364.06, amount=0.06709132, maker_side=sell, created_at=2018-12-31 21:48:28+00:00)
# Trade(tid=9684179, price=72333.86, amount=0.00129399, maker_side=sell, created_at=2018-12-31 21:49:23+00:00)
# Trade(tid=9684180, price=72336.05, amount=0.00351501, maker_side=sell, created_at=2018-12-31 21:49:23+00:00)
# Trade(tid=9684208, price=71555.00, amount=0.04299127, maker_side=buy, created_at=2018-12-31 21:51:39+00:00)
# Trade(tid=9684209, price=71555.00, amount=0.04086032, maker_side=buy, created_at=2018-12-31 21:52:34+00:00)
# Trade(tid=9684210, price=71550.00, amount=0.03127869, maker_side=buy, created_at=2018-12-31 21:52:34+00:00)
# Trade(tid=9684211, price=71533.00, amount=0.01118365, maker_side=buy, created_at=2018-12-31 21:52:34+00:00)
# Trade(tid=9684212, price=71510.00, amount=0.16696966, maker_side=buy, created_at=2018-12-31 21:52:34+00:00)
# Trade(tid=9684213, price=71502.01, amount=0.98827991, maker_side=buy, created_at=2018-12-31 21:52:34+00:00)
# Trade(tid=9684214, price=72222.76, amount=0.00692303, maker_side=sell, created_at=2018-12-31 21:52:47+00:00)
# Trade(tid=9684215, price=71507.18, amount=0.16086000, maker_side=buy, created_at=2018-12-31 21:53:31+00:00)
# Trade(tid=9684216, price=71507.18, amount=0.03861967, maker_side=buy, created_at=2018-12-31 21:53:37+00:00)
# Trade(tid=9684217, price=72168.68, amount=0.07795996, maker_side=sell, created_at=2018-12-31 21:53:57+00:00)
# Trade(tid=9684218, price=72176.90, amount=0.06198289, maker_side=sell, created_at=2018-12-31 21:53:57+00:00)
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
#
#
# 9684934
# ---------------------------------------------------------------------------
# ApiError                                  Traceback (most recent call last)
# <ipython-input-136-0cbc6ea93218> in <module>
#      19     limit = '100'
#      20     #Calling the api trades, we use sort 'asc' so i't starts on the marker we want.
# ---> 21     trades = api.trades('btc_mxn', sort='asc', limit=limit, marker=mark)
#      22     #Starting the counter so we don't raise the error of too many requests on the api.
#      23     count = 0
#
# ~/Desktop/DataAnalytics/proyectos/proyectos/lib/python3.7/site-packages/bitso/api.py in trades(self, book, **kwargs)
#     184         if 'sort' in kwargs:
#     185             parameters['sort'] = kwargs['sort']
# --> 186         resp = self._request_url(url, 'GET', params=parameters)
#     187         return [Trade._NewFromJsonDict(x) for x in resp['payload']]
#     188
#
# ~/Desktop/DataAnalytics/proyectos/proyectos/lib/python3.7/site-packages/bitso/api.py in _request_url(self, url, verb, params, private)
#     945
#     946         content = resp.content
# --> 947         data = self._parse_json(content if isinstance(content, basestring) else content.decode('utf-8'))
#     948         return data
#     949
#
# ~/Desktop/DataAnalytics/proyectos/proyectos/lib/python3.7/site-packages/bitso/api.py in _parse_json(self, json_data)
#     973         try:
#     974             data = json.loads(json_data)
# --> 975             self._check_for_api_error(data)
#     976         except:
#     977             raise
#
# ~/Desktop/DataAnalytics/proyectos/proyectos/lib/python3.7/site-packages/bitso/api.py in _check_for_api_error(self, data)
#     980     def _check_for_api_error(self, data):
#     981         if data['success'] != True:
# --> 982             raise ApiError(data['error'])
#     983         if 'error' in data:
#     984             raise ApiError(data['error'])
#
# ApiError: {'code': 200, 'message': 'Demasiadas solicitudes.'}

# %%
# creating a new data frame.
df = pd.DataFrame(columns=['price', 'volume', 'hour', 'date', 'side'])
# using the lists we got from the while loop to fill the dataframe.
df.price = btc_mxn_price
df.volume = btc_mxn_volume
df.hour = btc_mxn_hour
df.date = btc_mxn_date
df.side = btc_mxn_side
df.date = df.date.astype('datetime64')
#creating new columns with the month and day of each row.
df['month'] = [i.month for i in df.date]
df['day'] = [i.day for i in df.date]
df['year'] = [i.year for i in df.date]

# %%
df.price = df.price.astype(int)
df.volume = df.volume.astype(int)

# %%
#Creating a function that needs a data frame and a number(month) for input.
def extraction(df, m):
    #variable that get's just the row that matches the same month
    f_df = df.loc[df['month'] == m]
    #variable that stores the year
    y = 2018
    #variable that creates a list with the numbers of days of the month
    days = list(f_df['day'].unique())
    #varible that creates a empty dictionary
    results = {}
    #list with the names of the keys in the dictionary that the function returns.
    nombres = ['date', '24h_avg', '12h_avg', 'min', 'max', 'volume', 'm_side']
    
    #for loop that creates new keys in the empty dictionary with a empty list as values.
    for i in nombres:
        results[i] = []
    
    #for that loops on each day in the list of the days of the month.
    for e in days:
        #variable that get's just the rows that match the day in the for loop.
        ndf = f_df.loc[f_df.day == e]
        #appending the results in each dictionary key.
        results['date'].append(datetime.date(y, m, e))
        results['24h_avg'].append(ndf.price.mean())
        results['12h_avg'].append(ndf.price.loc[ndf.hour<12].mean())
        results['max'].append(ndf.price.max())
        results['min'].append(ndf.price.min())
        results['volume'].append(ndf.volume.sum())
        weight = ndf.side.value_counts().sum()
        
        if len(ndf.side.value_counts()) == 2:
            buy = ndf.side.value_counts()['buy']/weight
            sell = ndf.side.value_counts()['sell']/weight
        else:
            if ndf.side.value_counts().index == 'buy':
                buy = ndf.side.value_counts().sum()/weight
            else:
                sell = ndf.side.value_counts().sum()/weight
                
        if buy>sell:
            results['m_side'].append('buy')
        else:
            results['m_side'].append('sell')
            
    #returns the dictionary with the appended elements
    return results

# %%
all_df = pd.DataFrame(columns=['date', '24h_avg', '12h_avg', 'min', 'max', 'volume', 'm_side'])
for i in df.month.unique():
    df_new = pd.DataFrame.from_dict(extraction(df,i))
    all_df = all_df.append(df_new)

# %%
all_df
# Out:
#           date       24h_avg       12h_avg    min    max volume m_side
# 0   2018-11-29  85946.196667  85170.500000  83616  88393     25   sell
# 1   2018-11-30  82963.281250  85850.100000  79999  87400      6    buy
# 0   2018-12-01  83963.092000  81247.270000  80101  86500     26   sell
# 1   2018-12-02  85055.632000  85585.400000  83600  86299      2   sell
# 2   2018-12-03  80289.887000  82459.825000  76306  84899     17    buy
# 3   2018-12-04  80080.830000  78720.856667  76979  83495      8   sell
# 4   2018-12-05  78612.175284  80095.236667  76205  81000      7    buy
# 5   2018-12-06  74984.588754  78095.990338  72000  79559      4   sell
# 6   2018-12-07  69137.401818  69843.144000  66035  71370     18    buy
# 7   2018-12-08  69750.255162  70424.170909  67500  71300      5   sell
# 8   2018-12-09  71837.697425  70018.491803  68970  74495     13   sell
# 9   2018-12-10  71078.343525  72290.816456  69600  72668     26   sell
# 10  2018-12-11  68840.838333  69592.117073  67508  70609     11   sell
# 11  2018-12-12  69493.088000  68699.865000  68000  70500      5   sell
# 12  2018-12-13  68327.317143  69233.295000  66500  70000      8   sell
# 13  2018-12-14  65986.683333  67177.496732  63900  67789     37   sell
# 14  2018-12-15  64885.468333  65084.436667  64500  65212      3   sell
# 15  2018-12-16  65522.602000  65463.575972  64350  66348     19   sell
# 16  2018-12-17  69455.093264  65039.220000  64257  72619     10   sell
# 17  2018-12-18  71173.982192  70875.197368  69864  74000     27   sell
# 18  2018-12-19  75578.757319  75207.456522  73537  79538     31   sell
# 19  2018-12-20  79798.445000  76543.205314  74224  83954     47   sell
# 20  2018-12-21  80212.991538  81402.805000  76000  83498     42   sell
# 21  2018-12-22  77860.150000  77299.500000  76500  79797     26    buy
# 22  2018-12-23  81081.091250  81327.617450  79900  82009     14    buy
# 23  2018-12-24  83135.475333  83890.902500  79926  85434     18    buy
# 24  2018-12-25  77162.387500  77532.505000  75501  79996     10   sell
# 25  2018-12-26  77147.014286  78183.713333  75500  79198     24    buy
# 26  2018-12-27  74009.766250  76145.560000  71111  76980     12    buy
# 27  2018-12-28  75034.309379  72151.275000  71111  77999     48   sell
# 28  2018-12-29  75746.510911  77046.491039  72000  77987    169   sell
# 29  2018-12-30  73849.216667  73400.590361  72400  76789     32   sell
# 30  2018-12-31  73426.736667  74190.038462  71502  74893      0   sell

# %%
new_df = pd.read_csv('df_2016_18.csv')
new_df
# Out:
#             date        24h_avg        12h_avg     min     max  volume m_side
# 0     2016-01-01    7609.079545    7632.189189    7460    7692       5   sell
# 1     2016-01-02    7566.760417    7542.795455    7466    7677       0   sell
# 2     2016-01-03    7605.622222    7591.555556    7450    7699       0   sell
# 3     2016-01-04    7575.472222    7600.250000    7452    7795       5   sell
# 4     2016-01-05    7530.852174    7541.564103    7450    7571       8   sell
# ...          ...            ...            ...     ...     ...     ...    ...
# 1047  2018-11-14  120154.375114  128290.251046  109649  128799      30    buy
# 1048  2018-11-15  113483.330015  115304.308688  108596  117800      15   sell
# 1049  2018-11-16  113055.892996  113805.945000  110820  114650       4   sell
# 1050  2018-11-17  112104.915179  112034.915441  110900  112888       2   sell
# 1051  2018-11-18  113953.917143  113494.440000  112222  115917       1    buy
#
# [1052 rows x 7 columns]

# %%
dfdf = pd.concat([new_df, all_df], ignore_index=True)
dfdf
# Out:
#             date       24h_avg       12h_avg    min    max volume m_side
# 0     2016-01-01   7609.079545   7632.189189   7460   7692      5   sell
# 1     2016-01-02   7566.760417   7542.795455   7466   7677      0   sell
# 2     2016-01-03   7605.622222   7591.555556   7450   7699      0   sell
# 3     2016-01-04   7575.472222   7600.250000   7452   7795      5   sell
# 4     2016-01-05   7530.852174   7541.564103   7450   7571      8   sell
# ...          ...           ...           ...    ...    ...    ...    ...
# 1059  2018-11-25  77161.617438  75143.978533  70200  83839     18   sell
# 1060  2018-11-26  78429.187858  81197.919403  74000  82500     11    buy
# 1061  2018-11-27  76857.395770  77004.091603  75399  78500     34   sell
# 1062  2018-11-28  84291.113636  80433.735695  77600  89499     27    buy
# 1063  2018-11-29  85051.233333  85051.233333  83550  86458     14   sell
#
# [1064 rows x 7 columns]

# %%
dfdf.to_csv('df_2016_18.csv', index=False)
